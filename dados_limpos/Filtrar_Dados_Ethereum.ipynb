# %% [markdown]
# #Limpando os dados da moeda Ethereum

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Juevan/Projeto_Grupo_M3_CNSEG/main/dados/coin_Ethereum.csv')
df.head(10)
# Out:
#    SNo      Name Symbol                 Date      High       Low      Open  \
# 0    1  Ethereum    ETH  2015-08-08 23:59:59  2.798810  0.714725  2.793760
# 1    2  Ethereum    ETH  2015-08-09 23:59:59  0.879810  0.629191  0.706136
# 2    3  Ethereum    ETH  2015-08-10 23:59:59  0.729854  0.636546  0.713989
# 3    4  Ethereum    ETH  2015-08-11 23:59:59  1.131410  0.663235  0.708087
# 4    5  Ethereum    ETH  2015-08-12 23:59:59  1.289940  0.883608  1.058750
# 5    6  Ethereum    ETH  2015-08-13 23:59:59  1.965070  1.171990  1.222240
# 6    7  Ethereum    ETH  2015-08-14 23:59:59  2.261880  1.754750  1.810920
# 7    8  Ethereum    ETH  2015-08-15 23:59:59  1.877240  1.570980  1.802890
# 8    9  Ethereum    ETH  2015-08-16 23:59:59  1.695240  1.089810  1.684350
# 9   10  Ethereum    ETH  2015-08-17 23:59:59  1.581190  1.185340  1.581190
#
#       Close     Volume     Marketcap
# 0  0.753325   674188.0  4.548689e+07
# 1  0.701897   532170.0  4.239957e+07
# 2  0.708448   405283.0  4.281836e+07
# 3  1.067860  1463100.0  6.456929e+07
# 4  1.217440  2150620.0  7.364501e+07
# 5  1.827670  4068680.0  1.106072e+08
# 6  1.827870  4637030.0  1.106723e+08
# 7  1.688900  2554360.0  1.023036e+08
# 8  1.566030  3550790.0  9.490101e+07
# 9  1.203610  1942830.0  8.729537e+07

# %%
df = df.rename(columns={'SNo': 'serial_number'})
df.head()
# Out:
#    serial_number      Name Symbol                 Date      High       Low  \
# 0              1  Ethereum    ETH  2015-08-08 23:59:59  2.798810  0.714725
# 1              2  Ethereum    ETH  2015-08-09 23:59:59  0.879810  0.629191
# 2              3  Ethereum    ETH  2015-08-10 23:59:59  0.729854  0.636546
# 3              4  Ethereum    ETH  2015-08-11 23:59:59  1.131410  0.663235
# 4              5  Ethereum    ETH  2015-08-12 23:59:59  1.289940  0.883608
#
#        Open     Close     Volume     Marketcap
# 0  2.793760  0.753325   674188.0  4.548689e+07
# 1  0.706136  0.701897   532170.0  4.239957e+07
# 2  0.713989  0.708448   405283.0  4.281836e+07
# 3  0.708087  1.067860  1463100.0  6.456929e+07
# 4  1.058750  1.217440  2150620.0  7.364501e+07

# %%
df.isnull().any()
df
# Out:
#       serial_number      Name Symbol                 Date         High  \
# 0                 1  Ethereum    ETH  2015-08-08 23:59:59     2.798810
# 1                 2  Ethereum    ETH  2015-08-09 23:59:59     0.879810
# 2                 3  Ethereum    ETH  2015-08-10 23:59:59     0.729854
# 3                 4  Ethereum    ETH  2015-08-11 23:59:59     1.131410
# 4                 5  Ethereum    ETH  2015-08-12 23:59:59     1.289940
# ...             ...       ...    ...                  ...          ...
# 2155           2156  Ethereum    ETH  2021-07-02 23:59:59  2155.596496
# 2156           2157  Ethereum    ETH  2021-07-03 23:59:59  2237.567155
# 2157           2158  Ethereum    ETH  2021-07-04 23:59:59  2384.286857
# 2158           2159  Ethereum    ETH  2021-07-05 23:59:59  2321.922836
# 2159           2160  Ethereum    ETH  2021-07-06 23:59:59  2346.294874
#
#               Low         Open        Close        Volume     Marketcap
# 0        0.714725     2.793760     0.753325  6.741880e+05  4.548689e+07
# 1        0.629191     0.706136     0.701897  5.321700e+05  4.239957e+07
# 2        0.636546     0.713989     0.708448  4.052830e+05  4.281836e+07
# 3        0.663235     0.708087     1.067860  1.463100e+06  6.456929e+07
# 4        0.883608     1.058750     1.217440  2.150620e+06  7.364501e+07
# ...           ...          ...          ...           ...           ...
# 2155  2021.824808  2109.892677  2150.040364  3.179621e+10  2.505527e+11
# 2156  2117.590013  2150.835025  2226.114282  1.743336e+10  2.594475e+11
# 2157  2190.837703  2226.550382  2321.724112  1.878711e+10  2.706217e+11
# 2158  2163.041394  2321.922836  2198.582464  2.010379e+10  2.562978e+11
# 2159  2197.919385  2197.919385  2324.679449  2.089186e+10  2.710286e+11
#
# [2160 rows x 10 columns]

# %%
df['Date'].unique()
df
# Out:
#       serial_number      Name Symbol                 Date         High  \
# 0                 1  Ethereum    ETH  2015-08-08 23:59:59     2.798810
# 1                 2  Ethereum    ETH  2015-08-09 23:59:59     0.879810
# 2                 3  Ethereum    ETH  2015-08-10 23:59:59     0.729854
# 3                 4  Ethereum    ETH  2015-08-11 23:59:59     1.131410
# 4                 5  Ethereum    ETH  2015-08-12 23:59:59     1.289940
# ...             ...       ...    ...                  ...          ...
# 2155           2156  Ethereum    ETH  2021-07-02 23:59:59  2155.596496
# 2156           2157  Ethereum    ETH  2021-07-03 23:59:59  2237.567155
# 2157           2158  Ethereum    ETH  2021-07-04 23:59:59  2384.286857
# 2158           2159  Ethereum    ETH  2021-07-05 23:59:59  2321.922836
# 2159           2160  Ethereum    ETH  2021-07-06 23:59:59  2346.294874
#
#               Low         Open        Close        Volume     Marketcap
# 0        0.714725     2.793760     0.753325  6.741880e+05  4.548689e+07
# 1        0.629191     0.706136     0.701897  5.321700e+05  4.239957e+07
# 2        0.636546     0.713989     0.708448  4.052830e+05  4.281836e+07
# 3        0.663235     0.708087     1.067860  1.463100e+06  6.456929e+07
# 4        0.883608     1.058750     1.217440  2.150620e+06  7.364501e+07
# ...           ...          ...          ...           ...           ...
# 2155  2021.824808  2109.892677  2150.040364  3.179621e+10  2.505527e+11
# 2156  2117.590013  2150.835025  2226.114282  1.743336e+10  2.594475e+11
# 2157  2190.837703  2226.550382  2321.724112  1.878711e+10  2.706217e+11
# 2158  2163.041394  2321.922836  2198.582464  2.010379e+10  2.562978e+11
# 2159  2197.919385  2197.919385  2324.679449  2.089186e+10  2.710286e+11
#
# [2160 rows x 10 columns]

# %%
df_filtered = df[df['Date'].isna() == False]
df_filtered
# Out:
#       serial_number      Name Symbol                 Date         High  \
# 0                 1  Ethereum    ETH  2015-08-08 23:59:59     2.798810
# 1                 2  Ethereum    ETH  2015-08-09 23:59:59     0.879810
# 2                 3  Ethereum    ETH  2015-08-10 23:59:59     0.729854
# 3                 4  Ethereum    ETH  2015-08-11 23:59:59     1.131410
# 4                 5  Ethereum    ETH  2015-08-12 23:59:59     1.289940
# ...             ...       ...    ...                  ...          ...
# 2155           2156  Ethereum    ETH  2021-07-02 23:59:59  2155.596496
# 2156           2157  Ethereum    ETH  2021-07-03 23:59:59  2237.567155
# 2157           2158  Ethereum    ETH  2021-07-04 23:59:59  2384.286857
# 2158           2159  Ethereum    ETH  2021-07-05 23:59:59  2321.922836
# 2159           2160  Ethereum    ETH  2021-07-06 23:59:59  2346.294874
#
#               Low         Open        Close        Volume     Marketcap
# 0        0.714725     2.793760     0.753325  6.741880e+05  4.548689e+07
# 1        0.629191     0.706136     0.701897  5.321700e+05  4.239957e+07
# 2        0.636546     0.713989     0.708448  4.052830e+05  4.281836e+07
# 3        0.663235     0.708087     1.067860  1.463100e+06  6.456929e+07
# 4        0.883608     1.058750     1.217440  2.150620e+06  7.364501e+07
# ...           ...          ...          ...           ...           ...
# 2155  2021.824808  2109.892677  2150.040364  3.179621e+10  2.505527e+11
# 2156  2117.590013  2150.835025  2226.114282  1.743336e+10  2.594475e+11
# 2157  2190.837703  2226.550382  2321.724112  1.878711e+10  2.706217e+11
# 2158  2163.041394  2321.922836  2198.582464  2.010379e+10  2.562978e+11
# 2159  2197.919385  2197.919385  2324.679449  2.089186e+10  2.710286e+11
#
# [2160 rows x 10 columns]

# %% [markdown]
# ###Localizar e filtrar duplicatas específicas

# %%
df.duplicated
df_filtered.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2155    False
# 2156    False
# 2157    False
# 2158    False
# 2159    False
# Length: 2160, dtype: bool

# %% [markdown]
# #Localizando Duplicatas

# %%
df[df['Date'].duplicated() == 1]
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# #Excluindo as Duplicatas

# %%
df_sem_duplicatas = df.drop_duplicates()
df_sem_duplicatas
# Out:
#       serial_number      Name Symbol                 Date         High  \
# 0                 1  Ethereum    ETH  2015-08-08 23:59:59     2.798810
# 1                 2  Ethereum    ETH  2015-08-09 23:59:59     0.879810
# 2                 3  Ethereum    ETH  2015-08-10 23:59:59     0.729854
# 3                 4  Ethereum    ETH  2015-08-11 23:59:59     1.131410
# 4                 5  Ethereum    ETH  2015-08-12 23:59:59     1.289940
# ...             ...       ...    ...                  ...          ...
# 2155           2156  Ethereum    ETH  2021-07-02 23:59:59  2155.596496
# 2156           2157  Ethereum    ETH  2021-07-03 23:59:59  2237.567155
# 2157           2158  Ethereum    ETH  2021-07-04 23:59:59  2384.286857
# 2158           2159  Ethereum    ETH  2021-07-05 23:59:59  2321.922836
# 2159           2160  Ethereum    ETH  2021-07-06 23:59:59  2346.294874
#
#               Low         Open        Close        Volume     Marketcap
# 0        0.714725     2.793760     0.753325  6.741880e+05  4.548689e+07
# 1        0.629191     0.706136     0.701897  5.321700e+05  4.239957e+07
# 2        0.636546     0.713989     0.708448  4.052830e+05  4.281836e+07
# 3        0.663235     0.708087     1.067860  1.463100e+06  6.456929e+07
# 4        0.883608     1.058750     1.217440  2.150620e+06  7.364501e+07
# ...           ...          ...          ...           ...           ...
# 2155  2021.824808  2109.892677  2150.040364  3.179621e+10  2.505527e+11
# 2156  2117.590013  2150.835025  2226.114282  1.743336e+10  2.594475e+11
# 2157  2190.837703  2226.550382  2321.724112  1.878711e+10  2.706217e+11
# 2158  2163.041394  2321.922836  2198.582464  2.010379e+10  2.562978e+11
# 2159  2197.919385  2197.919385  2324.679449  2.089186e+10  2.710286e+11
#
# [2160 rows x 10 columns]

# %% [markdown]
# ##Organizando os valores para o google sheets conseguir interpretar

# %% [markdown]
# ##Arredondando valores, ajeitando o sinal de float, convertendo tipos

# %%
df['High'] = df['High'].astype(str)
df['Low'] = df['Low'].astype(str)
df['Open'] = df['Open'].astype(str)
df['Close'] = df['Close'].astype(str)
df['Volume'] = df['Volume'].astype(str)


df['High'].str.replace(';', '')
df['Low'].str.replace(',', '.')
df['Open'].str.replace(',', '.')
df['Close'].str.replace(',', '.')
df['Volume'].str.replace(',', '.')

df['High'] = df['High'].astype(float).round(4)
df['Low'] = df['Low'].astype(float).round(4)
df['Open'] = df['Open'].astype(float).round(4)
df['Close'] = df['Close'].astype(float).round(4)
df['Volume'] = df['Volume'].astype(float).round(4)

df
# Out:
#       serial_number      Name Symbol                 Date       High  \
# 0                 1  Ethereum    ETH  2015-08-08 23:59:59     2.7988
# 1                 2  Ethereum    ETH  2015-08-09 23:59:59     0.8798
# 2                 3  Ethereum    ETH  2015-08-10 23:59:59     0.7299
# 3                 4  Ethereum    ETH  2015-08-11 23:59:59     1.1314
# 4                 5  Ethereum    ETH  2015-08-12 23:59:59     1.2899
# ...             ...       ...    ...                  ...        ...
# 2155           2156  Ethereum    ETH  2021-07-02 23:59:59  2155.5965
# 2156           2157  Ethereum    ETH  2021-07-03 23:59:59  2237.5672
# 2157           2158  Ethereum    ETH  2021-07-04 23:59:59  2384.2869
# 2158           2159  Ethereum    ETH  2021-07-05 23:59:59  2321.9228
# 2159           2160  Ethereum    ETH  2021-07-06 23:59:59  2346.2949
#
#             Low       Open      Close        Volume     Marketcap
# 0        0.7147     2.7938     0.7533  6.741880e+05  4.548689e+07
# 1        0.6292     0.7061     0.7019  5.321700e+05  4.239957e+07
# 2        0.6365     0.7140     0.7084  4.052830e+05  4.281836e+07
# 3        0.6632     0.7081     1.0679  1.463100e+06  6.456929e+07
# 4        0.8836     1.0588     1.2174  2.150620e+06  7.364501e+07
# ...         ...        ...        ...           ...           ...
# 2155  2021.8248  2109.8927  2150.0404  3.179621e+10  2.505527e+11
# 2156  2117.5900  2150.8350  2226.1143  1.743336e+10  2.594475e+11
# 2157  2190.8377  2226.5504  2321.7241  1.878711e+10  2.706217e+11
# 2158  2163.0414  2321.9228  2198.5825  2.010379e+10  2.562978e+11
# 2159  2197.9194  2197.9194  2324.6794  2.089186e+10  2.710286e+11
#
# [2160 rows x 10 columns]

# %% [markdown]
# ##Tirar campos nulos

# %%
null_rows = df[df.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ####Não tem dados nulos

# %% [markdown]
# ###Tirando todos os registros vazios no intervalo de dados

# %%
df.dropna()
df
# Out:
#       serial_number      Name Symbol                 Date       High  \
# 0                 1  Ethereum    ETH  2015-08-08 23:59:59     2.7988
# 1                 2  Ethereum    ETH  2015-08-09 23:59:59     0.8798
# 2                 3  Ethereum    ETH  2015-08-10 23:59:59     0.7299
# 3                 4  Ethereum    ETH  2015-08-11 23:59:59     1.1314
# 4                 5  Ethereum    ETH  2015-08-12 23:59:59     1.2899
# ...             ...       ...    ...                  ...        ...
# 2155           2156  Ethereum    ETH  2021-07-02 23:59:59  2155.5965
# 2156           2157  Ethereum    ETH  2021-07-03 23:59:59  2237.5672
# 2157           2158  Ethereum    ETH  2021-07-04 23:59:59  2384.2869
# 2158           2159  Ethereum    ETH  2021-07-05 23:59:59  2321.9228
# 2159           2160  Ethereum    ETH  2021-07-06 23:59:59  2346.2949
#
#             Low       Open      Close        Volume     Marketcap
# 0        0.7147     2.7938     0.7533  6.741880e+05  4.548689e+07
# 1        0.6292     0.7061     0.7019  5.321700e+05  4.239957e+07
# 2        0.6365     0.7140     0.7084  4.052830e+05  4.281836e+07
# 3        0.6632     0.7081     1.0679  1.463100e+06  6.456929e+07
# 4        0.8836     1.0588     1.2174  2.150620e+06  7.364501e+07
# ...         ...        ...        ...           ...           ...
# 2155  2021.8248  2109.8927  2150.0404  3.179621e+10  2.505527e+11
# 2156  2117.5900  2150.8350  2226.1143  1.743336e+10  2.594475e+11
# 2157  2190.8377  2226.5504  2321.7241  1.878711e+10  2.706217e+11
# 2158  2163.0414  2321.9228  2198.5825  2.010379e+10  2.562978e+11
# 2159  2197.9194  2197.9194  2324.6794  2.089186e+10  2.710286e+11
#
# [2160 rows x 10 columns]

# %% [markdown]
# ##Filtrando dados de 2013

# %%
df['Date'] = pd.to_datetime(df['Date'])

df_2013 = df[df['Date'].dt.year == 2013]

print(df_2013)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ##Filtrando dados de 2020 para frente
# Esse é o que vamos usar para trabalhar

# %%
start_date = pd.to_datetime('2020-01-01')

df_from_2020 = df[df['Date'] >= start_date]

print(df_from_2020)

from google.colab import files

filtered_file_path = '/content/'
df_from_2020.to_csv("limpo_ethereum.csv", index=False)
# Out:
#       serial_number      Name Symbol                Date       High  \
# 1607           1608  Ethereum    ETH 2020-01-01 23:59:59   132.8354
# 1608           1609  Ethereum    ETH 2020-01-02 23:59:59   130.8200
# 1609           1610  Ethereum    ETH 2020-01-03 23:59:59   134.5540
# 1610           1611  Ethereum    ETH 2020-01-04 23:59:59   136.0527
# 1611           1612  Ethereum    ETH 2020-01-05 23:59:59   139.4102
# ...             ...       ...    ...                 ...        ...
# 2155           2156  Ethereum    ETH 2021-07-02 23:59:59  2155.5965
# 2156           2157  Ethereum    ETH 2021-07-03 23:59:59  2237.5672
# 2157           2158  Ethereum    ETH 2021-07-04 23:59:59  2384.2869
# 2158           2159  Ethereum    ETH 2021-07-05 23:59:59  2321.9228
# 2159           2160  Ethereum    ETH 2021-07-06 23:59:59  2346.2949
#
#             Low       Open      Close        Volume     Marketcap
# 1607   129.1983   129.6307   130.8020  7.935230e+09  1.427106e+10
# 1608   126.9549   130.8200   127.4102  8.032709e+09  1.390251e+10
# 1609   126.4900   127.4113   134.1717  1.047685e+10  1.464213e+10
# 1610   133.0406   134.1685   135.0694  7.430905e+09  1.474195e+10
# 1611   135.0456   135.0721   136.2768  7.526675e+09  1.487557e+10
# ...         ...        ...        ...           ...           ...
# 2155  2021.8248  2109.8927  2150.0404  3.179621e+10  2.505527e+11
# 2156  2117.5900  2150.8350  2226.1143  1.743336e+10  2.594475e+11
# 2157  2190.8377  2226.5504  2321.7241  1.878711e+10  2.706217e+11
# 2158  2163.0414  2321.9228  2198.5825  2.010379e+10  2.562978e+11
# 2159  2197.9194  2197.9194  2324.6794  2.089186e+10  2.710286e+11
#
# [553 rows x 10 columns]

# %% [markdown]
# ##O que foi feito
# Perguntas para verificar se a planilha está realmente limpa e útil:
#
#     Esses dados fazem sentido?
#         Sim, estou removendo todos os dados que não serão úteis, seja por serem duplicados, nulos ou não totalmente preenchidos. Essa planilha será comparada com eventos filtrados por ano e comparada com outras moedas referentes ao mesmo período.
#
#     Os dados seguem o padrão certo?
#         Sim, os dados foram convertidos, corrigidos e arredondados.
#
#     Prova alguma teoria, suspeita ou traz algum insight?
#         Sim, com esses dados posso analisar a relação entre as moedas e o mundo real.
#
#     Você consegue identificar tendências ou padrões com esses dados?
#         Sim, consigo observar médias, padrões e usar gráficos para extrair informações sobre como a moeda reagiu e como outras moedas reagiram. Posso comparar acontecimentos e observar seu impacto na moeda, além de calcular médias anuais.
#
#     Se não está conseguindo identificar tendências, seria por causa de algum problema na planilha?
#         Não se aplica.
