# %% [markdown]
# #Limpando os dados da moeda Stellar

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Juevan/Projeto_Grupo_M3_CNSEG/main/dados/coin_Stellar.csv')
df.head(10)
# Out:
#    SNo     Name Symbol                 Date      High       Low      Open  \
# 0    1  Stellar    XLM  2014-08-06 23:59:59  0.003402  0.002266  0.002373
# 1    2  Stellar    XLM  2014-08-07 23:59:59  0.003042  0.002455  0.002686
# 2    3  Stellar    XLM  2014-08-08 23:59:59  0.003243  0.002493  0.002493
# 3    4  Stellar    XLM  2014-08-09 23:59:59  0.003710  0.002873  0.002884
# 4    5  Stellar    XLM  2014-08-10 23:59:59  0.007620  0.003363  0.003497
# 5    6  Stellar    XLM  2014-08-11 23:59:59  0.005065  0.003591  0.004566
# 6    7  Stellar    XLM  2014-08-12 23:59:59  0.003679  0.002503  0.003592
# 7    8  Stellar    XLM  2014-08-13 23:59:59  0.003215  0.002570  0.002619
# 8    9  Stellar    XLM  2014-08-14 23:59:59  0.002850  0.002482  0.002763
# 9   10  Stellar    XLM  2014-08-15 23:59:59  0.002610  0.002357  0.002566
#
#       Close         Volume     Marketcap
# 0  0.002657   35819.800781  9.663695e+05
# 1  0.002501  142864.000000  1.079148e+06
# 2  0.002881   93707.796875  1.260109e+06
# 3  0.003481  233579.000000  1.645185e+06
# 4  0.004303  352737.000000  2.216012e+06
# 5  0.003591  479942.000000  2.273974e+06
# 6  0.002659  345441.000000  2.271970e+06
# 7  0.002773  256302.000000  2.589318e+06
# 8  0.002540  169177.000000  2.487701e+06
# 9  0.002403  135243.000000  2.431616e+06

# %%
df = df.rename(columns={'SNo': 'serial_number'})
df.head()
# Out:
#    serial_number     Name Symbol                 Date      High       Low  \
# 0              1  Stellar    XLM  2014-08-06 23:59:59  0.003402  0.002266
# 1              2  Stellar    XLM  2014-08-07 23:59:59  0.003042  0.002455
# 2              3  Stellar    XLM  2014-08-08 23:59:59  0.003243  0.002493
# 3              4  Stellar    XLM  2014-08-09 23:59:59  0.003710  0.002873
# 4              5  Stellar    XLM  2014-08-10 23:59:59  0.007620  0.003363
#
#        Open     Close         Volume     Marketcap
# 0  0.002373  0.002657   35819.800781  9.663695e+05
# 1  0.002686  0.002501  142864.000000  1.079148e+06
# 2  0.002493  0.002881   93707.796875  1.260109e+06
# 3  0.002884  0.003481  233579.000000  1.645185e+06
# 4  0.003497  0.004303  352737.000000  2.216012e+06

# %%
df.isnull().any()
df
# Out:
#       serial_number     Name Symbol                 Date      High       Low  \
# 0                 1  Stellar    XLM  2014-08-06 23:59:59  0.003402  0.002266
# 1                 2  Stellar    XLM  2014-08-07 23:59:59  0.003042  0.002455
# 2                 3  Stellar    XLM  2014-08-08 23:59:59  0.003243  0.002493
# 3                 4  Stellar    XLM  2014-08-09 23:59:59  0.003710  0.002873
# 4                 5  Stellar    XLM  2014-08-10 23:59:59  0.007620  0.003363
# ...             ...      ...    ...                  ...       ...       ...
# 2522           2523  Stellar    XLM  2021-07-02 23:59:59  0.273359  0.252874
# 2523           2524  Stellar    XLM  2021-07-03 23:59:59  0.270331  0.259710
# 2524           2525  Stellar    XLM  2021-07-04 23:59:59  0.272314  0.259118
# 2525           2526  Stellar    XLM  2021-07-05 23:59:59  0.268272  0.252300
# 2526           2527  Stellar    XLM  2021-07-06 23:59:59  0.267757  0.253547
#
#           Open     Close        Volume     Marketcap
# 0     0.002373  0.002657  3.581980e+04  9.663695e+05
# 1     0.002686  0.002501  1.428640e+05  1.079148e+06
# 2     0.002493  0.002881  9.370780e+04  1.260109e+06
# 3     0.002884  0.003481  2.335790e+05  1.645185e+06
# 4     0.003497  0.004303  3.527370e+05  2.216012e+06
# ...        ...       ...           ...           ...
# 2522  0.269148  0.263427  3.487793e+08  6.118631e+09
# 2523  0.263304  0.264324  3.310069e+08  6.139464e+09
# 2524  0.264254  0.268128  3.376196e+08  6.227819e+09
# 2525  0.268272  0.254456  3.359242e+08  5.910264e+09
# 2526  0.253931  0.260190  3.604261e+08  6.049985e+09
#
# [2527 rows x 10 columns]

# %%
df['Date'].unique()
df
# Out:
#       serial_number     Name Symbol                 Date      High       Low  \
# 0                 1  Stellar    XLM  2014-08-06 23:59:59  0.003402  0.002266
# 1                 2  Stellar    XLM  2014-08-07 23:59:59  0.003042  0.002455
# 2                 3  Stellar    XLM  2014-08-08 23:59:59  0.003243  0.002493
# 3                 4  Stellar    XLM  2014-08-09 23:59:59  0.003710  0.002873
# 4                 5  Stellar    XLM  2014-08-10 23:59:59  0.007620  0.003363
# ...             ...      ...    ...                  ...       ...       ...
# 2522           2523  Stellar    XLM  2021-07-02 23:59:59  0.273359  0.252874
# 2523           2524  Stellar    XLM  2021-07-03 23:59:59  0.270331  0.259710
# 2524           2525  Stellar    XLM  2021-07-04 23:59:59  0.272314  0.259118
# 2525           2526  Stellar    XLM  2021-07-05 23:59:59  0.268272  0.252300
# 2526           2527  Stellar    XLM  2021-07-06 23:59:59  0.267757  0.253547
#
#           Open     Close        Volume     Marketcap
# 0     0.002373  0.002657  3.581980e+04  9.663695e+05
# 1     0.002686  0.002501  1.428640e+05  1.079148e+06
# 2     0.002493  0.002881  9.370780e+04  1.260109e+06
# 3     0.002884  0.003481  2.335790e+05  1.645185e+06
# 4     0.003497  0.004303  3.527370e+05  2.216012e+06
# ...        ...       ...           ...           ...
# 2522  0.269148  0.263427  3.487793e+08  6.118631e+09
# 2523  0.263304  0.264324  3.310069e+08  6.139464e+09
# 2524  0.264254  0.268128  3.376196e+08  6.227819e+09
# 2525  0.268272  0.254456  3.359242e+08  5.910264e+09
# 2526  0.253931  0.260190  3.604261e+08  6.049985e+09
#
# [2527 rows x 10 columns]

# %%
df_filtered = df[df['Date'].isna() == False]
df_filtered
# Out:
#       serial_number     Name Symbol                 Date      High       Low  \
# 0                 1  Stellar    XLM  2014-08-06 23:59:59  0.003402  0.002266
# 1                 2  Stellar    XLM  2014-08-07 23:59:59  0.003042  0.002455
# 2                 3  Stellar    XLM  2014-08-08 23:59:59  0.003243  0.002493
# 3                 4  Stellar    XLM  2014-08-09 23:59:59  0.003710  0.002873
# 4                 5  Stellar    XLM  2014-08-10 23:59:59  0.007620  0.003363
# ...             ...      ...    ...                  ...       ...       ...
# 2522           2523  Stellar    XLM  2021-07-02 23:59:59  0.273359  0.252874
# 2523           2524  Stellar    XLM  2021-07-03 23:59:59  0.270331  0.259710
# 2524           2525  Stellar    XLM  2021-07-04 23:59:59  0.272314  0.259118
# 2525           2526  Stellar    XLM  2021-07-05 23:59:59  0.268272  0.252300
# 2526           2527  Stellar    XLM  2021-07-06 23:59:59  0.267757  0.253547
#
#           Open     Close        Volume     Marketcap
# 0     0.002373  0.002657  3.581980e+04  9.663695e+05
# 1     0.002686  0.002501  1.428640e+05  1.079148e+06
# 2     0.002493  0.002881  9.370780e+04  1.260109e+06
# 3     0.002884  0.003481  2.335790e+05  1.645185e+06
# 4     0.003497  0.004303  3.527370e+05  2.216012e+06
# ...        ...       ...           ...           ...
# 2522  0.269148  0.263427  3.487793e+08  6.118631e+09
# 2523  0.263304  0.264324  3.310069e+08  6.139464e+09
# 2524  0.264254  0.268128  3.376196e+08  6.227819e+09
# 2525  0.268272  0.254456  3.359242e+08  5.910264e+09
# 2526  0.253931  0.260190  3.604261e+08  6.049985e+09
#
# [2527 rows x 10 columns]

# %% [markdown]
# ###Localizar e filtrar duplicatas específicas

# %%
df.duplicated
df_filtered.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2522    False
# 2523    False
# 2524    False
# 2525    False
# 2526    False
# Length: 2527, dtype: bool

# %% [markdown]
# #Localizando Duplicatas

# %%
df[df['Date'].duplicated() == 1]
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# #Excluindo as Duplicatas

# %%
df_sem_duplicatas = df.drop_duplicates()
df_sem_duplicatas
# Out:
#       serial_number     Name Symbol                 Date      High       Low  \
# 0                 1  Stellar    XLM  2014-08-06 23:59:59  0.003402  0.002266
# 1                 2  Stellar    XLM  2014-08-07 23:59:59  0.003042  0.002455
# 2                 3  Stellar    XLM  2014-08-08 23:59:59  0.003243  0.002493
# 3                 4  Stellar    XLM  2014-08-09 23:59:59  0.003710  0.002873
# 4                 5  Stellar    XLM  2014-08-10 23:59:59  0.007620  0.003363
# ...             ...      ...    ...                  ...       ...       ...
# 2522           2523  Stellar    XLM  2021-07-02 23:59:59  0.273359  0.252874
# 2523           2524  Stellar    XLM  2021-07-03 23:59:59  0.270331  0.259710
# 2524           2525  Stellar    XLM  2021-07-04 23:59:59  0.272314  0.259118
# 2525           2526  Stellar    XLM  2021-07-05 23:59:59  0.268272  0.252300
# 2526           2527  Stellar    XLM  2021-07-06 23:59:59  0.267757  0.253547
#
#           Open     Close        Volume     Marketcap
# 0     0.002373  0.002657  3.581980e+04  9.663695e+05
# 1     0.002686  0.002501  1.428640e+05  1.079148e+06
# 2     0.002493  0.002881  9.370780e+04  1.260109e+06
# 3     0.002884  0.003481  2.335790e+05  1.645185e+06
# 4     0.003497  0.004303  3.527370e+05  2.216012e+06
# ...        ...       ...           ...           ...
# 2522  0.269148  0.263427  3.487793e+08  6.118631e+09
# 2523  0.263304  0.264324  3.310069e+08  6.139464e+09
# 2524  0.264254  0.268128  3.376196e+08  6.227819e+09
# 2525  0.268272  0.254456  3.359242e+08  5.910264e+09
# 2526  0.253931  0.260190  3.604261e+08  6.049985e+09
#
# [2527 rows x 10 columns]

# %% [markdown]
# ##Organizando os valores para o google sheets conseguir interpretar

# %% [markdown]
# ##Arredondando valores, ajeitando o sinal de float, convertendo tipos

# %%
df['High'] = df['High'].astype(str)
df['Low'] = df['Low'].astype(str)
df['Open'] = df['Open'].astype(str)
df['Close'] = df['Close'].astype(str)
df['Volume'] = df['Volume'].astype(str)


df['High'].str.replace(';', '')
df['Low'].str.replace(',', '.')
df['Open'].str.replace(',', '.')
df['Close'].str.replace(',', '.')
df['Volume'].str.replace(',', '.')

df['High'] = df['High'].astype(float).round(4)
df['Low'] = df['Low'].astype(float).round(4)
df['Open'] = df['Open'].astype(float).round(4)
df['Close'] = df['Close'].astype(float).round(4)
df['Volume'] = df['Volume'].astype(float).round(4)

df
# Out:
#       serial_number     Name Symbol                 Date    High     Low  \
# 0                 1  Stellar    XLM  2014-08-06 23:59:59  0.0034  0.0023
# 1                 2  Stellar    XLM  2014-08-07 23:59:59  0.0030  0.0025
# 2                 3  Stellar    XLM  2014-08-08 23:59:59  0.0032  0.0025
# 3                 4  Stellar    XLM  2014-08-09 23:59:59  0.0037  0.0029
# 4                 5  Stellar    XLM  2014-08-10 23:59:59  0.0076  0.0034
# ...             ...      ...    ...                  ...     ...     ...
# 2522           2523  Stellar    XLM  2021-07-02 23:59:59  0.2734  0.2529
# 2523           2524  Stellar    XLM  2021-07-03 23:59:59  0.2703  0.2597
# 2524           2525  Stellar    XLM  2021-07-04 23:59:59  0.2723  0.2591
# 2525           2526  Stellar    XLM  2021-07-05 23:59:59  0.2683  0.2523
# 2526           2527  Stellar    XLM  2021-07-06 23:59:59  0.2678  0.2535
#
#         Open   Close        Volume     Marketcap
# 0     0.0024  0.0027  3.581980e+04  9.663695e+05
# 1     0.0027  0.0025  1.428640e+05  1.079148e+06
# 2     0.0025  0.0029  9.370780e+04  1.260109e+06
# 3     0.0029  0.0035  2.335790e+05  1.645185e+06
# 4     0.0035  0.0043  3.527370e+05  2.216012e+06
# ...      ...     ...           ...           ...
# 2522  0.2691  0.2634  3.487793e+08  6.118631e+09
# 2523  0.2633  0.2643  3.310069e+08  6.139464e+09
# 2524  0.2643  0.2681  3.376196e+08  6.227819e+09
# 2525  0.2683  0.2545  3.359242e+08  5.910264e+09
# 2526  0.2539  0.2602  3.604261e+08  6.049985e+09
#
# [2527 rows x 10 columns]

# %% [markdown]
# ##Tirar campos nulos

# %%
null_rows = df[df.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ####Não tem dados nulos

# %% [markdown]
# ###Tirando todos os registros vazios no intervalo de dados

# %%
df.dropna()
df
# Out:
#       serial_number     Name Symbol                 Date    High     Low  \
# 0                 1  Stellar    XLM  2014-08-06 23:59:59  0.0034  0.0023
# 1                 2  Stellar    XLM  2014-08-07 23:59:59  0.0030  0.0025
# 2                 3  Stellar    XLM  2014-08-08 23:59:59  0.0032  0.0025
# 3                 4  Stellar    XLM  2014-08-09 23:59:59  0.0037  0.0029
# 4                 5  Stellar    XLM  2014-08-10 23:59:59  0.0076  0.0034
# ...             ...      ...    ...                  ...     ...     ...
# 2522           2523  Stellar    XLM  2021-07-02 23:59:59  0.2734  0.2529
# 2523           2524  Stellar    XLM  2021-07-03 23:59:59  0.2703  0.2597
# 2524           2525  Stellar    XLM  2021-07-04 23:59:59  0.2723  0.2591
# 2525           2526  Stellar    XLM  2021-07-05 23:59:59  0.2683  0.2523
# 2526           2527  Stellar    XLM  2021-07-06 23:59:59  0.2678  0.2535
#
#         Open   Close        Volume     Marketcap
# 0     0.0024  0.0027  3.581980e+04  9.663695e+05
# 1     0.0027  0.0025  1.428640e+05  1.079148e+06
# 2     0.0025  0.0029  9.370780e+04  1.260109e+06
# 3     0.0029  0.0035  2.335790e+05  1.645185e+06
# 4     0.0035  0.0043  3.527370e+05  2.216012e+06
# ...      ...     ...           ...           ...
# 2522  0.2691  0.2634  3.487793e+08  6.118631e+09
# 2523  0.2633  0.2643  3.310069e+08  6.139464e+09
# 2524  0.2643  0.2681  3.376196e+08  6.227819e+09
# 2525  0.2683  0.2545  3.359242e+08  5.910264e+09
# 2526  0.2539  0.2602  3.604261e+08  6.049985e+09
#
# [2527 rows x 10 columns]

# %% [markdown]
# ##Filtrando dados de 2013

# %%
df['Date'] = pd.to_datetime(df['Date'])

df_2013 = df[df['Date'].dt.year == 2013]

print(df_2013)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ##Filtrando dados de 2020 para frente
# Esse é o que vamos usar para trabalhar

# %%
start_date = pd.to_datetime('2020-01-01')

df_from_2020 = df[df['Date'] >= start_date]

print(df_from_2020)

from google.colab import files

filtered_file_path = '/content/'
df_from_2020.to_csv("stellar_limpo.csv", index=False)
# Out:
#       serial_number     Name Symbol                Date    High     Low  \
# 1974           1975  Stellar    XLM 2020-01-01 23:59:59  0.0458  0.0434
# 1975           1976  Stellar    XLM 2020-01-02 23:59:59  0.0456  0.0436
# 1976           1977  Stellar    XLM 2020-01-03 23:59:59  0.0459  0.0435
# 1977           1978  Stellar    XLM 2020-01-04 23:59:59  0.0463  0.0443
# 1978           1979  Stellar    XLM 2020-01-05 23:59:59  0.0467  0.0448
# ...             ...      ...    ...                 ...     ...     ...
# 2522           2523  Stellar    XLM 2021-07-02 23:59:59  0.2734  0.2529
# 2523           2524  Stellar    XLM 2021-07-03 23:59:59  0.2703  0.2597
# 2524           2525  Stellar    XLM 2021-07-04 23:59:59  0.2723  0.2591
# 2525           2526  Stellar    XLM 2021-07-05 23:59:59  0.2683  0.2523
# 2526           2527  Stellar    XLM 2021-07-06 23:59:59  0.2678  0.2535
#
#         Open   Close        Volume     Marketcap
# 1974  0.0451  0.0455  1.684022e+08  9.115006e+08
# 1975  0.0454  0.0441  1.518490e+08  8.846658e+08
# 1976  0.0440  0.0452  1.689310e+08  9.071503e+08
# 1977  0.0452  0.0463  1.522538e+08  9.279671e+08
# 1978  0.0462  0.0454  1.659561e+08  9.096571e+08
# ...      ...     ...           ...           ...
# 2522  0.2691  0.2634  3.487793e+08  6.118631e+09
# 2523  0.2633  0.2643  3.310069e+08  6.139464e+09
# 2524  0.2643  0.2681  3.376196e+08  6.227819e+09
# 2525  0.2683  0.2545  3.359242e+08  5.910264e+09
# 2526  0.2539  0.2602  3.604261e+08  6.049985e+09
#
# [553 rows x 10 columns]

# %% [markdown]
# ##O que foi feito
# Perguntas para verificar se a planilha está realmente limpa e útil:
#
#     Esses dados fazem sentido?
#         Sim, estou removendo todos os dados que não serão úteis, seja por serem duplicados, nulos ou não totalmente preenchidos. Essa planilha será comparada com eventos filtrados por ano e comparada com outras moedas referentes ao mesmo período.
#
#     Os dados seguem o padrão certo?
#         Sim, os dados foram convertidos, corrigidos e arredondados.
#
#     Prova alguma teoria, suspeita ou traz algum insight?
#         Sim, com esses dados posso analisar a relação entre as moedas e o mundo real.
#
#     Você consegue identificar tendências ou padrões com esses dados?
#         Sim, consigo observar médias, padrões e usar gráficos para extrair informações sobre como a moeda reagiu e como outras moedas reagiram. Posso comparar acontecimentos e observar seu impacto na moeda, além de calcular médias anuais.
#
#     Se não está conseguindo identificar tendências, seria por causa de algum problema na planilha?
#         Não se aplica.
