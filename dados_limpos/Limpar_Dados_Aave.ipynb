# %% [markdown]
# #Limpando os dados da moeda Aave

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Juevan/Projeto_Grupo_M3_CNSEG/main/dados/coin_Aave.csv')
df.head(10)
# Out:
#    SNo  Name Symbol                 Date       High        Low       Open  \
# 0    1  Aave   AAVE  2020-10-05 23:59:59  55.112358  49.787900  52.675035
# 1    2  Aave   AAVE  2020-10-06 23:59:59  53.402270  40.734578  53.291969
# 2    3  Aave   AAVE  2020-10-07 23:59:59  42.408314  35.970690  42.399947
# 3    4  Aave   AAVE  2020-10-08 23:59:59  44.902511  36.696057  39.885262
# 4    5  Aave   AAVE  2020-10-09 23:59:59  47.569533  43.291776  43.764463
# 5    6  Aave   AAVE  2020-10-10 23:59:59  51.405655  46.703328  46.818146
# 6    7  Aave   AAVE  2020-10-11 23:59:59  51.453374  48.716040  49.133130
# 7    8  Aave   AAVE  2020-10-12 23:59:59  54.421418  48.754077  49.661573
# 8    9  Aave   AAVE  2020-10-13 23:59:59  57.481904  49.598735  52.238392
# 9   10  Aave   AAVE  2020-10-14 23:59:59  57.853946  49.629529  51.372899
#
#        Close        Volume     Marketcap
# 0  53.219243  0.000000e+00  8.912813e+07
# 1  42.401599  5.830915e+05  7.101144e+07
# 2  40.083976  6.828342e+05  6.713004e+07
# 3  43.764463  1.658817e+06  2.202651e+08
# 4  46.817744  8.155377e+05  2.356322e+08
# 5  49.133718  1.074627e+06  2.472884e+08
# 6  49.660726  6.921506e+05  2.499408e+08
# 7  52.238692  1.354836e+06  2.629157e+08
# 8  51.124317  1.386221e+06  2.573071e+08
# 9  51.316518  3.132405e+06  2.582744e+08

# %%
df = df.rename(columns={'SNo': 'serial_number'})
df.head()
# Out:
#    serial_number  Name Symbol                 Date       High        Low  \
# 0              1  Aave   AAVE  2020-10-05 23:59:59  55.112358  49.787900
# 1              2  Aave   AAVE  2020-10-06 23:59:59  53.402270  40.734578
# 2              3  Aave   AAVE  2020-10-07 23:59:59  42.408314  35.970690
# 3              4  Aave   AAVE  2020-10-08 23:59:59  44.902511  36.696057
# 4              5  Aave   AAVE  2020-10-09 23:59:59  47.569533  43.291776
#
#         Open      Close        Volume     Marketcap
# 0  52.675035  53.219243  0.000000e+00  8.912813e+07
# 1  53.291969  42.401599  5.830915e+05  7.101144e+07
# 2  42.399947  40.083976  6.828342e+05  6.713004e+07
# 3  39.885262  43.764463  1.658817e+06  2.202651e+08
# 4  43.764463  46.817744  8.155377e+05  2.356322e+08

# %%
df.isnull().any()
df
# Out:
#      serial_number  Name Symbol                 Date        High         Low  \
# 0                1  Aave   AAVE  2020-10-05 23:59:59   55.112358   49.787900
# 1                2  Aave   AAVE  2020-10-06 23:59:59   53.402270   40.734578
# 2                3  Aave   AAVE  2020-10-07 23:59:59   42.408314   35.970690
# 3                4  Aave   AAVE  2020-10-08 23:59:59   44.902511   36.696057
# 4                5  Aave   AAVE  2020-10-09 23:59:59   47.569533   43.291776
# ..             ...   ...    ...                  ...         ...         ...
# 270            271  Aave   AAVE  2021-07-02 23:59:59  234.483957  215.951539
# 271            272  Aave   AAVE  2021-07-03 23:59:59  265.107342  228.485206
# 272            273  Aave   AAVE  2021-07-04 23:59:59  289.001124  248.285491
# 273            274  Aave   AAVE  2021-07-05 23:59:59  317.387234  263.433881
# 274            275  Aave   AAVE  2021-07-06 23:59:59  346.714780  307.997525
#
#            Open       Close        Volume     Marketcap
# 0     52.675035   53.219243  0.000000e+00  8.912813e+07
# 1     53.291969   42.401599  5.830915e+05  7.101144e+07
# 2     42.399947   40.083976  6.828342e+05  6.713004e+07
# 3     39.885262   43.764463  1.658817e+06  2.202651e+08
# 4     43.764463   46.817744  8.155377e+05  2.356322e+08
# ..          ...         ...           ...           ...
# 270  230.814119  233.948437  2.566395e+08  3.001542e+09
# 271  234.208478  259.655225  3.853778e+08  3.331546e+09
# 272  259.399426  277.038792  4.275719e+08  3.555054e+09
# 273  277.110533  307.829079  7.931409e+08  3.950269e+09
# 274  307.997525  316.898507  9.887055e+08  4.066776e+09
#
# [275 rows x 10 columns]

# %%
df['Date'].unique()
df
# Out:
#      serial_number  Name Symbol                 Date        High         Low  \
# 0                1  Aave   AAVE  2020-10-05 23:59:59   55.112358   49.787900
# 1                2  Aave   AAVE  2020-10-06 23:59:59   53.402270   40.734578
# 2                3  Aave   AAVE  2020-10-07 23:59:59   42.408314   35.970690
# 3                4  Aave   AAVE  2020-10-08 23:59:59   44.902511   36.696057
# 4                5  Aave   AAVE  2020-10-09 23:59:59   47.569533   43.291776
# ..             ...   ...    ...                  ...         ...         ...
# 270            271  Aave   AAVE  2021-07-02 23:59:59  234.483957  215.951539
# 271            272  Aave   AAVE  2021-07-03 23:59:59  265.107342  228.485206
# 272            273  Aave   AAVE  2021-07-04 23:59:59  289.001124  248.285491
# 273            274  Aave   AAVE  2021-07-05 23:59:59  317.387234  263.433881
# 274            275  Aave   AAVE  2021-07-06 23:59:59  346.714780  307.997525
#
#            Open       Close        Volume     Marketcap
# 0     52.675035   53.219243  0.000000e+00  8.912813e+07
# 1     53.291969   42.401599  5.830915e+05  7.101144e+07
# 2     42.399947   40.083976  6.828342e+05  6.713004e+07
# 3     39.885262   43.764463  1.658817e+06  2.202651e+08
# 4     43.764463   46.817744  8.155377e+05  2.356322e+08
# ..          ...         ...           ...           ...
# 270  230.814119  233.948437  2.566395e+08  3.001542e+09
# 271  234.208478  259.655225  3.853778e+08  3.331546e+09
# 272  259.399426  277.038792  4.275719e+08  3.555054e+09
# 273  277.110533  307.829079  7.931409e+08  3.950269e+09
# 274  307.997525  316.898507  9.887055e+08  4.066776e+09
#
# [275 rows x 10 columns]

# %%
df_filtered = df[df['Date'].isna() == False]
df_filtered
# Out:
#      serial_number  Name Symbol                 Date        High         Low  \
# 0                1  Aave   AAVE  2020-10-05 23:59:59   55.112358   49.787900
# 1                2  Aave   AAVE  2020-10-06 23:59:59   53.402270   40.734578
# 2                3  Aave   AAVE  2020-10-07 23:59:59   42.408314   35.970690
# 3                4  Aave   AAVE  2020-10-08 23:59:59   44.902511   36.696057
# 4                5  Aave   AAVE  2020-10-09 23:59:59   47.569533   43.291776
# ..             ...   ...    ...                  ...         ...         ...
# 270            271  Aave   AAVE  2021-07-02 23:59:59  234.483957  215.951539
# 271            272  Aave   AAVE  2021-07-03 23:59:59  265.107342  228.485206
# 272            273  Aave   AAVE  2021-07-04 23:59:59  289.001124  248.285491
# 273            274  Aave   AAVE  2021-07-05 23:59:59  317.387234  263.433881
# 274            275  Aave   AAVE  2021-07-06 23:59:59  346.714780  307.997525
#
#            Open       Close        Volume     Marketcap
# 0     52.675035   53.219243  0.000000e+00  8.912813e+07
# 1     53.291969   42.401599  5.830915e+05  7.101144e+07
# 2     42.399947   40.083976  6.828342e+05  6.713004e+07
# 3     39.885262   43.764463  1.658817e+06  2.202651e+08
# 4     43.764463   46.817744  8.155377e+05  2.356322e+08
# ..          ...         ...           ...           ...
# 270  230.814119  233.948437  2.566395e+08  3.001542e+09
# 271  234.208478  259.655225  3.853778e+08  3.331546e+09
# 272  259.399426  277.038792  4.275719e+08  3.555054e+09
# 273  277.110533  307.829079  7.931409e+08  3.950269e+09
# 274  307.997525  316.898507  9.887055e+08  4.066776e+09
#
# [275 rows x 10 columns]

# %% [markdown]
# ###Localizar e filtrar duplicatas específicas

# %%
df.duplicated
df_filtered.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 270    False
# 271    False
# 272    False
# 273    False
# 274    False
# Length: 275, dtype: bool

# %% [markdown]
# #Localizando Duplicatas

# %%
df[df['Date'].duplicated() == 1]
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# #Excluindo as Duplicatas

# %%
df_sem_duplicatas = df.drop_duplicates()
df_sem_duplicatas
# Out:
#      serial_number  Name Symbol                 Date        High         Low  \
# 0                1  Aave   AAVE  2020-10-05 23:59:59   55.112358   49.787900
# 1                2  Aave   AAVE  2020-10-06 23:59:59   53.402270   40.734578
# 2                3  Aave   AAVE  2020-10-07 23:59:59   42.408314   35.970690
# 3                4  Aave   AAVE  2020-10-08 23:59:59   44.902511   36.696057
# 4                5  Aave   AAVE  2020-10-09 23:59:59   47.569533   43.291776
# ..             ...   ...    ...                  ...         ...         ...
# 270            271  Aave   AAVE  2021-07-02 23:59:59  234.483957  215.951539
# 271            272  Aave   AAVE  2021-07-03 23:59:59  265.107342  228.485206
# 272            273  Aave   AAVE  2021-07-04 23:59:59  289.001124  248.285491
# 273            274  Aave   AAVE  2021-07-05 23:59:59  317.387234  263.433881
# 274            275  Aave   AAVE  2021-07-06 23:59:59  346.714780  307.997525
#
#            Open       Close        Volume     Marketcap
# 0     52.675035   53.219243  0.000000e+00  8.912813e+07
# 1     53.291969   42.401599  5.830915e+05  7.101144e+07
# 2     42.399947   40.083976  6.828342e+05  6.713004e+07
# 3     39.885262   43.764463  1.658817e+06  2.202651e+08
# 4     43.764463   46.817744  8.155377e+05  2.356322e+08
# ..          ...         ...           ...           ...
# 270  230.814119  233.948437  2.566395e+08  3.001542e+09
# 271  234.208478  259.655225  3.853778e+08  3.331546e+09
# 272  259.399426  277.038792  4.275719e+08  3.555054e+09
# 273  277.110533  307.829079  7.931409e+08  3.950269e+09
# 274  307.997525  316.898507  9.887055e+08  4.066776e+09
#
# [275 rows x 10 columns]

# %% [markdown]
# ##Organizando os valores para o google sheets conseguir interpretar

# %% [markdown]
# ##Arredondando valores, ajeitando o sinal de float, convertendo tipos

# %%
df['High'] = df['High'].astype(str)
df['Low'] = df['Low'].astype(str)
df['Open'] = df['Open'].astype(str)
df['Close'] = df['Close'].astype(str)
df['Volume'] = df['Volume'].astype(str)


df['High'].str.replace(';', '')
df['Low'].str.replace(',', '.')
df['Open'].str.replace(',', '.')
df['Close'].str.replace(',', '.')
df['Volume'].str.replace(',', '.')

df['High'] = df['High'].astype(float).round(4)
df['Low'] = df['Low'].astype(float).round(4)
df['Open'] = df['Open'].astype(float).round(4)
df['Close'] = df['Close'].astype(float).round(4)
df['Volume'] = df['Volume'].astype(float).round(4)

df
# Out:
#      serial_number  Name Symbol                 Date      High       Low  \
# 0                1  Aave   AAVE  2020-10-05 23:59:59   55.1124   49.7879
# 1                2  Aave   AAVE  2020-10-06 23:59:59   53.4023   40.7346
# 2                3  Aave   AAVE  2020-10-07 23:59:59   42.4083   35.9707
# 3                4  Aave   AAVE  2020-10-08 23:59:59   44.9025   36.6961
# 4                5  Aave   AAVE  2020-10-09 23:59:59   47.5695   43.2918
# ..             ...   ...    ...                  ...       ...       ...
# 270            271  Aave   AAVE  2021-07-02 23:59:59  234.4840  215.9515
# 271            272  Aave   AAVE  2021-07-03 23:59:59  265.1073  228.4852
# 272            273  Aave   AAVE  2021-07-04 23:59:59  289.0011  248.2855
# 273            274  Aave   AAVE  2021-07-05 23:59:59  317.3872  263.4339
# 274            275  Aave   AAVE  2021-07-06 23:59:59  346.7148  307.9975
#
#          Open     Close        Volume     Marketcap
# 0     52.6750   53.2192  0.000000e+00  8.912813e+07
# 1     53.2920   42.4016  5.830915e+05  7.101144e+07
# 2     42.3999   40.0840  6.828342e+05  6.713004e+07
# 3     39.8853   43.7645  1.658817e+06  2.202651e+08
# 4     43.7645   46.8177  8.155377e+05  2.356322e+08
# ..        ...       ...           ...           ...
# 270  230.8141  233.9484  2.566395e+08  3.001542e+09
# 271  234.2085  259.6552  3.853778e+08  3.331546e+09
# 272  259.3994  277.0388  4.275719e+08  3.555054e+09
# 273  277.1105  307.8291  7.931409e+08  3.950269e+09
# 274  307.9975  316.8985  9.887055e+08  4.066776e+09
#
# [275 rows x 10 columns]

# %% [markdown]
# ##Tirar campos nulos

# %%
null_rows = df[df.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ####Não tem dados nulos

# %% [markdown]
# ###Tirando todos os registros vazios no intervalo de dados

# %%
df.dropna()
df
# Out:
#      serial_number  Name Symbol                 Date      High       Low  \
# 0                1  Aave   AAVE  2020-10-05 23:59:59   55.1124   49.7879
# 1                2  Aave   AAVE  2020-10-06 23:59:59   53.4023   40.7346
# 2                3  Aave   AAVE  2020-10-07 23:59:59   42.4083   35.9707
# 3                4  Aave   AAVE  2020-10-08 23:59:59   44.9025   36.6961
# 4                5  Aave   AAVE  2020-10-09 23:59:59   47.5695   43.2918
# ..             ...   ...    ...                  ...       ...       ...
# 270            271  Aave   AAVE  2021-07-02 23:59:59  234.4840  215.9515
# 271            272  Aave   AAVE  2021-07-03 23:59:59  265.1073  228.4852
# 272            273  Aave   AAVE  2021-07-04 23:59:59  289.0011  248.2855
# 273            274  Aave   AAVE  2021-07-05 23:59:59  317.3872  263.4339
# 274            275  Aave   AAVE  2021-07-06 23:59:59  346.7148  307.9975
#
#          Open     Close        Volume     Marketcap
# 0     52.6750   53.2192  0.000000e+00  8.912813e+07
# 1     53.2920   42.4016  5.830915e+05  7.101144e+07
# 2     42.3999   40.0840  6.828342e+05  6.713004e+07
# 3     39.8853   43.7645  1.658817e+06  2.202651e+08
# 4     43.7645   46.8177  8.155377e+05  2.356322e+08
# ..        ...       ...           ...           ...
# 270  230.8141  233.9484  2.566395e+08  3.001542e+09
# 271  234.2085  259.6552  3.853778e+08  3.331546e+09
# 272  259.3994  277.0388  4.275719e+08  3.555054e+09
# 273  277.1105  307.8291  7.931409e+08  3.950269e+09
# 274  307.9975  316.8985  9.887055e+08  4.066776e+09
#
# [275 rows x 10 columns]

# %% [markdown]
# ##Filtrando dados de 2013

# %%
df['Date'] = pd.to_datetime(df['Date'])

df_2013 = df[df['Date'].dt.year == 2013]

print(df_2013)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ##Filtrando dados de 2020 para frente
# Esse é o que vamos usar para trabalhar

# %%
start_date = pd.to_datetime('2020-01-01')

df_from_2020 = df[df['Date'] >= start_date]

print(df_from_2020)

from google.colab import files

filtered_file_path = '/content/'
df_from_2020.to_csv("aave_limpo", index=False)
# Out:
#      serial_number  Name Symbol                Date      High       Low  \
# 0                1  Aave   AAVE 2020-10-05 23:59:59   55.1124   49.7879
# 1                2  Aave   AAVE 2020-10-06 23:59:59   53.4023   40.7346
# 2                3  Aave   AAVE 2020-10-07 23:59:59   42.4083   35.9707
# 3                4  Aave   AAVE 2020-10-08 23:59:59   44.9025   36.6961
# 4                5  Aave   AAVE 2020-10-09 23:59:59   47.5695   43.2918
# ..             ...   ...    ...                 ...       ...       ...
# 270            271  Aave   AAVE 2021-07-02 23:59:59  234.4840  215.9515
# 271            272  Aave   AAVE 2021-07-03 23:59:59  265.1073  228.4852
# 272            273  Aave   AAVE 2021-07-04 23:59:59  289.0011  248.2855
# 273            274  Aave   AAVE 2021-07-05 23:59:59  317.3872  263.4339
# 274            275  Aave   AAVE 2021-07-06 23:59:59  346.7148  307.9975
#
#          Open     Close        Volume     Marketcap
# 0     52.6750   53.2192  0.000000e+00  8.912813e+07
# 1     53.2920   42.4016  5.830915e+05  7.101144e+07
# 2     42.3999   40.0840  6.828342e+05  6.713004e+07
# 3     39.8853   43.7645  1.658817e+06  2.202651e+08
# 4     43.7645   46.8177  8.155377e+05  2.356322e+08
# ..        ...       ...           ...           ...
# 270  230.8141  233.9484  2.566395e+08  3.001542e+09
# 271  234.2085  259.6552  3.853778e+08  3.331546e+09
# 272  259.3994  277.0388  4.275719e+08  3.555054e+09
# 273  277.1105  307.8291  7.931409e+08  3.950269e+09
# 274  307.9975  316.8985  9.887055e+08  4.066776e+09
#
# [275 rows x 10 columns]

# %% [markdown]
# ##O que foi feito
# Perguntas para verificar se a planilha está realmente limpa e útil:
#
#     Esses dados fazem sentido?
#         Sim, estou removendo todos os dados que não serão úteis, seja por serem duplicados, nulos ou não totalmente preenchidos. Essa planilha será comparada com eventos filtrados por ano e comparada com outras moedas referentes ao mesmo período.
#
#     Os dados seguem o padrão certo?
#         Sim, os dados foram convertidos, corrigidos e arredondados.
#
#     Prova alguma teoria, suspeita ou traz algum insight?
#         Sim, com esses dados posso analisar a relação entre as moedas e o mundo real.
#
#     Você consegue identificar tendências ou padrões com esses dados?
#         Sim, consigo observar médias, padrões e usar gráficos para extrair informações sobre como a moeda reagiu e como outras moedas reagiram. Posso comparar acontecimentos e observar seu impacto na moeda, além de calcular médias anuais.
#
#     Se não está conseguindo identificar tendências, seria por causa de algum problema na planilha?
#         Não se aplica.
