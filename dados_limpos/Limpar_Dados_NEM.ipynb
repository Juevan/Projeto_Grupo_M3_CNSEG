# %% [markdown]
# #Limpando os dados da moeda NEM

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Juevan/Projeto_Grupo_M3_CNSEG/main/dados/coin_NEM.csv')
df.head(10)
# Out:
#    SNo Name Symbol                 Date      High       Low      Open  \
# 0    1  NEM    XEM  2015-04-02 23:59:59  0.000323  0.000227  0.000242
# 1    2  NEM    XEM  2015-04-03 23:59:59  0.000330  0.000291  0.000309
# 2    3  NEM    XEM  2015-04-04 23:59:59  0.000318  0.000251  0.000310
# 3    4  NEM    XEM  2015-04-05 23:59:59  0.000283  0.000218  0.000272
# 4    5  NEM    XEM  2015-04-06 23:59:59  0.000299  0.000229  0.000232
# 5    6  NEM    XEM  2015-04-07 23:59:59  0.000288  0.000234  0.000288
# 6    7  NEM    XEM  2015-04-08 23:59:59  0.000259  0.000223  0.000245
# 7    8  NEM    XEM  2015-04-09 23:59:59  0.000239  0.000213  0.000228
# 8    9  NEM    XEM  2015-04-10 23:59:59  0.000227  0.000167  0.000224
# 9   10  NEM    XEM  2015-04-11 23:59:59  0.000192  0.000143  0.000175
#
#       Close        Volume     Marketcap
# 0  0.000314  28549.400391  2.823534e+06
# 1  0.000310  20677.900391  2.792457e+06
# 2  0.000277  23550.199219  2.488770e+06
# 3  0.000232  26800.199219  2.087388e+06
# 4  0.000289  22511.500000  2.598354e+06
# 5  0.000241  14437.000000  2.164689e+06
# 6  0.000228   6932.850098  2.050830e+06
# 7  0.000224  10013.599609  2.017638e+06
# 8  0.000175  16846.000000  1.572237e+06
# 9  0.000163  22845.900391  1.470060e+06

# %%
df = df.rename(columns={'SNo': 'serial_number'})
df.head()
# Out:
#    serial_number Name Symbol                 Date      High       Low  \
# 0              1  NEM    XEM  2015-04-02 23:59:59  0.000323  0.000227
# 1              2  NEM    XEM  2015-04-03 23:59:59  0.000330  0.000291
# 2              3  NEM    XEM  2015-04-04 23:59:59  0.000318  0.000251
# 3              4  NEM    XEM  2015-04-05 23:59:59  0.000283  0.000218
# 4              5  NEM    XEM  2015-04-06 23:59:59  0.000299  0.000229
#
#        Open     Close        Volume     Marketcap
# 0  0.000242  0.000314  28549.400391  2.823534e+06
# 1  0.000309  0.000310  20677.900391  2.792457e+06
# 2  0.000310  0.000277  23550.199219  2.488770e+06
# 3  0.000272  0.000232  26800.199219  2.087388e+06
# 4  0.000232  0.000289  22511.500000  2.598354e+06

# %%
df.isnull().any()
df
# Out:
#       serial_number Name Symbol                 Date      High       Low  \
# 0                 1  NEM    XEM  2015-04-02 23:59:59  0.000323  0.000227
# 1                 2  NEM    XEM  2015-04-03 23:59:59  0.000330  0.000291
# 2                 3  NEM    XEM  2015-04-04 23:59:59  0.000318  0.000251
# 3                 4  NEM    XEM  2015-04-05 23:59:59  0.000283  0.000218
# 4                 5  NEM    XEM  2015-04-06 23:59:59  0.000299  0.000229
# ...             ...  ...    ...                  ...       ...       ...
# 2283           2284  NEM    XEM  2021-07-02 23:59:59  0.131455  0.123406
# 2284           2285  NEM    XEM  2021-07-03 23:59:59  0.136359  0.128350
# 2285           2286  NEM    XEM  2021-07-04 23:59:59  0.140061  0.129912
# 2286           2287  NEM    XEM  2021-07-05 23:59:59  0.137633  0.126915
# 2287           2288  NEM    XEM  2021-07-06 23:59:59  0.136318  0.128804
#
#           Open     Close        Volume     Marketcap
# 0     0.000242  0.000314  2.854940e+04  2.823534e+06
# 1     0.000309  0.000310  2.067790e+04  2.792457e+06
# 2     0.000310  0.000277  2.355020e+04  2.488770e+06
# 3     0.000272  0.000232  2.680020e+04  2.087388e+06
# 4     0.000232  0.000289  2.251150e+04  2.598354e+06
# ...        ...       ...           ...           ...
# 2283  0.128181  0.131455  3.983899e+07  1.183097e+09
# 2284  0.131542  0.134756  4.164779e+07  1.212805e+09
# 2285  0.134751  0.137617  4.953784e+07  1.238554e+09
# 2286  0.137633  0.130602  5.999584e+07  1.175421e+09
# 2287  0.130591  0.133591  6.635341e+07  1.202315e+09
#
# [2288 rows x 10 columns]

# %%
df['Date'].unique()
df
# Out:
#       serial_number Name Symbol                 Date      High       Low  \
# 0                 1  NEM    XEM  2015-04-02 23:59:59  0.000323  0.000227
# 1                 2  NEM    XEM  2015-04-03 23:59:59  0.000330  0.000291
# 2                 3  NEM    XEM  2015-04-04 23:59:59  0.000318  0.000251
# 3                 4  NEM    XEM  2015-04-05 23:59:59  0.000283  0.000218
# 4                 5  NEM    XEM  2015-04-06 23:59:59  0.000299  0.000229
# ...             ...  ...    ...                  ...       ...       ...
# 2283           2284  NEM    XEM  2021-07-02 23:59:59  0.131455  0.123406
# 2284           2285  NEM    XEM  2021-07-03 23:59:59  0.136359  0.128350
# 2285           2286  NEM    XEM  2021-07-04 23:59:59  0.140061  0.129912
# 2286           2287  NEM    XEM  2021-07-05 23:59:59  0.137633  0.126915
# 2287           2288  NEM    XEM  2021-07-06 23:59:59  0.136318  0.128804
#
#           Open     Close        Volume     Marketcap
# 0     0.000242  0.000314  2.854940e+04  2.823534e+06
# 1     0.000309  0.000310  2.067790e+04  2.792457e+06
# 2     0.000310  0.000277  2.355020e+04  2.488770e+06
# 3     0.000272  0.000232  2.680020e+04  2.087388e+06
# 4     0.000232  0.000289  2.251150e+04  2.598354e+06
# ...        ...       ...           ...           ...
# 2283  0.128181  0.131455  3.983899e+07  1.183097e+09
# 2284  0.131542  0.134756  4.164779e+07  1.212805e+09
# 2285  0.134751  0.137617  4.953784e+07  1.238554e+09
# 2286  0.137633  0.130602  5.999584e+07  1.175421e+09
# 2287  0.130591  0.133591  6.635341e+07  1.202315e+09
#
# [2288 rows x 10 columns]

# %%
df_filtered = df[df['Date'].isna() == False]
df_filtered
# Out:
#       serial_number Name Symbol                 Date      High       Low  \
# 0                 1  NEM    XEM  2015-04-02 23:59:59  0.000323  0.000227
# 1                 2  NEM    XEM  2015-04-03 23:59:59  0.000330  0.000291
# 2                 3  NEM    XEM  2015-04-04 23:59:59  0.000318  0.000251
# 3                 4  NEM    XEM  2015-04-05 23:59:59  0.000283  0.000218
# 4                 5  NEM    XEM  2015-04-06 23:59:59  0.000299  0.000229
# ...             ...  ...    ...                  ...       ...       ...
# 2283           2284  NEM    XEM  2021-07-02 23:59:59  0.131455  0.123406
# 2284           2285  NEM    XEM  2021-07-03 23:59:59  0.136359  0.128350
# 2285           2286  NEM    XEM  2021-07-04 23:59:59  0.140061  0.129912
# 2286           2287  NEM    XEM  2021-07-05 23:59:59  0.137633  0.126915
# 2287           2288  NEM    XEM  2021-07-06 23:59:59  0.136318  0.128804
#
#           Open     Close        Volume     Marketcap
# 0     0.000242  0.000314  2.854940e+04  2.823534e+06
# 1     0.000309  0.000310  2.067790e+04  2.792457e+06
# 2     0.000310  0.000277  2.355020e+04  2.488770e+06
# 3     0.000272  0.000232  2.680020e+04  2.087388e+06
# 4     0.000232  0.000289  2.251150e+04  2.598354e+06
# ...        ...       ...           ...           ...
# 2283  0.128181  0.131455  3.983899e+07  1.183097e+09
# 2284  0.131542  0.134756  4.164779e+07  1.212805e+09
# 2285  0.134751  0.137617  4.953784e+07  1.238554e+09
# 2286  0.137633  0.130602  5.999584e+07  1.175421e+09
# 2287  0.130591  0.133591  6.635341e+07  1.202315e+09
#
# [2288 rows x 10 columns]

# %% [markdown]
# ###Localizar e filtrar duplicatas específicas

# %%
df.duplicated
df_filtered.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2283    False
# 2284    False
# 2285    False
# 2286    False
# 2287    False
# Length: 2288, dtype: bool

# %% [markdown]
# #Localizando Duplicatas

# %%
df[df['Date'].duplicated() == 1]
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# #Excluindo as Duplicatas

# %%
df_sem_duplicatas = df.drop_duplicates()
df_sem_duplicatas
# Out:
#       serial_number Name Symbol                 Date      High       Low  \
# 0                 1  NEM    XEM  2015-04-02 23:59:59  0.000323  0.000227
# 1                 2  NEM    XEM  2015-04-03 23:59:59  0.000330  0.000291
# 2                 3  NEM    XEM  2015-04-04 23:59:59  0.000318  0.000251
# 3                 4  NEM    XEM  2015-04-05 23:59:59  0.000283  0.000218
# 4                 5  NEM    XEM  2015-04-06 23:59:59  0.000299  0.000229
# ...             ...  ...    ...                  ...       ...       ...
# 2283           2284  NEM    XEM  2021-07-02 23:59:59  0.131455  0.123406
# 2284           2285  NEM    XEM  2021-07-03 23:59:59  0.136359  0.128350
# 2285           2286  NEM    XEM  2021-07-04 23:59:59  0.140061  0.129912
# 2286           2287  NEM    XEM  2021-07-05 23:59:59  0.137633  0.126915
# 2287           2288  NEM    XEM  2021-07-06 23:59:59  0.136318  0.128804
#
#           Open     Close        Volume     Marketcap
# 0     0.000242  0.000314  2.854940e+04  2.823534e+06
# 1     0.000309  0.000310  2.067790e+04  2.792457e+06
# 2     0.000310  0.000277  2.355020e+04  2.488770e+06
# 3     0.000272  0.000232  2.680020e+04  2.087388e+06
# 4     0.000232  0.000289  2.251150e+04  2.598354e+06
# ...        ...       ...           ...           ...
# 2283  0.128181  0.131455  3.983899e+07  1.183097e+09
# 2284  0.131542  0.134756  4.164779e+07  1.212805e+09
# 2285  0.134751  0.137617  4.953784e+07  1.238554e+09
# 2286  0.137633  0.130602  5.999584e+07  1.175421e+09
# 2287  0.130591  0.133591  6.635341e+07  1.202315e+09
#
# [2288 rows x 10 columns]

# %% [markdown]
# ##Organizando os valores para o google sheets conseguir interpretar

# %% [markdown]
# ##Arredondando valores, ajeitando o sinal de float, convertendo tipos

# %%
df['High'] = df['High'].astype(str)
df['Low'] = df['Low'].astype(str)
df['Open'] = df['Open'].astype(str)
df['Close'] = df['Close'].astype(str)
df['Volume'] = df['Volume'].astype(str)


df['High'].str.replace(';', '')
df['Low'].str.replace(',', '.')
df['Open'].str.replace(',', '.')
df['Close'].str.replace(',', '.')
df['Volume'].str.replace(',', '.')

df['High'] = df['High'].astype(float).round(4)
df['Low'] = df['Low'].astype(float).round(4)
df['Open'] = df['Open'].astype(float).round(4)
df['Close'] = df['Close'].astype(float).round(4)
df['Volume'] = df['Volume'].astype(float).round(4)

df
# Out:
#       serial_number Name Symbol                 Date    High     Low    Open  \
# 0                 1  NEM    XEM  2015-04-02 23:59:59  0.0003  0.0002  0.0002
# 1                 2  NEM    XEM  2015-04-03 23:59:59  0.0003  0.0003  0.0003
# 2                 3  NEM    XEM  2015-04-04 23:59:59  0.0003  0.0003  0.0003
# 3                 4  NEM    XEM  2015-04-05 23:59:59  0.0003  0.0002  0.0003
# 4                 5  NEM    XEM  2015-04-06 23:59:59  0.0003  0.0002  0.0002
# ...             ...  ...    ...                  ...     ...     ...     ...
# 2283           2284  NEM    XEM  2021-07-02 23:59:59  0.1315  0.1234  0.1282
# 2284           2285  NEM    XEM  2021-07-03 23:59:59  0.1364  0.1284  0.1315
# 2285           2286  NEM    XEM  2021-07-04 23:59:59  0.1401  0.1299  0.1348
# 2286           2287  NEM    XEM  2021-07-05 23:59:59  0.1376  0.1269  0.1376
# 2287           2288  NEM    XEM  2021-07-06 23:59:59  0.1363  0.1288  0.1306
#
#        Close        Volume     Marketcap
# 0     0.0003  2.854940e+04  2.823534e+06
# 1     0.0003  2.067790e+04  2.792457e+06
# 2     0.0003  2.355020e+04  2.488770e+06
# 3     0.0002  2.680020e+04  2.087388e+06
# 4     0.0003  2.251150e+04  2.598354e+06
# ...      ...           ...           ...
# 2283  0.1315  3.983899e+07  1.183097e+09
# 2284  0.1348  4.164779e+07  1.212805e+09
# 2285  0.1376  4.953784e+07  1.238554e+09
# 2286  0.1306  5.999584e+07  1.175421e+09
# 2287  0.1336  6.635341e+07  1.202315e+09
#
# [2288 rows x 10 columns]

# %% [markdown]
# ##Tirar campos nulos

# %%
null_rows = df[df.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ####Não tem dados nulos

# %% [markdown]
# ###Tirando todos os registros vazios no intervalo de dados

# %%
df.dropna()
df
# Out:
#       serial_number Name Symbol                 Date    High     Low    Open  \
# 0                 1  NEM    XEM  2015-04-02 23:59:59  0.0003  0.0002  0.0002
# 1                 2  NEM    XEM  2015-04-03 23:59:59  0.0003  0.0003  0.0003
# 2                 3  NEM    XEM  2015-04-04 23:59:59  0.0003  0.0003  0.0003
# 3                 4  NEM    XEM  2015-04-05 23:59:59  0.0003  0.0002  0.0003
# 4                 5  NEM    XEM  2015-04-06 23:59:59  0.0003  0.0002  0.0002
# ...             ...  ...    ...                  ...     ...     ...     ...
# 2283           2284  NEM    XEM  2021-07-02 23:59:59  0.1315  0.1234  0.1282
# 2284           2285  NEM    XEM  2021-07-03 23:59:59  0.1364  0.1284  0.1315
# 2285           2286  NEM    XEM  2021-07-04 23:59:59  0.1401  0.1299  0.1348
# 2286           2287  NEM    XEM  2021-07-05 23:59:59  0.1376  0.1269  0.1376
# 2287           2288  NEM    XEM  2021-07-06 23:59:59  0.1363  0.1288  0.1306
#
#        Close        Volume     Marketcap
# 0     0.0003  2.854940e+04  2.823534e+06
# 1     0.0003  2.067790e+04  2.792457e+06
# 2     0.0003  2.355020e+04  2.488770e+06
# 3     0.0002  2.680020e+04  2.087388e+06
# 4     0.0003  2.251150e+04  2.598354e+06
# ...      ...           ...           ...
# 2283  0.1315  3.983899e+07  1.183097e+09
# 2284  0.1348  4.164779e+07  1.212805e+09
# 2285  0.1376  4.953784e+07  1.238554e+09
# 2286  0.1306  5.999584e+07  1.175421e+09
# 2287  0.1336  6.635341e+07  1.202315e+09
#
# [2288 rows x 10 columns]

# %% [markdown]
# ##Filtrando dados de 2013

# %%
df['Date'] = pd.to_datetime(df['Date'])

df_2013 = df[df['Date'].dt.year == 2013]

print(df_2013)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ##Filtrando dados de 2020 para frente
# Esse é o que vamos usar para trabalhar

# %%
start_date = pd.to_datetime('2020-01-01')

df_from_2020 = df[df['Date'] >= start_date]

print(df_from_2020)

from google.colab import files

filtered_file_path = '/content/'
df_from_2020.to_csv("NEM_limpo.csv", index=False)
# Out:
#       serial_number Name Symbol                Date    High     Low    Open  \
# 1735           1736  NEM    XEM 2020-01-01 23:59:59  0.0330  0.0319  0.0321
# 1736           1737  NEM    XEM 2020-01-02 23:59:59  0.0332  0.0314  0.0327
# 1737           1738  NEM    XEM 2020-01-03 23:59:59  0.0326  0.0313  0.0320
# 1738           1739  NEM    XEM 2020-01-04 23:59:59  0.0329  0.0317  0.0321
# 1739           1740  NEM    XEM 2020-01-05 23:59:59  0.0333  0.0319  0.0321
# ...             ...  ...    ...                 ...     ...     ...     ...
# 2283           2284  NEM    XEM 2021-07-02 23:59:59  0.1315  0.1234  0.1282
# 2284           2285  NEM    XEM 2021-07-03 23:59:59  0.1364  0.1284  0.1315
# 2285           2286  NEM    XEM 2021-07-04 23:59:59  0.1401  0.1299  0.1348
# 2286           2287  NEM    XEM 2021-07-05 23:59:59  0.1376  0.1269  0.1376
# 2287           2288  NEM    XEM 2021-07-06 23:59:59  0.1363  0.1288  0.1306
#
#        Close        Volume     Marketcap
# 1735  0.0326  5.041453e+06  2.938314e+08
# 1736  0.0319  5.253256e+06  2.872094e+08
# 1737  0.0321  5.138719e+06  2.891040e+08
# 1738  0.0321  8.757789e+06  2.888092e+08
# 1739  0.0324  4.489886e+06  2.912630e+08
# ...      ...           ...           ...
# 2283  0.1315  3.983899e+07  1.183097e+09
# 2284  0.1348  4.164779e+07  1.212805e+09
# 2285  0.1376  4.953784e+07  1.238554e+09
# 2286  0.1306  5.999584e+07  1.175421e+09
# 2287  0.1336  6.635341e+07  1.202315e+09
#
# [553 rows x 10 columns]

# %% [markdown]
# ##O que foi feito
# Perguntas para verificar se a planilha está realmente limpa e útil:
#
#     Esses dados fazem sentido?
#         Sim, estou removendo todos os dados que não serão úteis, seja por serem duplicados, nulos ou não totalmente preenchidos. Essa planilha será comparada com eventos filtrados por ano e comparada com outras moedas referentes ao mesmo período.
#
#     Os dados seguem o padrão certo?
#         Sim, os dados foram convertidos, corrigidos e arredondados.
#
#     Prova alguma teoria, suspeita ou traz algum insight?
#         Sim, com esses dados posso analisar a relação entre as moedas e o mundo real.
#
#     Você consegue identificar tendências ou padrões com esses dados?
#         Sim, consigo observar médias, padrões e usar gráficos para extrair informações sobre como a moeda reagiu e como outras moedas reagiram. Posso comparar acontecimentos e observar seu impacto na moeda, além de calcular médias anuais.
#
#     Se não está conseguindo identificar tendências, seria por causa de algum problema na planilha?
#         Não se aplica.
