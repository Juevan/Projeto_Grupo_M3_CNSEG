df['Date'].unique()
df
# Out:
#       serial_number       Name Symbol                 Date       High  \
# 0                 1  Chainlink   LINK  2017-09-21 23:59:59   0.207892
# 1                 2  Chainlink   LINK  2017-09-22 23:59:59   0.181675
# 2                 3  Chainlink   LINK  2017-09-23 23:59:59   0.157440
# 3                 4  Chainlink   LINK  2017-09-24 23:59:59   0.190250
# 4                 5  Chainlink   LINK  2017-09-25 23:59:59   0.182637
# ...             ...        ...    ...                  ...        ...
# 1380           1381  Chainlink   LINK  2021-07-02 23:59:59  18.520256
# 1381           1382  Chainlink   LINK  2021-07-03 23:59:59  18.886003
# 1382           1383  Chainlink   LINK  2021-07-04 23:59:59  19.894503
# 1383           1384  Chainlink   LINK  2021-07-05 23:59:59  19.246891
# 1384           1385  Chainlink   LINK  2021-07-06 23:59:59  20.240997
#
#             Low       Open      Close        Volume     Marketcap
# ...

# %%
df_filtered = df[df['Date'].isna() == False]
df_filtered
# Out:
#       serial_number       Name Symbol                 Date       High  \
# 0                 1  Chainlink   LINK  2017-09-21 23:59:59   0.207892
# 1                 2  Chainlink   LINK  2017-09-22 23:59:59   0.181675
# 2                 3  Chainlink   LINK  2017-09-23 23:59:59   0.157440
# 3                 4  Chainlink   LINK  2017-09-24 23:59:59   0.190250
# 4                 5  Chainlink   LINK  2017-09-25 23:59:59   0.182637
# ...             ...        ...    ...                  ...        ...
# 1380           1381  Chainlink   LINK  2021-07-02 23:59:59  18.520256
# 1381           1382  Chainlink   LINK  2021-07-03 23:59:59  18.886003
# 1382           1383  Chainlink   LINK  2021-07-04 23:59:59  19.894503
# 1383           1384  Chainlink   LINK  2021-07-05 23:59:59  19.246891
# 1384           1385  Chainlink   LINK  2021-07-06 23:59:59  20.240997
#
#             Low       Open      Close        Volume     Marketcap
# ...

# %% [markdown]
# ###Localizar e filtrar duplicatas específicas

# %%
df.duplicated
df_filtered.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1380    False
# 1381    False
# 1382    False
# 1383    False
# 1384    False
# Length: 1385, dtype: bool

# %% [markdown]
# #Localizando Duplicatas

# %%
df[df['Date'].duplicated() == 1]
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# #Excluindo as Duplicatas

# %%
df_sem_duplicatas = df.drop_duplicates()
df_sem_duplicatas
# Out:
#       serial_number       Name Symbol                 Date       High  \
# 0                 1  Chainlink   LINK  2017-09-21 23:59:59   0.207892
# 1                 2  Chainlink   LINK  2017-09-22 23:59:59   0.181675
# 2                 3  Chainlink   LINK  2017-09-23 23:59:59   0.157440
# 3                 4  Chainlink   LINK  2017-09-24 23:59:59   0.190250
# 4                 5  Chainlink   LINK  2017-09-25 23:59:59   0.182637
# ...             ...        ...    ...                  ...        ...
# 1380           1381  Chainlink   LINK  2021-07-02 23:59:59  18.520256
# 1381           1382  Chainlink   LINK  2021-07-03 23:59:59  18.886003
# 1382           1383  Chainlink   LINK  2021-07-04 23:59:59  19.894503
# 1383           1384  Chainlink   LINK  2021-07-05 23:59:59  19.246891
# 1384           1385  Chainlink   LINK  2021-07-06 23:59:59  20.240997
#
#             Low       Open      Close        Volume     Marketcap
# ...

# %% [markdown]
# ##Organizando os valores para o google sheets conseguir interpretar

# %% [markdown]
# ##Arredondando valores, ajeitando o sinal de float, convertendo tipos

# %%
df['High'] = df['High'].astype(str)
df['Low'] = df['Low'].astype(str)
df['Open'] = df['Open'].astype(str)
df['Close'] = df['Close'].astype(str)
df['Volume'] = df['Volume'].astype(str)


df['High'].str.replace(';', '')
df['Low'].str.replace(',', '.')
df['Open'].str.replace(',', '.')
df['Close'].str.replace(',', '.')
df['Volume'].str.replace(',', '.')

df['High'] = df['High'].astype(float).round(4)
df['Low'] = df['Low'].astype(float).round(4)
df['Open'] = df['Open'].astype(float).round(4)
df['Close'] = df['Close'].astype(float).round(4)
df['Volume'] = df['Volume'].astype(float).round(4)

df
# Out:
#       serial_number       Name Symbol                 Date     High      Low  \
# 0                 1  Chainlink   LINK  2017-09-21 23:59:59   0.2079   0.1553
# 1                 2  Chainlink   LINK  2017-09-22 23:59:59   0.1817   0.1399
# 2                 3  Chainlink   LINK  2017-09-23 23:59:59   0.1574   0.1263
# 3                 4  Chainlink   LINK  2017-09-24 23:59:59   0.1902   0.1303
# 4                 5  Chainlink   LINK  2017-09-25 23:59:59   0.1826   0.1586
# ...             ...        ...    ...                  ...      ...      ...
# 1380           1381  Chainlink   LINK  2021-07-02 23:59:59  18.5203  17.3055
# 1381           1382  Chainlink   LINK  2021-07-03 23:59:59  18.8860  17.8981
# 1382           1383  Chainlink   LINK  2021-07-04 23:59:59  19.8945  18.0290
# 1383           1384  Chainlink   LINK  2021-07-05 23:59:59  19.2469  17.8148
# 1384           1385  Chainlink   LINK  2021-07-06 23:59:59  20.2410  18.3519
#
# ...

# %% [markdown]
# ##Tirar campos nulos

# %%
null_rows = df[df.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ####Não tem dados nulos

# %% [markdown]
# ###Tirando todos os registros vazios no intervalo de dados

# %%
df.dropna()
df
# Out:
#       serial_number       Name Symbol                 Date     High      Low  \
# 0                 1  Chainlink   LINK  2017-09-21 23:59:59   0.2079   0.1553
# 1                 2  Chainlink   LINK  2017-09-22 23:59:59   0.1817   0.1399
# 2                 3  Chainlink   LINK  2017-09-23 23:59:59   0.1574   0.1263
# 3                 4  Chainlink   LINK  2017-09-24 23:59:59   0.1902   0.1303
# 4                 5  Chainlink   LINK  2017-09-25 23:59:59   0.1826   0.1586
# ...             ...        ...    ...                  ...      ...      ...
# 1380           1381  Chainlink   LINK  2021-07-02 23:59:59  18.5203  17.3055
# 1381           1382  Chainlink   LINK  2021-07-03 23:59:59  18.8860  17.8981
# 1382           1383  Chainlink   LINK  2021-07-04 23:59:59  19.8945  18.0290
# 1383           1384  Chainlink   LINK  2021-07-05 23:59:59  19.2469  17.8148
# 1384           1385  Chainlink   LINK  2021-07-06 23:59:59  20.2410  18.3519
#
# ...

# %% [markdown]
# ##Filtrando dados de 2013

# %%
df['Date'] = pd.to_datetime(df['Date'])

df_2013 = df[df['Date'].dt.year == 2013]

print(df_2013)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ##Filtrando dados de 2020 para frente
# Esse é o que vamos usar para trabalhar

# %%
start_date = pd.to_datetime('2020-01-01')

df_from_2020 = df[df['Date'] >= start_date]

print(df_from_2020)

from google.colab import files

filtered_file_path = '/content/'
df_from_2020.to_csv("filtered_file_path", index=False)
# Out:
#       serial_number       Name Symbol                Date     High      Low  \
# 832             833  Chainlink   LINK 2020-01-01 23:59:59   1.8514   1.7634
# 833             834  Chainlink   LINK 2020-01-02 23:59:59   1.8169   1.7217
# 834             835  Chainlink   LINK 2020-01-03 23:59:59   1.8265   1.7126
# 835             836  Chainlink   LINK 2020-01-04 23:59:59   1.8511   1.7897
# 836             837  Chainlink   LINK 2020-01-05 23:59:59   1.8552   1.8037
# ...             ...        ...    ...                 ...      ...      ...
# 1380           1381  Chainlink   LINK 2021-07-02 23:59:59  18.5203  17.3055
# 1381           1382  Chainlink   LINK 2021-07-03 23:59:59  18.8860  17.8981
# 1382           1383  Chainlink   LINK 2021-07-04 23:59:59  19.8945  18.0290
# 1383           1384  Chainlink   LINK 2021-07-05 23:59:59  19.2469  17.8148
# 1384           1385  Chainlink   LINK 2021-07-06 23:59:59  20.2410  18.3519
#
#          Open    Close        Volume     Marketcap
# ...

# %% [markdown]
# ##O que foi feito
# Perguntas para verificar se a planilha está realmente limpa e útil:
#
#     Esses dados fazem sentido?
#         Sim, estou removendo todos os dados que não serão úteis, seja por serem duplicados, nulos ou não totalmente preenchidos. Essa planilha será comparada com eventos filtrados por ano e comparada com outras moedas referentes ao mesmo período.
#
#     Os dados seguem o padrão certo?
#         Sim, os dados foram convertidos, corrigidos e arredondados.
#
#     Prova alguma teoria, suspeita ou traz algum insight?
#         Sim, com esses dados posso analisar a relação entre as moedas e o mundo real.
#
#     Você consegue identificar tendências ou padrões com esses dados?
#         Sim, consigo observar médias, padrões e usar gráficos para extrair informações sobre como a moeda reagiu e como outras moedas reagiram. Posso comparar acontecimentos e observar seu impacto na moeda, além de calcular médias anuais.
#
#     Se não está conseguindo identificar tendências, seria por causa de algum problema na planilha?
#         Não se aplica.

# %% [markdown]
# #Limpando os dados da moeda Tron
# Vídeo usado: https://youtu.be/iaZQF8SLHJs
#
# OBS: Você pode costumizar seu delimitador

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/
# 1389           1390  TRON    TRX  2021-07-04 23:59:59  0.068182  0.065113
# 1390           1391  TRON    TRX  2021-07-05 23:59:59  0.067344  0.063691
# 1391           1392  TRON    TRX  2021-07-06 23:59:59  0.066369  0.064010
#
#           Open     Close        Volume     Marketcap
# ...

# %% [markdown]
# ##Organizando os valores para o google sheets conseguir interpretar

# %% [markdown]
# ##Arredondando valores, ajeitando o sinal de float, convertendo tipos

# %%
df['High'] = df['High'].astype(str)
df['Low'] = df['Low'].astype(str)
df['Open'] = df['Open'].astype(str)
df['Close'] = df['Close'].astype(str)
df['Volume'] = df['Volume'].astype(str)


df['High'].str.replace(';', '')
df['Low'].str.replace(',', '.')
df['Open'].str.replace(',', '.')
df['Close'].str.replace(',', '.')
df['Volume'].str.replace(',', '.')

df['High'] = df['High'].astype(float).round(4)
df['Low'] = df['Low'].astype(float).round(4)
df['Open'] = df['Open'].astype(float).round(4)
df['Close'] = df['Close'].astype(float).round(4)
df['Volume'] = df['Volume'].astype(float).round(4)

df
# Out:
#       serial_number  Name Symbol                 Date    High     Low    Open  \
# 0                 1  TRON    TRX  2017-09-14 23:59:59  0.0025  0.0013  0.0020
# 1                 2  TRON    TRX  2017-09-15 23:59:59  0.0018  0.0011  0.0014
# 2                 3  TRON    TRX  2017-09-16 23:59:59  0.0177  0.0014  0.0018
# 3                 4  TRON    TRX  2017-09-17 23:59:59  0.0039  0.0018  0.0018
# 4                 5  TRON    TRX  2017-09-18 23:59:59  0.0034  0.0025  0.0033
# ...             ...   ...    ...                  ...     ...     ...     ...
# 1387           1388  TRON    TRX  2021-07-02 23:59:59  0.0666  0.0634  0.0648
# 1388           1389  TRON    TRX  2021-07-03 23:59:59  0.0673  0.0653  0.0666
# 1389           1390  TRON    TRX  2021-07-04 23:59:59  0.0682  0.0651  0.0668
# 1390           1391  TRON    TRX  2021-07-05 23:59:59  0.0673  0.0637  0.0673
# 1391           1392  TRON    TRX  2021-07-06 23:59:59  0.0664  0.0640  0.0645
#
# ...

# %% [markdown]
# ##Tirar campos nulos

# %%
null_rows = df[df.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ####Não tem dados nulos

# %% [markdown]
# ###Tirando todos os registros vazios no intervalo de dados

# %%
df.dropna()
df
# Out:
#       serial_number  Name Symbol                 Date    High     Low    Open  \
# 0                 1  TRON    TRX  2017-09-14 23:59:59  0.0025  0.0013  0.0020
# 1                 2  TRON    TRX  2017-09-15 23:59:59  0.0018  0.0011  0.0014
# 2                 3  TRON    TRX  2017-09-16 23:59:59  0.0177  0.0014  0.0018
# 3                 4  TRON    TRX  2017-09-17 23:59:59  0.0039  0.0018  0.0018
# 4                 5  TRON    TRX  2017-09-18 23:59:59  0.0034  0.0025  0.0033
# ...             ...   ...    ...                  ...     ...     ...     ...
# 1387           1388  TRON    TRX  2021-07-02 23:59:59  0.0666  0.0634  0.0648
# 1388           1389  TRON    TRX  2021-07-03 23:59:59  0.0673  0.0653  0.0666
# 1389           1390  TRON    TRX  2021-07-04 23:59:59  0.0682  0.0651  0.0668
# 1390           1391  TRON    TRX  2021-07-05 23:59:59  0.0673  0.0637  0.0673
# 1391           1392  TRON    TRX  2021-07-06 23:59:59  0.0664  0.0640  0.0645
#
# ...

# %% [markdown]
# ##Filtrando dados de 2013

# %%
df['Date'] = pd.to_datetime(df['Date'])

df_2013 = df[df['Date'].dt.year == 2013]

print(df_2013)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ##Filtrando dados de 2020 para frente
# Esse é o que vamos usar para trabalhar

# %%
start_date = pd.to_datetime('2020-01-01')

df_from_2020 = df[df['Date'] >= start_date]

print(df_from_2020)

from google.colab import files

filtered_file_path = '/content/'
df_from_2020.to_csv("chainlink_limpo.csv", index=False)
# Out:
#       serial_number  Name Symbol                Date    High     Low    Open  \
# 839             840  TRON    TRX 2020-01-01 23:59:59  0.0134  0.0132  0.0133
# 840             841  TRON    TRX 2020-01-02 23:59:59  0.0133  0.0128  0.0133
# 841             842  TRON    TRX 2020-01-03 23:59:59  0.0135  0.0128  0.0129
# 842             843  TRON    TRX 2020-01-04 23:59:59  0.0135  0.0133  0.0134
# 843             844  TRON    TRX 2020-01-05 23:59:59  0.0139  0.0135  0.0135
# ...             ...   ...    ...                 ...     ...     ...     ...
# 1387           1388  TRON    TRX 2021-07-02 23:59:59  0.0666  0.0634  0.0648
# 1388           1389  TRON    TRX 2021-07-03 23:59:59  0.0673  0.0653  0.0666
# 1389           1390  TRON    TRX 2021-07-04 23:59:59  0.0682  0.0651  0.0668
# 1390           1391  TRON    TRX 2021-07-05 23:59:59  0.0673  0.0637  0.0673
# 1391           1392  TRON    TRX 2021-07-06 23:59:59  0.0664  0.0640  0.0645
#
#        Close        Volume     Marketcap
# ...

# %% [markdown]
# ##O que foi feito
# Perguntas para verificar se a planilha está realmente limpa e útil:
#
#     Esses dados fazem sentido?
#         Sim, estou removendo todos os dados que não serão úteis, seja por serem duplicados, nulos ou não totalmente preenchidos. Essa planilha será comparada com eventos filtrados por ano e comparada com outras moedas referentes ao mesmo período.
#
#     Os dados seguem o padrão certo?
#         Sim, os dados foram convertidos, corrigidos e arredondados.
#
#     Prova alguma teoria, suspeita ou traz algum insight?
#         Sim, com esses dados posso analisar a relação entre as moedas e o mundo real.
#
#     Você consegue identificar tendências ou padrões com esses dados?
#         Sim, consigo observar médias, padrões e usar gráficos para extrair informações sobre como a moeda reagiu e como outras moedas reagiram. Posso comparar acontecimentos e observar seu impacto na moeda, além de calcular médias anuais.
#
#     Se não está conseguindo identificar tendências, seria por causa de algum problema na planilha?
#         Não se aplica.
