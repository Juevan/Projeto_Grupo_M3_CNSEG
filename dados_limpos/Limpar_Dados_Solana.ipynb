# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Juevan/Projeto_Grupo_M3_CNSEG/main/dados/coin_Solana.csv')
df.head(10)
# Out:
#    SNo    Name Symbol                 Date      High       Low      Open  \
# 0    1  Solana    SOL  2020-04-11 23:59:59  1.049073  0.765020  0.951054
# 1    2  Solana    SOL  2020-04-12 23:59:59  0.956670  0.762426  0.785448
# 2    3  Solana    SOL  2020-04-13 23:59:59  0.891603  0.773976  0.890760
# 3    4  Solana    SOL  2020-04-14 23:59:59  0.796472  0.628169  0.777832
# 4    5  Solana    SOL  2020-04-15 23:59:59  0.704964  0.621531  0.669289
# 5    6  Solana    SOL  2020-04-16 23:59:59  0.774192  0.625107  0.630879
# 6    7  Solana    SOL  2020-04-17 23:59:59  0.719614  0.660728  0.689312
# 7    8  Solana    SOL  2020-04-18 23:59:59  0.717618  0.659427  0.660728
# 8    9  Solana    SOL  2020-04-19 23:59:59  0.684641  0.598487  0.681516
# 9   10  Solana    SOL  2020-04-20 23:59:59  0.639254  0.520578  0.612948
#
#       Close        Volume  Marketcap
# 0  0.776819  4.386244e+07        0.0
# 1  0.882507  3.873690e+07        0.0
# 2  0.777832  1.821129e+07        0.0
# 3  0.661925  1.674761e+07        0.0
# 4  0.646651  1.307528e+07        0.0
# 5  0.690816  2.134603e+07        0.0
# 6  0.660728  9.870810e+06        0.0
# 7  0.681096  9.782112e+06        0.0
# 8  0.606969  9.289670e+06        0.0
# 9  0.538812  8.342616e+06        0.0

# %%
df = df.rename(columns={'SNo': 'serial_number'})
df.head()
# Out:
#    serial_number    Name Symbol                 Date      High       Low  \
# 0              1  Solana    SOL  2020-04-11 23:59:59  1.049073  0.765020
# 1              2  Solana    SOL  2020-04-12 23:59:59  0.956670  0.762426
# 2              3  Solana    SOL  2020-04-13 23:59:59  0.891603  0.773976
# 3              4  Solana    SOL  2020-04-14 23:59:59  0.796472  0.628169
# 4              5  Solana    SOL  2020-04-15 23:59:59  0.704964  0.621531
#
#        Open     Close        Volume  Marketcap
# 0  0.951054  0.776819  4.386244e+07        0.0
# 1  0.785448  0.882507  3.873690e+07        0.0
# 2  0.890760  0.777832  1.821129e+07        0.0
# 3  0.777832  0.661925  1.674761e+07        0.0
# 4  0.669289  0.646651  1.307528e+07        0.0

# %%
df.isnull().any()
df
# Out:
#      serial_number    Name Symbol                 Date       High        Low  \
# 0                1  Solana    SOL  2020-04-11 23:59:59   1.049073   0.765020
# 1                2  Solana    SOL  2020-04-12 23:59:59   0.956670   0.762426
# 2                3  Solana    SOL  2020-04-13 23:59:59   0.891603   0.773976
# 3                4  Solana    SOL  2020-04-14 23:59:59   0.796472   0.628169
# 4                5  Solana    SOL  2020-04-15 23:59:59   0.704964   0.621531
# ..             ...     ...    ...                  ...        ...        ...
# 447            448  Solana    SOL  2021-07-02 23:59:59  34.031786  31.479924
# 448            449  Solana    SOL  2021-07-03 23:59:59  35.404770  33.298475
# 449            450  Solana    SOL  2021-07-04 23:59:59  35.502372  33.555737
# 450            451  Solana    SOL  2021-07-05 23:59:59  34.461824  32.482692
# 451            452  Solana    SOL  2021-07-06 23:59:59  34.978319  32.930307
#
#           Open      Close        Volume     Marketcap
# 0     0.951054   0.776819  4.386244e+07  0.000000e+00
# 1     0.785448   0.882507  3.873690e+07  0.000000e+00
# 2     0.890760   0.777832  1.821129e+07  0.000000e+00
# 3     0.777832   0.661925  1.674761e+07  0.000000e+00
# 4     0.669289   0.646651  1.307528e+07  0.000000e+00
# ..         ...        ...           ...           ...
# 447  33.306310  34.020482  4.402988e+08  9.275257e+09
# 448  34.015575  34.478816  3.270200e+08  9.400216e+09
# 449  34.495117  34.310601  3.034205e+08  9.354354e+09
# 450  34.282550  32.984588  3.138393e+08  8.992833e+09
# 451  32.930307  34.269140  3.653360e+08  9.343050e+09
#
# [452 rows x 10 columns]

# %%
df['Date'].unique()
df
# Out:
#      serial_number    Name Symbol                 Date       High        Low  \
# 0                1  Solana    SOL  2020-04-11 23:59:59   1.049073   0.765020
# 1                2  Solana    SOL  2020-04-12 23:59:59   0.956670   0.762426
# 2                3  Solana    SOL  2020-04-13 23:59:59   0.891603   0.773976
# 3                4  Solana    SOL  2020-04-14 23:59:59   0.796472   0.628169
# 4                5  Solana    SOL  2020-04-15 23:59:59   0.704964   0.621531
# ..             ...     ...    ...                  ...        ...        ...
# 447            448  Solana    SOL  2021-07-02 23:59:59  34.031786  31.479924
# 448            449  Solana    SOL  2021-07-03 23:59:59  35.404770  33.298475
# 449            450  Solana    SOL  2021-07-04 23:59:59  35.502372  33.555737
# 450            451  Solana    SOL  2021-07-05 23:59:59  34.461824  32.482692
# 451            452  Solana    SOL  2021-07-06 23:59:59  34.978319  32.930307
#
#           Open      Close        Volume     Marketcap
# 0     0.951054   0.776819  4.386244e+07  0.000000e+00
# 1     0.785448   0.882507  3.873690e+07  0.000000e+00
# 2     0.890760   0.777832  1.821129e+07  0.000000e+00
# 3     0.777832   0.661925  1.674761e+07  0.000000e+00
# 4     0.669289   0.646651  1.307528e+07  0.000000e+00
# ..         ...        ...           ...           ...
# 447  33.306310  34.020482  4.402988e+08  9.275257e+09
# 448  34.015575  34.478816  3.270200e+08  9.400216e+09
# 449  34.495117  34.310601  3.034205e+08  9.354354e+09
# 450  34.282550  32.984588  3.138393e+08  8.992833e+09
# 451  32.930307  34.269140  3.653360e+08  9.343050e+09
#
# [452 rows x 10 columns]

# %%
df_filtered = df[df['Date'].isna() == False]
df_filtered
# Out:
#      serial_number    Name Symbol                 Date       High        Low  \
# 0                1  Solana    SOL  2020-04-11 23:59:59   1.049073   0.765020
# 1                2  Solana    SOL  2020-04-12 23:59:59   0.956670   0.762426
# 2                3  Solana    SOL  2020-04-13 23:59:59   0.891603   0.773976
# 3                4  Solana    SOL  2020-04-14 23:59:59   0.796472   0.628169
# 4                5  Solana    SOL  2020-04-15 23:59:59   0.704964   0.621531
# ..             ...     ...    ...                  ...        ...        ...
# 447            448  Solana    SOL  2021-07-02 23:59:59  34.031786  31.479924
# 448            449  Solana    SOL  2021-07-03 23:59:59  35.404770  33.298475
# 449            450  Solana    SOL  2021-07-04 23:59:59  35.502372  33.555737
# 450            451  Solana    SOL  2021-07-05 23:59:59  34.461824  32.482692
# 451            452  Solana    SOL  2021-07-06 23:59:59  34.978319  32.930307
#
#           Open      Close        Volume     Marketcap
# 0     0.951054   0.776819  4.386244e+07  0.000000e+00
# 1     0.785448   0.882507  3.873690e+07  0.000000e+00
# 2     0.890760   0.777832  1.821129e+07  0.000000e+00
# 3     0.777832   0.661925  1.674761e+07  0.000000e+00
# 4     0.669289   0.646651  1.307528e+07  0.000000e+00
# ..         ...        ...           ...           ...
# 447  33.306310  34.020482  4.402988e+08  9.275257e+09
# 448  34.015575  34.478816  3.270200e+08  9.400216e+09
# 449  34.495117  34.310601  3.034205e+08  9.354354e+09
# 450  34.282550  32.984588  3.138393e+08  8.992833e+09
# 451  32.930307  34.269140  3.653360e+08  9.343050e+09
#
# [452 rows x 10 columns]

# %% [markdown]
# ###Localizar e filtrar duplicatas específicas

# %%
df.duplicated
df_filtered.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 447    False
# 448    False
# 449    False
# 450    False
# 451    False
# Length: 452, dtype: bool

# %% [markdown]
# #Localizando Duplicatas

# %%
df[df['Date'].duplicated() == 1]
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# #Excluindo as Duplicatas

# %%
df_sem_duplicatas = df.drop_duplicates()
df_sem_duplicatas
# Out:
#      serial_number    Name Symbol                 Date       High        Low  \
# 0                1  Solana    SOL  2020-04-11 23:59:59   1.049073   0.765020
# 1                2  Solana    SOL  2020-04-12 23:59:59   0.956670   0.762426
# 2                3  Solana    SOL  2020-04-13 23:59:59   0.891603   0.773976
# 3                4  Solana    SOL  2020-04-14 23:59:59   0.796472   0.628169
# 4                5  Solana    SOL  2020-04-15 23:59:59   0.704964   0.621531
# ..             ...     ...    ...                  ...        ...        ...
# 447            448  Solana    SOL  2021-07-02 23:59:59  34.031786  31.479924
# 448            449  Solana    SOL  2021-07-03 23:59:59  35.404770  33.298475
# 449            450  Solana    SOL  2021-07-04 23:59:59  35.502372  33.555737
# 450            451  Solana    SOL  2021-07-05 23:59:59  34.461824  32.482692
# 451            452  Solana    SOL  2021-07-06 23:59:59  34.978319  32.930307
#
#           Open      Close        Volume     Marketcap
# 0     0.951054   0.776819  4.386244e+07  0.000000e+00
# 1     0.785448   0.882507  3.873690e+07  0.000000e+00
# 2     0.890760   0.777832  1.821129e+07  0.000000e+00
# 3     0.777832   0.661925  1.674761e+07  0.000000e+00
# 4     0.669289   0.646651  1.307528e+07  0.000000e+00
# ..         ...        ...           ...           ...
# 447  33.306310  34.020482  4.402988e+08  9.275257e+09
# 448  34.015575  34.478816  3.270200e+08  9.400216e+09
# 449  34.495117  34.310601  3.034205e+08  9.354354e+09
# 450  34.282550  32.984588  3.138393e+08  8.992833e+09
# 451  32.930307  34.269140  3.653360e+08  9.343050e+09
#
# [452 rows x 10 columns]

# %% [markdown]
# ##Organizando os valores para o google sheets conseguir interpretar

# %% [markdown]
# ##Arredondando valores, ajeitando o sinal de float, convertendo tipos

# %%
df['High'] = df['High'].astype(str)
df['Low'] = df['Low'].astype(str)
df['Open'] = df['Open'].astype(str)
df['Close'] = df['Close'].astype(str)
df['Volume'] = df['Volume'].astype(str)


df['High'].str.replace(';', '')
df['Low'].str.replace(',', '.')
df['Open'].str.replace(',', '.')
df['Close'].str.replace(',', '.')
df['Volume'].str.replace(',', '.')

df['High'] = df['High'].astype(float).round(4)
df['Low'] = df['Low'].astype(float).round(4)
df['Open'] = df['Open'].astype(float).round(4)
df['Close'] = df['Close'].astype(float).round(4)
df['Volume'] = df['Volume'].astype(float).round(4)

df
# Out:
#      serial_number    Name Symbol                 Date     High      Low  \
# 0                1  Solana    SOL  2020-04-11 23:59:59   1.0491   0.7650
# 1                2  Solana    SOL  2020-04-12 23:59:59   0.9567   0.7624
# 2                3  Solana    SOL  2020-04-13 23:59:59   0.8916   0.7740
# 3                4  Solana    SOL  2020-04-14 23:59:59   0.7965   0.6282
# 4                5  Solana    SOL  2020-04-15 23:59:59   0.7050   0.6215
# ..             ...     ...    ...                  ...      ...      ...
# 447            448  Solana    SOL  2021-07-02 23:59:59  34.0318  31.4799
# 448            449  Solana    SOL  2021-07-03 23:59:59  35.4048  33.2985
# 449            450  Solana    SOL  2021-07-04 23:59:59  35.5024  33.5557
# 450            451  Solana    SOL  2021-07-05 23:59:59  34.4618  32.4827
# 451            452  Solana    SOL  2021-07-06 23:59:59  34.9783  32.9303
#
#         Open    Close        Volume     Marketcap
# 0     0.9511   0.7768  4.386244e+07  0.000000e+00
# 1     0.7854   0.8825  3.873690e+07  0.000000e+00
# 2     0.8908   0.7778  1.821129e+07  0.000000e+00
# 3     0.7778   0.6619  1.674761e+07  0.000000e+00
# 4     0.6693   0.6467  1.307528e+07  0.000000e+00
# ..       ...      ...           ...           ...
# 447  33.3063  34.0205  4.402988e+08  9.275257e+09
# 448  34.0156  34.4788  3.270200e+08  9.400216e+09
# 449  34.4951  34.3106  3.034205e+08  9.354354e+09
# 450  34.2826  32.9846  3.138393e+08  8.992833e+09
# 451  32.9303  34.2691  3.653360e+08  9.343050e+09
#
# [452 rows x 10 columns]

# %% [markdown]
# ##Tirar campos nulos

# %%
null_rows = df[df.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ####Não tem dados nulos

# %% [markdown]
# ###Tirando todos os registros vazios no intervalo de dados

# %%
df.dropna()
df
# Out:
#      serial_number    Name Symbol                 Date     High      Low  \
# 0                1  Solana    SOL  2020-04-11 23:59:59   1.0491   0.7650
# 1                2  Solana    SOL  2020-04-12 23:59:59   0.9567   0.7624
# 2                3  Solana    SOL  2020-04-13 23:59:59   0.8916   0.7740
# 3                4  Solana    SOL  2020-04-14 23:59:59   0.7965   0.6282
# 4                5  Solana    SOL  2020-04-15 23:59:59   0.7050   0.6215
# ..             ...     ...    ...                  ...      ...      ...
# 447            448  Solana    SOL  2021-07-02 23:59:59  34.0318  31.4799
# 448            449  Solana    SOL  2021-07-03 23:59:59  35.4048  33.2985
# 449            450  Solana    SOL  2021-07-04 23:59:59  35.5024  33.5557
# 450            451  Solana    SOL  2021-07-05 23:59:59  34.4618  32.4827
# 451            452  Solana    SOL  2021-07-06 23:59:59  34.9783  32.9303
#
#         Open    Close        Volume     Marketcap
# 0     0.9511   0.7768  4.386244e+07  0.000000e+00
# 1     0.7854   0.8825  3.873690e+07  0.000000e+00
# 2     0.8908   0.7778  1.821129e+07  0.000000e+00
# 3     0.7778   0.6619  1.674761e+07  0.000000e+00
# 4     0.6693   0.6467  1.307528e+07  0.000000e+00
# ..       ...      ...           ...           ...
# 447  33.3063  34.0205  4.402988e+08  9.275257e+09
# 448  34.0156  34.4788  3.270200e+08  9.400216e+09
# 449  34.4951  34.3106  3.034205e+08  9.354354e+09
# 450  34.2826  32.9846  3.138393e+08  8.992833e+09
# 451  32.9303  34.2691  3.653360e+08  9.343050e+09
#
# [452 rows x 10 columns]

# %% [markdown]
# ##Filtrando dados de 2013

# %%
df['Date'] = pd.to_datetime(df['Date'])

df_2013 = df[df['Date'].dt.year == 2013]

print(df_2013)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ##Filtrando dados de 2020 para frente
# Esse é o que vamos usar para trabalhar

# %%
start_date = pd.to_datetime('2020-01-01')

df_from_2020 = df[df['Date'] >= start_date]

print(df_from_2020)

from google.colab import files

filtered_file_path = '/content/'
df_from_2020.to_csv("filtered_file_path", index=False)
# Out:
#      serial_number    Name Symbol                Date     High      Low  \
# 0                1  Solana    SOL 2020-04-11 23:59:59   1.0491   0.7650
# 1                2  Solana    SOL 2020-04-12 23:59:59   0.9567   0.7624
# 2                3  Solana    SOL 2020-04-13 23:59:59   0.8916   0.7740
# 3                4  Solana    SOL 2020-04-14 23:59:59   0.7965   0.6282
# 4                5  Solana    SOL 2020-04-15 23:59:59   0.7050   0.6215
# ..             ...     ...    ...                 ...      ...      ...
# 447            448  Solana    SOL 2021-07-02 23:59:59  34.0318  31.4799
# 448            449  Solana    SOL 2021-07-03 23:59:59  35.4048  33.2985
# 449            450  Solana    SOL 2021-07-04 23:59:59  35.5024  33.5557
# 450            451  Solana    SOL 2021-07-05 23:59:59  34.4618  32.4827
# 451            452  Solana    SOL 2021-07-06 23:59:59  34.9783  32.9303
#
#         Open    Close        Volume     Marketcap
# 0     0.9511   0.7768  4.386244e+07  0.000000e+00
# 1     0.7854   0.8825  3.873690e+07  0.000000e+00
# 2     0.8908   0.7778  1.821129e+07  0.000000e+00
# 3     0.7778   0.6619  1.674761e+07  0.000000e+00
# 4     0.6693   0.6467  1.307528e+07  0.000000e+00
# ..       ...      ...           ...           ...
# 447  33.3063  34.0205  4.402988e+08  9.275257e+09
# 448  34.0156  34.4788  3.270200e+08  9.400216e+09
# 449  34.4951  34.3106  3.034205e+08  9.354354e+09
# 450  34.2826  32.9846  3.138393e+08  8.992833e+09
# 451  32.9303  34.2691  3.653360e+08  9.343050e+09
#
# [452 rows x 10 columns]

# %% [markdown]
# ##O que foi feito
# Perguntas para verificar se a planilha está realmente limpa e útil:
#
#     Esses dados fazem sentido?
#         Sim, estou removendo todos os dados que não serão úteis, seja por serem duplicados, nulos ou não totalmente preenchidos. Essa planilha será comparada com eventos filtrados por ano e comparada com outras moedas referentes ao mesmo período.
#
#     Os dados seguem o padrão certo?
#         Sim, os dados foram convertidos, corrigidos e arredondados.
#
#     Prova alguma teoria, suspeita ou traz algum insight?
#         Sim, com esses dados posso analisar a relação entre as moedas e o mundo real.
#
#     Você consegue identificar tendências ou padrões com esses dados?
#         Sim, consigo observar médias, padrões e usar gráficos para extrair informações sobre como a moeda reagiu e como outras moedas reagiram. Posso comparar acontecimentos e observar seu impacto na moeda, além de calcular médias anuais.
#
#     Se não está conseguindo identificar tendências, seria por causa de algum problema na planilha?
#         Não se aplica.
