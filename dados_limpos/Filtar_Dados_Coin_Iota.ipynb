# %% [markdown]
# #Limpando os dados da moeda Lota

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Juevan/Projeto_Grupo_M3_CNSEG/main/dados/coin_Iota.csv')
df.head(10)
# Out:
#    SNo  Name Symbol                 Date      High       Low      Open  \
# 0    1  IOTA  MIOTA  2017-06-14 23:59:59  0.606196  0.495745  0.592347
# 1    2  IOTA  MIOTA  2017-06-15 23:59:59  0.543165  0.300365  0.528284
# 2    3  IOTA  MIOTA  2017-06-16 23:59:59  0.448249  0.309852  0.353285
# 3    4  IOTA  MIOTA  2017-06-17 23:59:59  0.444205  0.414139  0.426762
# 4    5  IOTA  MIOTA  2017-06-18 23:59:59  0.426069  0.393790  0.420597
# 5    6  IOTA  MIOTA  2017-06-19 23:59:59  0.420990  0.388231  0.405456
# 6    7  IOTA  MIOTA  2017-06-20 23:59:59  0.422032  0.398649  0.414299
# 7    8  IOTA  MIOTA  2017-06-21 23:59:59  0.437340  0.405037  0.419439
# 8    9  IOTA  MIOTA  2017-06-22 23:59:59  0.427283  0.407261  0.413371
# 9   10  IOTA  MIOTA  2017-06-23 23:59:59  0.480910  0.408405  0.417769
#
#       Close      Volume     Marketcap
# 0  0.528916  14194900.0  1.470138e+09
# 1  0.363661  10300400.0  1.010807e+09
# 2  0.410757   6920690.0  1.141712e+09
# 3  0.419906   3100660.0  1.167141e+09
# 4  0.405862   2514450.0  1.128106e+09
# 5  0.412183   3543640.0  1.145675e+09
# 6  0.418494   3755470.0  1.163217e+09
# 7  0.413547   3999810.0  1.149466e+09
# 8  0.417742   2343320.0  1.161127e+09
# 9  0.480910   3768560.0  1.336704e+09

# %%
df = df.rename(columns={'SNo': 'serial_number'})
df.head()
# Out:
#    serial_number  Name Symbol                 Date      High       Low  \
# 0              1  IOTA  MIOTA  2017-06-14 23:59:59  0.606196  0.495745
# 1              2  IOTA  MIOTA  2017-06-15 23:59:59  0.543165  0.300365
# 2              3  IOTA  MIOTA  2017-06-16 23:59:59  0.448249  0.309852
# 3              4  IOTA  MIOTA  2017-06-17 23:59:59  0.444205  0.414139
# 4              5  IOTA  MIOTA  2017-06-18 23:59:59  0.426069  0.393790
#
#        Open     Close      Volume     Marketcap
# 0  0.592347  0.528916  14194900.0  1.470138e+09
# 1  0.528284  0.363661  10300400.0  1.010807e+09
# 2  0.353285  0.410757   6920690.0  1.141712e+09
# 3  0.426762  0.419906   3100660.0  1.167141e+09
# 4  0.420597  0.405862   2514450.0  1.128106e+09

# %%
df.isnull().any()
df
# Out:
#       serial_number  Name Symbol                 Date      High       Low  \
# 0                 1  IOTA  MIOTA  2017-06-14 23:59:59  0.606196  0.495745
# 1                 2  IOTA  MIOTA  2017-06-15 23:59:59  0.543165  0.300365
# 2                 3  IOTA  MIOTA  2017-06-16 23:59:59  0.448249  0.309852
# 3                 4  IOTA  MIOTA  2017-06-17 23:59:59  0.444205  0.414139
# 4                 5  IOTA  MIOTA  2017-06-18 23:59:59  0.426069  0.393790
# ...             ...   ...    ...                  ...       ...       ...
# 1479           1480  IOTA  MIOTA  2021-07-02 23:59:59  0.832226  0.763102
# 1480           1481  IOTA  MIOTA  2021-07-03 23:59:59  0.847473  0.799677
# 1481           1482  IOTA  MIOTA  2021-07-04 23:59:59  0.877730  0.797663
# 1482           1483  IOTA  MIOTA  2021-07-05 23:59:59  0.868300  0.810015
# 1483           1484  IOTA  MIOTA  2021-07-06 23:59:59  0.882165  0.820371
#
#           Open     Close       Volume     Marketcap
# 0     0.592347  0.528916  14194900.00  1.470138e+09
# 1     0.528284  0.363661  10300400.00  1.010807e+09
# 2     0.353285  0.410757   6920690.00  1.141712e+09
# 3     0.426762  0.419906   3100660.00  1.167141e+09
# 4     0.420597  0.405862   2514450.00  1.128106e+09
# ...        ...       ...          ...           ...
# 1479  0.802916  0.828754  33929219.23  2.303546e+09
# 1480  0.827826  0.829169  28133181.35  2.304699e+09
# 1481  0.830209  0.844145  37850311.04  2.346327e+09
# 1482  0.844715  0.820022  39787635.09  2.279275e+09
# 1483  0.820371  0.851735  38663873.89  2.367423e+09
#
# [1484 rows x 10 columns]

# %%
df['Date'].unique()
df
# Out:
#       serial_number  Name Symbol                 Date      High       Low  \
# 0                 1  IOTA  MIOTA  2017-06-14 23:59:59  0.606196  0.495745
# 1                 2  IOTA  MIOTA  2017-06-15 23:59:59  0.543165  0.300365
# 2                 3  IOTA  MIOTA  2017-06-16 23:59:59  0.448249  0.309852
# 3                 4  IOTA  MIOTA  2017-06-17 23:59:59  0.444205  0.414139
# 4                 5  IOTA  MIOTA  2017-06-18 23:59:59  0.426069  0.393790
# ...             ...   ...    ...                  ...       ...       ...
# 1479           1480  IOTA  MIOTA  2021-07-02 23:59:59  0.832226  0.763102
# 1480           1481  IOTA  MIOTA  2021-07-03 23:59:59  0.847473  0.799677
# 1481           1482  IOTA  MIOTA  2021-07-04 23:59:59  0.877730  0.797663
# 1482           1483  IOTA  MIOTA  2021-07-05 23:59:59  0.868300  0.810015
# 1483           1484  IOTA  MIOTA  2021-07-06 23:59:59  0.882165  0.820371
#
#           Open     Close       Volume     Marketcap
# 0     0.592347  0.528916  14194900.00  1.470138e+09
# 1     0.528284  0.363661  10300400.00  1.010807e+09
# 2     0.353285  0.410757   6920690.00  1.141712e+09
# 3     0.426762  0.419906   3100660.00  1.167141e+09
# 4     0.420597  0.405862   2514450.00  1.128106e+09
# ...        ...       ...          ...           ...
# 1479  0.802916  0.828754  33929219.23  2.303546e+09
# 1480  0.827826  0.829169  28133181.35  2.304699e+09
# 1481  0.830209  0.844145  37850311.04  2.346327e+09
# 1482  0.844715  0.820022  39787635.09  2.279275e+09
# 1483  0.820371  0.851735  38663873.89  2.367423e+09
#
# [1484 rows x 10 columns]

# %%
df_filtered = df[df['Date'].isna() == False]
df_filtered
# Out:
#       serial_number  Name Symbol                 Date      High       Low  \
# 0                 1  IOTA  MIOTA  2017-06-14 23:59:59  0.606196  0.495745
# 1                 2  IOTA  MIOTA  2017-06-15 23:59:59  0.543165  0.300365
# 2                 3  IOTA  MIOTA  2017-06-16 23:59:59  0.448249  0.309852
# 3                 4  IOTA  MIOTA  2017-06-17 23:59:59  0.444205  0.414139
# 4                 5  IOTA  MIOTA  2017-06-18 23:59:59  0.426069  0.393790
# ...             ...   ...    ...                  ...       ...       ...
# 1479           1480  IOTA  MIOTA  2021-07-02 23:59:59  0.832226  0.763102
# 1480           1481  IOTA  MIOTA  2021-07-03 23:59:59  0.847473  0.799677
# 1481           1482  IOTA  MIOTA  2021-07-04 23:59:59  0.877730  0.797663
# 1482           1483  IOTA  MIOTA  2021-07-05 23:59:59  0.868300  0.810015
# 1483           1484  IOTA  MIOTA  2021-07-06 23:59:59  0.882165  0.820371
#
#           Open     Close       Volume     Marketcap
# 0     0.592347  0.528916  14194900.00  1.470138e+09
# 1     0.528284  0.363661  10300400.00  1.010807e+09
# 2     0.353285  0.410757   6920690.00  1.141712e+09
# 3     0.426762  0.419906   3100660.00  1.167141e+09
# 4     0.420597  0.405862   2514450.00  1.128106e+09
# ...        ...       ...          ...           ...
# 1479  0.802916  0.828754  33929219.23  2.303546e+09
# 1480  0.827826  0.829169  28133181.35  2.304699e+09
# 1481  0.830209  0.844145  37850311.04  2.346327e+09
# 1482  0.844715  0.820022  39787635.09  2.279275e+09
# 1483  0.820371  0.851735  38663873.89  2.367423e+09
#
# [1484 rows x 10 columns]

# %% [markdown]
# ###Localizar e filtrar duplicatas específicas

# %%
df.duplicated
df_filtered.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1479    False
# 1480    False
# 1481    False
# 1482    False
# 1483    False
# Length: 1484, dtype: bool

# %% [markdown]
# #Localizando Duplicatas

# %%
df[df['Date'].duplicated() == 1]
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# #Excluindo as Duplicatas

# %%
df_sem_duplicatas = df.drop_duplicates()
df_sem_duplicatas
# Out:
#       serial_number  Name Symbol                 Date      High       Low  \
# 0                 1  IOTA  MIOTA  2017-06-14 23:59:59  0.606196  0.495745
# 1                 2  IOTA  MIOTA  2017-06-15 23:59:59  0.543165  0.300365
# 2                 3  IOTA  MIOTA  2017-06-16 23:59:59  0.448249  0.309852
# 3                 4  IOTA  MIOTA  2017-06-17 23:59:59  0.444205  0.414139
# 4                 5  IOTA  MIOTA  2017-06-18 23:59:59  0.426069  0.393790
# ...             ...   ...    ...                  ...       ...       ...
# 1479           1480  IOTA  MIOTA  2021-07-02 23:59:59  0.832226  0.763102
# 1480           1481  IOTA  MIOTA  2021-07-03 23:59:59  0.847473  0.799677
# 1481           1482  IOTA  MIOTA  2021-07-04 23:59:59  0.877730  0.797663
# 1482           1483  IOTA  MIOTA  2021-07-05 23:59:59  0.868300  0.810015
# 1483           1484  IOTA  MIOTA  2021-07-06 23:59:59  0.882165  0.820371
#
#           Open     Close       Volume     Marketcap
# 0     0.592347  0.528916  14194900.00  1.470138e+09
# 1     0.528284  0.363661  10300400.00  1.010807e+09
# 2     0.353285  0.410757   6920690.00  1.141712e+09
# 3     0.426762  0.419906   3100660.00  1.167141e+09
# 4     0.420597  0.405862   2514450.00  1.128106e+09
# ...        ...       ...          ...           ...
# 1479  0.802916  0.828754  33929219.23  2.303546e+09
# 1480  0.827826  0.829169  28133181.35  2.304699e+09
# 1481  0.830209  0.844145  37850311.04  2.346327e+09
# 1482  0.844715  0.820022  39787635.09  2.279275e+09
# 1483  0.820371  0.851735  38663873.89  2.367423e+09
#
# [1484 rows x 10 columns]

# %% [markdown]
# ##Organizando os valores para o google sheets conseguir interpretar

# %% [markdown]
# ##Arredondando valores, ajeitando o sinal de float, convertendo tipos

# %%
df['High'] = df['High'].astype(str)
df['Low'] = df['Low'].astype(str)
df['Open'] = df['Open'].astype(str)
df['Close'] = df['Close'].astype(str)
df['Volume'] = df['Volume'].astype(str)


df['High'].str.replace(';', '')
df['Low'].str.replace(',', '.')
df['Open'].str.replace(',', '.')
df['Close'].str.replace(',', '.')
df['Volume'].str.replace(',', '.')

df['High'] = df['High'].astype(float).round(4)
df['Low'] = df['Low'].astype(float).round(4)
df['Open'] = df['Open'].astype(float).round(4)
df['Close'] = df['Close'].astype(float).round(4)
df['Volume'] = df['Volume'].astype(float).round(4)

df
# Out:
#       serial_number  Name Symbol                 Date    High     Low    Open  \
# 0                 1  IOTA  MIOTA  2017-06-14 23:59:59  0.6062  0.4957  0.5923
# 1                 2  IOTA  MIOTA  2017-06-15 23:59:59  0.5432  0.3004  0.5283
# 2                 3  IOTA  MIOTA  2017-06-16 23:59:59  0.4482  0.3099  0.3533
# 3                 4  IOTA  MIOTA  2017-06-17 23:59:59  0.4442  0.4141  0.4268
# 4                 5  IOTA  MIOTA  2017-06-18 23:59:59  0.4261  0.3938  0.4206
# ...             ...   ...    ...                  ...     ...     ...     ...
# 1479           1480  IOTA  MIOTA  2021-07-02 23:59:59  0.8322  0.7631  0.8029
# 1480           1481  IOTA  MIOTA  2021-07-03 23:59:59  0.8475  0.7997  0.8278
# 1481           1482  IOTA  MIOTA  2021-07-04 23:59:59  0.8777  0.7977  0.8302
# 1482           1483  IOTA  MIOTA  2021-07-05 23:59:59  0.8683  0.8100  0.8447
# 1483           1484  IOTA  MIOTA  2021-07-06 23:59:59  0.8822  0.8204  0.8204
#
#        Close       Volume     Marketcap
# 0     0.5289  14194900.00  1.470138e+09
# 1     0.3637  10300400.00  1.010807e+09
# 2     0.4108   6920690.00  1.141712e+09
# 3     0.4199   3100660.00  1.167141e+09
# 4     0.4059   2514450.00  1.128106e+09
# ...      ...          ...           ...
# 1479  0.8288  33929219.23  2.303546e+09
# 1480  0.8292  28133181.35  2.304699e+09
# 1481  0.8441  37850311.04  2.346327e+09
# 1482  0.8200  39787635.09  2.279275e+09
# 1483  0.8517  38663873.89  2.367423e+09
#
# [1484 rows x 10 columns]

# %% [markdown]
# ##Tirar campos nulos

# %%
null_rows = df[df.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ####Não tem dados nulos

# %% [markdown]
# ###Tirando todos os registros vazios no intervalo de dados

# %%
df.dropna()
df
# Out:
#       serial_number  Name Symbol                 Date    High     Low    Open  \
# 0                 1  IOTA  MIOTA  2017-06-14 23:59:59  0.6062  0.4957  0.5923
# 1                 2  IOTA  MIOTA  2017-06-15 23:59:59  0.5432  0.3004  0.5283
# 2                 3  IOTA  MIOTA  2017-06-16 23:59:59  0.4482  0.3099  0.3533
# 3                 4  IOTA  MIOTA  2017-06-17 23:59:59  0.4442  0.4141  0.4268
# 4                 5  IOTA  MIOTA  2017-06-18 23:59:59  0.4261  0.3938  0.4206
# ...             ...   ...    ...                  ...     ...     ...     ...
# 1479           1480  IOTA  MIOTA  2021-07-02 23:59:59  0.8322  0.7631  0.8029
# 1480           1481  IOTA  MIOTA  2021-07-03 23:59:59  0.8475  0.7997  0.8278
# 1481           1482  IOTA  MIOTA  2021-07-04 23:59:59  0.8777  0.7977  0.8302
# 1482           1483  IOTA  MIOTA  2021-07-05 23:59:59  0.8683  0.8100  0.8447
# 1483           1484  IOTA  MIOTA  2021-07-06 23:59:59  0.8822  0.8204  0.8204
#
#        Close       Volume     Marketcap
# 0     0.5289  14194900.00  1.470138e+09
# 1     0.3637  10300400.00  1.010807e+09
# 2     0.4108   6920690.00  1.141712e+09
# 3     0.4199   3100660.00  1.167141e+09
# 4     0.4059   2514450.00  1.128106e+09
# ...      ...          ...           ...
# 1479  0.8288  33929219.23  2.303546e+09
# 1480  0.8292  28133181.35  2.304699e+09
# 1481  0.8441  37850311.04  2.346327e+09
# 1482  0.8200  39787635.09  2.279275e+09
# 1483  0.8517  38663873.89  2.367423e+09
#
# [1484 rows x 10 columns]

# %% [markdown]
# ##Filtrando dados de 2013

# %%
df['Date'] = pd.to_datetime(df['Date'])

df_2013 = df[df['Date'].dt.year == 2013]

print(df_2013)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ##Filtrando dados de 2020 para frente
# Esse é o que vamos usar para trabalhar

# %%
start_date = pd.to_datetime('2020-01-01')

df_from_2020 = df[df['Date'] >= start_date]

print(df_from_2020)

from google.colab import files

filtered_file_path = '/content/'
df_from_2020.to_csv("lota.csv", index=False)
# Out:
#       serial_number  Name Symbol                Date    High     Low    Open  \
# 931             932  IOTA  MIOTA 2020-01-01 23:59:59  0.1642  0.1591  0.1600
# 932             933  IOTA  MIOTA 2020-01-02 23:59:59  0.1615  0.1576  0.1611
# 933             934  IOTA  MIOTA 2020-01-03 23:59:59  0.1676  0.1561  0.1584
# 934             935  IOTA  MIOTA 2020-01-04 23:59:59  0.1747  0.1649  0.1670
# 935             936  IOTA  MIOTA 2020-01-05 23:59:59  0.1754  0.1690  0.1744
# ...             ...   ...    ...                 ...     ...     ...     ...
# 1479           1480  IOTA  MIOTA 2021-07-02 23:59:59  0.8322  0.7631  0.8029
# 1480           1481  IOTA  MIOTA 2021-07-03 23:59:59  0.8475  0.7997  0.8278
# 1481           1482  IOTA  MIOTA 2021-07-04 23:59:59  0.8777  0.7977  0.8302
# 1482           1483  IOTA  MIOTA 2021-07-05 23:59:59  0.8683  0.8100  0.8447
# 1483           1484  IOTA  MIOTA 2021-07-06 23:59:59  0.8822  0.8204  0.8204
#
#        Close        Volume     Marketcap
# 931   0.1611  3.981429e+06  4.476660e+08
# 932   0.1584  3.753023e+06  4.403778e+08
# 933   0.1669  4.989336e+06  4.637898e+08
# 934   0.1742  5.312939e+06  4.842296e+08
# 935   0.1730  5.642017e+06  4.809799e+08
# ...      ...           ...           ...
# 1479  0.8288  3.392922e+07  2.303546e+09
# 1480  0.8292  2.813318e+07  2.304699e+09
# 1481  0.8441  3.785031e+07  2.346327e+09
# 1482  0.8200  3.978764e+07  2.279275e+09
# 1483  0.8517  3.866387e+07  2.367423e+09
#
# [553 rows x 10 columns]
