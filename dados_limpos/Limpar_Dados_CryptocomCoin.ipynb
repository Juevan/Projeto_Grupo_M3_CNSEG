# %% [markdown]
# #Limpando os dados da moeda CryptocomCoin

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Juevan/Projeto_Grupo_M3_CNSEG/main/dados/coin_CryptocomCoin.csv')
df.head(10)
# Out:
#    SNo             Name Symbol                 Date      High       Low  \
# 0    1  Crypto.com Coin    CRO  2018-12-15 23:59:59  0.019845  0.016150
# 1    2  Crypto.com Coin    CRO  2018-12-16 23:59:59  0.017496  0.014127
# 2    3  Crypto.com Coin    CRO  2018-12-17 23:59:59  0.016723  0.011487
# 3    4  Crypto.com Coin    CRO  2018-12-18 23:59:59  0.017215  0.013553
# 4    5  Crypto.com Coin    CRO  2018-12-19 23:59:59  0.031509  0.015609
# 5    6  Crypto.com Coin    CRO  2018-12-20 23:59:59  0.034677  0.020722
# 6    7  Crypto.com Coin    CRO  2018-12-21 23:59:59  0.039854  0.031724
# 7    8  Crypto.com Coin    CRO  2018-12-22 23:59:59  0.034878  0.031585
# 8    9  Crypto.com Coin    CRO  2018-12-23 23:59:59  0.037290  0.030013
# 9   10  Crypto.com Coin    CRO  2018-12-24 23:59:59  0.032311  0.029606
#
#        Open     Close        Volume     Marketcap
# 0  0.019542  0.017243  9.897096e+05  0.000000e+00
# 1  0.017213  0.015301  7.171740e+05  0.000000e+00
# 2  0.015186  0.014448  6.156226e+05  1.547062e+07
# 3  0.014308  0.016260  7.644745e+05  1.785590e+07
# 4  0.016087  0.020790  1.025196e+06  2.340088e+07
# 5  0.020814  0.032447  1.591948e+06  3.741019e+07
# 6  0.032472  0.032816  2.941460e+06  3.873471e+07
# 7  0.032921  0.034737  1.786517e+06  4.195432e+07
# 8  0.034823  0.030401  1.624196e+06  3.755048e+07
# 9  0.030321  0.029606  1.520019e+06  3.737891e+07

# %%
df = df.rename(columns={'SNo': 'serial_number'})
df.head()
# Out:
#    serial_number             Name Symbol                 Date      High  \
# 0              1  Crypto.com Coin    CRO  2018-12-15 23:59:59  0.019845
# 1              2  Crypto.com Coin    CRO  2018-12-16 23:59:59  0.017496
# 2              3  Crypto.com Coin    CRO  2018-12-17 23:59:59  0.016723
# 3              4  Crypto.com Coin    CRO  2018-12-18 23:59:59  0.017215
# 4              5  Crypto.com Coin    CRO  2018-12-19 23:59:59  0.031509
#
#         Low      Open     Close        Volume     Marketcap
# 0  0.016150  0.019542  0.017243  9.897096e+05  0.000000e+00
# 1  0.014127  0.017213  0.015301  7.171740e+05  0.000000e+00
# 2  0.011487  0.015186  0.014448  6.156226e+05  1.547062e+07
# 3  0.013553  0.014308  0.016260  7.644745e+05  1.785590e+07
# 4  0.015609  0.016087  0.020790  1.025196e+06  2.340088e+07

# %%
df.isnull().any()
df
# Out:
#      serial_number             Name Symbol                 Date      High  \
# 0                1  Crypto.com Coin    CRO  2018-12-15 23:59:59  0.019845
# 1                2  Crypto.com Coin    CRO  2018-12-16 23:59:59  0.017496
# 2                3  Crypto.com Coin    CRO  2018-12-17 23:59:59  0.016723
# 3                4  Crypto.com Coin    CRO  2018-12-18 23:59:59  0.017215
# 4                5  Crypto.com Coin    CRO  2018-12-19 23:59:59  0.031509
# ..             ...              ...    ...                  ...       ...
# 930            931  Crypto.com Coin    CRO  2021-07-02 23:59:59  0.114202
# 931            932  Crypto.com Coin    CRO  2021-07-03 23:59:59  0.119593
# 932            933  Crypto.com Coin    CRO  2021-07-04 23:59:59  0.125262
# 933            934  Crypto.com Coin    CRO  2021-07-05 23:59:59  0.122467
# 934            935  Crypto.com Coin    CRO  2021-07-06 23:59:59  0.124989
#
#           Low      Open     Close        Volume     Marketcap
# 0    0.016150  0.019542  0.017243  9.897096e+05  0.000000e+00
# 1    0.014127  0.017213  0.015301  7.171740e+05  0.000000e+00
# 2    0.011487  0.015186  0.014448  6.156226e+05  1.547062e+07
# 3    0.013553  0.014308  0.016260  7.644745e+05  1.785590e+07
# 4    0.015609  0.016087  0.020790  1.025196e+06  2.340088e+07
# ..        ...       ...       ...           ...           ...
# 930  0.108968  0.112168  0.113914  4.495990e+07  2.877801e+09
# 931  0.112773  0.113903  0.118407  4.578038e+07  2.991307e+09
# 932  0.117165  0.118389  0.122427  4.174486e+07  3.092883e+09
# 933  0.113482  0.122467  0.115814  4.728913e+07  2.925805e+09
# 934  0.115725  0.115725  0.122856  1.520764e+08  3.103718e+09
#
# [935 rows x 10 columns]

# %%
df['Date'].unique()
df
# Out:
#      serial_number             Name Symbol                 Date      High  \
# 0                1  Crypto.com Coin    CRO  2018-12-15 23:59:59  0.019845
# 1                2  Crypto.com Coin    CRO  2018-12-16 23:59:59  0.017496
# 2                3  Crypto.com Coin    CRO  2018-12-17 23:59:59  0.016723
# 3                4  Crypto.com Coin    CRO  2018-12-18 23:59:59  0.017215
# 4                5  Crypto.com Coin    CRO  2018-12-19 23:59:59  0.031509
# ..             ...              ...    ...                  ...       ...
# 930            931  Crypto.com Coin    CRO  2021-07-02 23:59:59  0.114202
# 931            932  Crypto.com Coin    CRO  2021-07-03 23:59:59  0.119593
# 932            933  Crypto.com Coin    CRO  2021-07-04 23:59:59  0.125262
# 933            934  Crypto.com Coin    CRO  2021-07-05 23:59:59  0.122467
# 934            935  Crypto.com Coin    CRO  2021-07-06 23:59:59  0.124989
#
#           Low      Open     Close        Volume     Marketcap
# 0    0.016150  0.019542  0.017243  9.897096e+05  0.000000e+00
# 1    0.014127  0.017213  0.015301  7.171740e+05  0.000000e+00
# 2    0.011487  0.015186  0.014448  6.156226e+05  1.547062e+07
# 3    0.013553  0.014308  0.016260  7.644745e+05  1.785590e+07
# 4    0.015609  0.016087  0.020790  1.025196e+06  2.340088e+07
# ..        ...       ...       ...           ...           ...
# 930  0.108968  0.112168  0.113914  4.495990e+07  2.877801e+09
# 931  0.112773  0.113903  0.118407  4.578038e+07  2.991307e+09
# 932  0.117165  0.118389  0.122427  4.174486e+07  3.092883e+09
# 933  0.113482  0.122467  0.115814  4.728913e+07  2.925805e+09
# 934  0.115725  0.115725  0.122856  1.520764e+08  3.103718e+09
#
# [935 rows x 10 columns]

# %%
df_filtered = df[df['Date'].isna() == False]
df_filtered
# Out:
#      serial_number             Name Symbol                 Date      High  \
# 0                1  Crypto.com Coin    CRO  2018-12-15 23:59:59  0.019845
# 1                2  Crypto.com Coin    CRO  2018-12-16 23:59:59  0.017496
# 2                3  Crypto.com Coin    CRO  2018-12-17 23:59:59  0.016723
# 3                4  Crypto.com Coin    CRO  2018-12-18 23:59:59  0.017215
# 4                5  Crypto.com Coin    CRO  2018-12-19 23:59:59  0.031509
# ..             ...              ...    ...                  ...       ...
# 930            931  Crypto.com Coin    CRO  2021-07-02 23:59:59  0.114202
# 931            932  Crypto.com Coin    CRO  2021-07-03 23:59:59  0.119593
# 932            933  Crypto.com Coin    CRO  2021-07-04 23:59:59  0.125262
# 933            934  Crypto.com Coin    CRO  2021-07-05 23:59:59  0.122467
# 934            935  Crypto.com Coin    CRO  2021-07-06 23:59:59  0.124989
#
#           Low      Open     Close        Volume     Marketcap
# 0    0.016150  0.019542  0.017243  9.897096e+05  0.000000e+00
# 1    0.014127  0.017213  0.015301  7.171740e+05  0.000000e+00
# 2    0.011487  0.015186  0.014448  6.156226e+05  1.547062e+07
# 3    0.013553  0.014308  0.016260  7.644745e+05  1.785590e+07
# 4    0.015609  0.016087  0.020790  1.025196e+06  2.340088e+07
# ..        ...       ...       ...           ...           ...
# 930  0.108968  0.112168  0.113914  4.495990e+07  2.877801e+09
# 931  0.112773  0.113903  0.118407  4.578038e+07  2.991307e+09
# 932  0.117165  0.118389  0.122427  4.174486e+07  3.092883e+09
# 933  0.113482  0.122467  0.115814  4.728913e+07  2.925805e+09
# 934  0.115725  0.115725  0.122856  1.520764e+08  3.103718e+09
#
# [935 rows x 10 columns]

# %% [markdown]
# ###Localizar e filtrar duplicatas específicas

# %%
df.duplicated
df_filtered.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 930    False
# 931    False
# 932    False
# 933    False
# 934    False
# Length: 935, dtype: bool

# %% [markdown]
# #Localizando Duplicatas

# %%
df[df['Date'].duplicated() == 1]
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# #Excluindo as Duplicatas

# %%
df_sem_duplicatas = df.drop_duplicates()
df_sem_duplicatas
# Out:
#      serial_number             Name Symbol                 Date      High  \
# 0                1  Crypto.com Coin    CRO  2018-12-15 23:59:59  0.019845
# 1                2  Crypto.com Coin    CRO  2018-12-16 23:59:59  0.017496
# 2                3  Crypto.com Coin    CRO  2018-12-17 23:59:59  0.016723
# 3                4  Crypto.com Coin    CRO  2018-12-18 23:59:59  0.017215
# 4                5  Crypto.com Coin    CRO  2018-12-19 23:59:59  0.031509
# ..             ...              ...    ...                  ...       ...
# 930            931  Crypto.com Coin    CRO  2021-07-02 23:59:59  0.114202
# 931            932  Crypto.com Coin    CRO  2021-07-03 23:59:59  0.119593
# 932            933  Crypto.com Coin    CRO  2021-07-04 23:59:59  0.125262
# 933            934  Crypto.com Coin    CRO  2021-07-05 23:59:59  0.122467
# 934            935  Crypto.com Coin    CRO  2021-07-06 23:59:59  0.124989
#
#           Low      Open     Close        Volume     Marketcap
# 0    0.016150  0.019542  0.017243  9.897096e+05  0.000000e+00
# 1    0.014127  0.017213  0.015301  7.171740e+05  0.000000e+00
# 2    0.011487  0.015186  0.014448  6.156226e+05  1.547062e+07
# 3    0.013553  0.014308  0.016260  7.644745e+05  1.785590e+07
# 4    0.015609  0.016087  0.020790  1.025196e+06  2.340088e+07
# ..        ...       ...       ...           ...           ...
# 930  0.108968  0.112168  0.113914  4.495990e+07  2.877801e+09
# 931  0.112773  0.113903  0.118407  4.578038e+07  2.991307e+09
# 932  0.117165  0.118389  0.122427  4.174486e+07  3.092883e+09
# 933  0.113482  0.122467  0.115814  4.728913e+07  2.925805e+09
# 934  0.115725  0.115725  0.122856  1.520764e+08  3.103718e+09
#
# [935 rows x 10 columns]

# %% [markdown]
# ##Organizando os valores para o google sheets conseguir interpretar

# %% [markdown]
# ##Arredondando valores, ajeitando o sinal de float, convertendo tipos

# %%
df['High'] = df['High'].astype(str)
df['Low'] = df['Low'].astype(str)
df['Open'] = df['Open'].astype(str)
df['Close'] = df['Close'].astype(str)
df['Volume'] = df['Volume'].astype(str)


df['High'].str.replace(';', '')
df['Low'].str.replace(',', '.')
df['Open'].str.replace(',', '.')
df['Close'].str.replace(',', '.')
df['Volume'].str.replace(',', '.')

df['High'] = df['High'].astype(float).round(4)
df['Low'] = df['Low'].astype(float).round(4)
df['Open'] = df['Open'].astype(float).round(4)
df['Close'] = df['Close'].astype(float).round(4)
df['Volume'] = df['Volume'].astype(float).round(4)

df
# Out:
#      serial_number             Name Symbol                 Date    High  \
# 0                1  Crypto.com Coin    CRO  2018-12-15 23:59:59  0.0198
# 1                2  Crypto.com Coin    CRO  2018-12-16 23:59:59  0.0175
# 2                3  Crypto.com Coin    CRO  2018-12-17 23:59:59  0.0167
# 3                4  Crypto.com Coin    CRO  2018-12-18 23:59:59  0.0172
# 4                5  Crypto.com Coin    CRO  2018-12-19 23:59:59  0.0315
# ..             ...              ...    ...                  ...     ...
# 930            931  Crypto.com Coin    CRO  2021-07-02 23:59:59  0.1142
# 931            932  Crypto.com Coin    CRO  2021-07-03 23:59:59  0.1196
# 932            933  Crypto.com Coin    CRO  2021-07-04 23:59:59  0.1253
# 933            934  Crypto.com Coin    CRO  2021-07-05 23:59:59  0.1225
# 934            935  Crypto.com Coin    CRO  2021-07-06 23:59:59  0.1250
#
#         Low    Open   Close        Volume     Marketcap
# 0    0.0161  0.0195  0.0172  9.897096e+05  0.000000e+00
# 1    0.0141  0.0172  0.0153  7.171740e+05  0.000000e+00
# 2    0.0115  0.0152  0.0144  6.156226e+05  1.547062e+07
# 3    0.0136  0.0143  0.0163  7.644745e+05  1.785590e+07
# 4    0.0156  0.0161  0.0208  1.025196e+06  2.340088e+07
# ..      ...     ...     ...           ...           ...
# 930  0.1090  0.1122  0.1139  4.495990e+07  2.877801e+09
# 931  0.1128  0.1139  0.1184  4.578038e+07  2.991307e+09
# 932  0.1172  0.1184  0.1224  4.174486e+07  3.092883e+09
# 933  0.1135  0.1225  0.1158  4.728913e+07  2.925805e+09
# 934  0.1157  0.1157  0.1229  1.520764e+08  3.103718e+09
#
# [935 rows x 10 columns]

# %% [markdown]
# ##Tirar campos nulos

# %%
null_rows = df[df.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ####Não tem dados nulos

# %% [markdown]
# ###Tirando todos os registros vazios no intervalo de dados

# %%
df.dropna()
df
# Out:
#      serial_number             Name Symbol                 Date    High  \
# 0                1  Crypto.com Coin    CRO  2018-12-15 23:59:59  0.0198
# 1                2  Crypto.com Coin    CRO  2018-12-16 23:59:59  0.0175
# 2                3  Crypto.com Coin    CRO  2018-12-17 23:59:59  0.0167
# 3                4  Crypto.com Coin    CRO  2018-12-18 23:59:59  0.0172
# 4                5  Crypto.com Coin    CRO  2018-12-19 23:59:59  0.0315
# ..             ...              ...    ...                  ...     ...
# 930            931  Crypto.com Coin    CRO  2021-07-02 23:59:59  0.1142
# 931            932  Crypto.com Coin    CRO  2021-07-03 23:59:59  0.1196
# 932            933  Crypto.com Coin    CRO  2021-07-04 23:59:59  0.1253
# 933            934  Crypto.com Coin    CRO  2021-07-05 23:59:59  0.1225
# 934            935  Crypto.com Coin    CRO  2021-07-06 23:59:59  0.1250
#
#         Low    Open   Close        Volume     Marketcap
# 0    0.0161  0.0195  0.0172  9.897096e+05  0.000000e+00
# 1    0.0141  0.0172  0.0153  7.171740e+05  0.000000e+00
# 2    0.0115  0.0152  0.0144  6.156226e+05  1.547062e+07
# 3    0.0136  0.0143  0.0163  7.644745e+05  1.785590e+07
# 4    0.0156  0.0161  0.0208  1.025196e+06  2.340088e+07
# ..      ...     ...     ...           ...           ...
# 930  0.1090  0.1122  0.1139  4.495990e+07  2.877801e+09
# 931  0.1128  0.1139  0.1184  4.578038e+07  2.991307e+09
# 932  0.1172  0.1184  0.1224  4.174486e+07  3.092883e+09
# 933  0.1135  0.1225  0.1158  4.728913e+07  2.925805e+09
# 934  0.1157  0.1157  0.1229  1.520764e+08  3.103718e+09
#
# [935 rows x 10 columns]

# %% [markdown]
# ##Filtrando dados de 2013

# %%
df['Date'] = pd.to_datetime(df['Date'])

df_2013 = df[df['Date'].dt.year == 2013]

print(df_2013)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ##Filtrando dados de 2020 para frente
# Esse é o que vamos usar para trabalhar

# %%
start_date = pd.to_datetime('2020-01-01')

df_from_2020 = df[df['Date'] >= start_date]

print(df_from_2020)

from google.colab import files

filtered_file_path = '/content/'
df_from_2020.to_csv("cryptocomcoin.csv", index=False)
# Out:
#      serial_number             Name Symbol                Date    High  \
# 382            383  Crypto.com Coin    CRO 2020-01-01 23:59:59  0.0342
# 383            384  Crypto.com Coin    CRO 2020-01-02 23:59:59  0.0340
# 384            385  Crypto.com Coin    CRO 2020-01-03 23:59:59  0.0349
# 385            386  Crypto.com Coin    CRO 2020-01-04 23:59:59  0.0349
# 386            387  Crypto.com Coin    CRO 2020-01-05 23:59:59  0.0353
# ..             ...              ...    ...                 ...     ...
# 930            931  Crypto.com Coin    CRO 2021-07-02 23:59:59  0.1142
# 931            932  Crypto.com Coin    CRO 2021-07-03 23:59:59  0.1196
# 932            933  Crypto.com Coin    CRO 2021-07-04 23:59:59  0.1253
# 933            934  Crypto.com Coin    CRO 2021-07-05 23:59:59  0.1225
# 934            935  Crypto.com Coin    CRO 2021-07-06 23:59:59  0.1250
#
#         Low    Open   Close        Volume     Marketcap
# 382  0.0336  0.0336  0.0340  1.132957e+07  4.313447e+08
# 383  0.0326  0.0340  0.0329  1.023818e+07  4.186373e+08
# 384  0.0327  0.0330  0.0347  1.351701e+07  4.424314e+08
# 385  0.0342  0.0346  0.0347  9.840614e+06  4.434745e+08
# 386  0.0346  0.0348  0.0346  7.626233e+06  4.433343e+08
# ..      ...     ...     ...           ...           ...
# 930  0.1090  0.1122  0.1139  4.495990e+07  2.877801e+09
# 931  0.1128  0.1139  0.1184  4.578038e+07  2.991307e+09
# 932  0.1172  0.1184  0.1224  4.174486e+07  3.092883e+09
# 933  0.1135  0.1225  0.1158  4.728913e+07  2.925805e+09
# 934  0.1157  0.1157  0.1229  1.520764e+08  3.103718e+09
#
# [553 rows x 10 columns]

# %% [markdown]
# ##O que foi feito
# Perguntas para verificar se a planilha está realmente limpa e útil:
#
#     Esses dados fazem sentido?
#         Sim, estou removendo todos os dados que não serão úteis, seja por serem duplicados, nulos ou não totalmente preenchidos. Essa planilha será comparada com eventos filtrados por ano e comparada com outras moedas referentes ao mesmo período.
#
#     Os dados seguem o padrão certo?
#         Sim, os dados foram convertidos, corrigidos e arredondados.
#
#     Prova alguma teoria, suspeita ou traz algum insight?
#         Sim, com esses dados posso analisar a relação entre as moedas e o mundo real.
#
#     Você consegue identificar tendências ou padrões com esses dados?
#         Sim, consigo observar médias, padrões e usar gráficos para extrair informações sobre como a moeda reagiu e como outras moedas reagiram. Posso comparar acontecimentos e observar seu impacto na moeda, além de calcular médias anuais.
#
#     Se não está conseguindo identificar tendências, seria por causa de algum problema na planilha?
#         Não se aplica.
