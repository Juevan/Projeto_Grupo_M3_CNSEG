# %% [markdown]
# #Limpando os dados da moeda XRP
# Vídeo usado: https://youtu.be/iaZQF8SLHJs
#
# OBS: Você pode costumizar seu delimitador

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Juevan/Projeto_Grupo_M3_CNSEG/main/dados/coin_XRP.csv')
df.head(10)
# Out:
#    SNo Name Symbol                 Date      High       Low      Open  \
# 0    1  XRP    XRP  2013-08-05 23:59:59  0.005980  0.005613  0.005875
# 1    2  XRP    XRP  2013-08-06 23:59:59  0.005661  0.004629  0.005637
# 2    3  XRP    XRP  2013-08-07 23:59:59  0.004682  0.004333  0.004669
# 3    4  XRP    XRP  2013-08-08 23:59:59  0.004424  0.004175  0.004397
# 4    5  XRP    XRP  2013-08-09 23:59:59  0.004367  0.004253  0.004257
# 5    6  XRP    XRP  2013-08-10 23:59:59  0.004366  0.004279  0.004291
# 6    7  XRP    XRP  2013-08-11 23:59:59  0.004421  0.004300  0.004314
# 7    8  XRP    XRP  2013-08-12 23:59:59  0.004520  0.004359  0.004414
# 8    9  XRP    XRP  2013-08-13 23:59:59  0.004463  0.004171  0.004463
# 9   10  XRP    XRP  2013-08-14 23:59:59  0.004267  0.003785  0.004267
#
#       Close  Volume     Marketcap
# 0  0.005613     0.0  4.387916e+07
# 1  0.004680     0.0  3.659101e+07
# 2  0.004417     0.0  3.453412e+07
# 3  0.004254     0.0  3.325863e+07
# 4  0.004291     0.0  3.354750e+07
# 5  0.004314     0.0  3.372497e+07
# 6  0.004415     0.0  3.451849e+07
# 7  0.004449     0.0  3.477820e+07
# 8  0.004245     0.0  3.319030e+07
# 9  0.003788     0.0  2.961745e+07

# %%
df = df.rename(columns={'SNo': 'serial_number'})
df.head()
# Out:
#    serial_number Name Symbol                 Date      High       Low  \
# 0              1  XRP    XRP  2013-08-05 23:59:59  0.005980  0.005613
# 1              2  XRP    XRP  2013-08-06 23:59:59  0.005661  0.004629
# 2              3  XRP    XRP  2013-08-07 23:59:59  0.004682  0.004333
# 3              4  XRP    XRP  2013-08-08 23:59:59  0.004424  0.004175
# 4              5  XRP    XRP  2013-08-09 23:59:59  0.004367  0.004253
#
#        Open     Close  Volume     Marketcap
# 0  0.005875  0.005613     0.0  4.387916e+07
# 1  0.005637  0.004680     0.0  3.659101e+07
# 2  0.004669  0.004417     0.0  3.453412e+07
# 3  0.004397  0.004254     0.0  3.325863e+07
# 4  0.004257  0.004291     0.0  3.354750e+07

# %%
df.isnull().any()
df
# Out:
#       serial_number Name Symbol                 Date      High       Low  \
# 0                 1  XRP    XRP  2013-08-05 23:59:59  0.005980  0.005613
# 1                 2  XRP    XRP  2013-08-06 23:59:59  0.005661  0.004629
# 2                 3  XRP    XRP  2013-08-07 23:59:59  0.004682  0.004333
# 3                 4  XRP    XRP  2013-08-08 23:59:59  0.004424  0.004175
# 4                 5  XRP    XRP  2013-08-09 23:59:59  0.004367  0.004253
# ...             ...  ...    ...                  ...       ...       ...
# 2888           2889  XRP    XRP  2021-07-02 23:59:59  0.667287  0.634726
# 2889           2890  XRP    XRP  2021-07-03 23:59:59  0.683677  0.644653
# 2890           2891  XRP    XRP  2021-07-04 23:59:59  0.707783  0.665802
# 2891           2892  XRP    XRP  2021-07-05 23:59:59  0.695653  0.648492
# 2892           2893  XRP    XRP  2021-07-06 23:59:59  0.679923  0.652676
#
#           Open     Close        Volume     Marketcap
# 0     0.005875  0.005613  0.000000e+00  4.387916e+07
# 1     0.005637  0.004680  0.000000e+00  3.659101e+07
# 2     0.004669  0.004417  0.000000e+00  3.453412e+07
# 3     0.004397  0.004254  0.000000e+00  3.325863e+07
# 4     0.004257  0.004291  0.000000e+00  3.354750e+07
# ...        ...       ...           ...           ...
# 2888  0.659890  0.656763  2.061607e+09  3.030759e+10
# 2889  0.655639  0.672888  1.872820e+09  3.105172e+10
# 2890  0.673218  0.694945  1.885242e+09  3.206960e+10
# 2891  0.695653  0.654300  2.076373e+09  3.019395e+10
# 2892  0.653055  0.665402  1.938959e+09  3.072284e+10
#
# [2893 rows x 10 columns]

# %%
df['Date'].unique()
df
# Out:
#       serial_number Name Symbol                 Date      High       Low  \
# 0                 1  XRP    XRP  2013-08-05 23:59:59  0.005980  0.005613
# 1                 2  XRP    XRP  2013-08-06 23:59:59  0.005661  0.004629
# 2                 3  XRP    XRP  2013-08-07 23:59:59  0.004682  0.004333
# 3                 4  XRP    XRP  2013-08-08 23:59:59  0.004424  0.004175
# 4                 5  XRP    XRP  2013-08-09 23:59:59  0.004367  0.004253
# ...             ...  ...    ...                  ...       ...       ...
# 2888           2889  XRP    XRP  2021-07-02 23:59:59  0.667287  0.634726
# 2889           2890  XRP    XRP  2021-07-03 23:59:59  0.683677  0.644653
# 2890           2891  XRP    XRP  2021-07-04 23:59:59  0.707783  0.665802
# 2891           2892  XRP    XRP  2021-07-05 23:59:59  0.695653  0.648492
# 2892           2893  XRP    XRP  2021-07-06 23:59:59  0.679923  0.652676
#
#           Open     Close        Volume     Marketcap
# 0     0.005875  0.005613  0.000000e+00  4.387916e+07
# 1     0.005637  0.004680  0.000000e+00  3.659101e+07
# 2     0.004669  0.004417  0.000000e+00  3.453412e+07
# 3     0.004397  0.004254  0.000000e+00  3.325863e+07
# 4     0.004257  0.004291  0.000000e+00  3.354750e+07
# ...        ...       ...           ...           ...
# 2888  0.659890  0.656763  2.061607e+09  3.030759e+10
# 2889  0.655639  0.672888  1.872820e+09  3.105172e+10
# 2890  0.673218  0.694945  1.885242e+09  3.206960e+10
# 2891  0.695653  0.654300  2.076373e+09  3.019395e+10
# 2892  0.653055  0.665402  1.938959e+09  3.072284e+10
#
# [2893 rows x 10 columns]

# %%
df_filtered = df[df['Date'].isna() == False]
df_filtered
# Out:
#       serial_number Name Symbol                 Date      High       Low  \
# 0                 1  XRP    XRP  2013-08-05 23:59:59  0.005980  0.005613
# 1                 2  XRP    XRP  2013-08-06 23:59:59  0.005661  0.004629
# 2                 3  XRP    XRP  2013-08-07 23:59:59  0.004682  0.004333
# 3                 4  XRP    XRP  2013-08-08 23:59:59  0.004424  0.004175
# 4                 5  XRP    XRP  2013-08-09 23:59:59  0.004367  0.004253
# ...             ...  ...    ...                  ...       ...       ...
# 2888           2889  XRP    XRP  2021-07-02 23:59:59  0.667287  0.634726
# 2889           2890  XRP    XRP  2021-07-03 23:59:59  0.683677  0.644653
# 2890           2891  XRP    XRP  2021-07-04 23:59:59  0.707783  0.665802
# 2891           2892  XRP    XRP  2021-07-05 23:59:59  0.695653  0.648492
# 2892           2893  XRP    XRP  2021-07-06 23:59:59  0.679923  0.652676
#
#           Open     Close        Volume     Marketcap
# 0     0.005875  0.005613  0.000000e+00  4.387916e+07
# 1     0.005637  0.004680  0.000000e+00  3.659101e+07
# 2     0.004669  0.004417  0.000000e+00  3.453412e+07
# 3     0.004397  0.004254  0.000000e+00  3.325863e+07
# 4     0.004257  0.004291  0.000000e+00  3.354750e+07
# ...        ...       ...           ...           ...
# 2888  0.659890  0.656763  2.061607e+09  3.030759e+10
# 2889  0.655639  0.672888  1.872820e+09  3.105172e+10
# 2890  0.673218  0.694945  1.885242e+09  3.206960e+10
# 2891  0.695653  0.654300  2.076373e+09  3.019395e+10
# 2892  0.653055  0.665402  1.938959e+09  3.072284e+10
#
# [2893 rows x 10 columns]

# %% [markdown]
# ###Localizar e filtrar duplicatas específicas

# %%
df.duplicated
df_filtered.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2888    False
# 2889    False
# 2890    False
# 2891    False
# 2892    False
# Length: 2893, dtype: bool

# %% [markdown]
# #Localizando Duplicatas

# %%
df[df['Date'].duplicated() == 1]
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# #Excluindo as Duplicatas

# %%
df_sem_duplicatas = df.drop_duplicates()
df_sem_duplicatas
# Out:
#       serial_number Name Symbol                 Date      High       Low  \
# 0                 1  XRP    XRP  2013-08-05 23:59:59  0.005980  0.005613
# 1                 2  XRP    XRP  2013-08-06 23:59:59  0.005661  0.004629
# 2                 3  XRP    XRP  2013-08-07 23:59:59  0.004682  0.004333
# 3                 4  XRP    XRP  2013-08-08 23:59:59  0.004424  0.004175
# 4                 5  XRP    XRP  2013-08-09 23:59:59  0.004367  0.004253
# ...             ...  ...    ...                  ...       ...       ...
# 2888           2889  XRP    XRP  2021-07-02 23:59:59  0.667287  0.634726
# 2889           2890  XRP    XRP  2021-07-03 23:59:59  0.683677  0.644653
# 2890           2891  XRP    XRP  2021-07-04 23:59:59  0.707783  0.665802
# 2891           2892  XRP    XRP  2021-07-05 23:59:59  0.695653  0.648492
# 2892           2893  XRP    XRP  2021-07-06 23:59:59  0.679923  0.652676
#
#           Open     Close        Volume     Marketcap
# 0     0.005875  0.005613  0.000000e+00  4.387916e+07
# 1     0.005637  0.004680  0.000000e+00  3.659101e+07
# 2     0.004669  0.004417  0.000000e+00  3.453412e+07
# 3     0.004397  0.004254  0.000000e+00  3.325863e+07
# 4     0.004257  0.004291  0.000000e+00  3.354750e+07
# ...        ...       ...           ...           ...
# 2888  0.659890  0.656763  2.061607e+09  3.030759e+10
# 2889  0.655639  0.672888  1.872820e+09  3.105172e+10
# 2890  0.673218  0.694945  1.885242e+09  3.206960e+10
# 2891  0.695653  0.654300  2.076373e+09  3.019395e+10
# 2892  0.653055  0.665402  1.938959e+09  3.072284e+10
#
# [2893 rows x 10 columns]

# %% [markdown]
# ##Organizando os valores para o google sheets conseguir interpretar

# %% [markdown]
# ##Arredondando valores, ajeitando o sinal de float, convertendo tipos

# %%
df['High'] = df['High'].astype(str)
df['Low'] = df['Low'].astype(str)
df['Open'] = df['Open'].astype(str)
df['Close'] = df['Close'].astype(str)
df['Volume'] = df['Volume'].astype(str)


df['High'].str.replace(';', '')
df['Low'].str.replace(',', '.')
df['Open'].str.replace(',', '.')
df['Close'].str.replace(',', '.')
df['Volume'].str.replace(',', '.')

df['High'] = df['High'].astype(float).round(4)
df['Low'] = df['Low'].astype(float).round(4)
df['Open'] = df['Open'].astype(float).round(4)
df['Close'] = df['Close'].astype(float).round(4)
df['Volume'] = df['Volume'].astype(float).round(4)

df
# Out:
#       serial_number Name Symbol                 Date    High     Low    Open  \
# 0                 1  XRP    XRP  2013-08-05 23:59:59  0.0060  0.0056  0.0059
# 1                 2  XRP    XRP  2013-08-06 23:59:59  0.0057  0.0046  0.0056
# 2                 3  XRP    XRP  2013-08-07 23:59:59  0.0047  0.0043  0.0047
# 3                 4  XRP    XRP  2013-08-08 23:59:59  0.0044  0.0042  0.0044
# 4                 5  XRP    XRP  2013-08-09 23:59:59  0.0044  0.0043  0.0043
# ...             ...  ...    ...                  ...     ...     ...     ...
# 2888           2889  XRP    XRP  2021-07-02 23:59:59  0.6673  0.6347  0.6599
# 2889           2890  XRP    XRP  2021-07-03 23:59:59  0.6837  0.6447  0.6556
# 2890           2891  XRP    XRP  2021-07-04 23:59:59  0.7078  0.6658  0.6732
# 2891           2892  XRP    XRP  2021-07-05 23:59:59  0.6957  0.6485  0.6957
# 2892           2893  XRP    XRP  2021-07-06 23:59:59  0.6799  0.6527  0.6531
#
#        Close        Volume     Marketcap
# 0     0.0056  0.000000e+00  4.387916e+07
# 1     0.0047  0.000000e+00  3.659101e+07
# 2     0.0044  0.000000e+00  3.453412e+07
# 3     0.0043  0.000000e+00  3.325863e+07
# 4     0.0043  0.000000e+00  3.354750e+07
# ...      ...           ...           ...
# 2888  0.6568  2.061607e+09  3.030759e+10
# 2889  0.6729  1.872820e+09  3.105172e+10
# 2890  0.6949  1.885242e+09  3.206960e+10
# 2891  0.6543  2.076373e+09  3.019395e+10
# 2892  0.6654  1.938959e+09  3.072284e+10
#
# [2893 rows x 10 columns]

# %% [markdown]
# ##Tirar campos nulos

# %%
null_rows = df[df.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ####Não tem dados nulos

# %% [markdown]
# ###Tirando todos os registros vazios no intervalo de dados

# %%
df.dropna()
df
# Out:
#       serial_number Name Symbol                 Date    High     Low    Open  \
# 0                 1  XRP    XRP  2013-08-05 23:59:59  0.0060  0.0056  0.0059
# 1                 2  XRP    XRP  2013-08-06 23:59:59  0.0057  0.0046  0.0056
# 2                 3  XRP    XRP  2013-08-07 23:59:59  0.0047  0.0043  0.0047
# 3                 4  XRP    XRP  2013-08-08 23:59:59  0.0044  0.0042  0.0044
# 4                 5  XRP    XRP  2013-08-09 23:59:59  0.0044  0.0043  0.0043
# ...             ...  ...    ...                  ...     ...     ...     ...
# 2888           2889  XRP    XRP  2021-07-02 23:59:59  0.6673  0.6347  0.6599
# 2889           2890  XRP    XRP  2021-07-03 23:59:59  0.6837  0.6447  0.6556
# 2890           2891  XRP    XRP  2021-07-04 23:59:59  0.7078  0.6658  0.6732
# 2891           2892  XRP    XRP  2021-07-05 23:59:59  0.6957  0.6485  0.6957
# 2892           2893  XRP    XRP  2021-07-06 23:59:59  0.6799  0.6527  0.6531
#
#        Close        Volume     Marketcap
# 0     0.0056  0.000000e+00  4.387916e+07
# 1     0.0047  0.000000e+00  3.659101e+07
# 2     0.0044  0.000000e+00  3.453412e+07
# 3     0.0043  0.000000e+00  3.325863e+07
# 4     0.0043  0.000000e+00  3.354750e+07
# ...      ...           ...           ...
# 2888  0.6568  2.061607e+09  3.030759e+10
# 2889  0.6729  1.872820e+09  3.105172e+10
# 2890  0.6949  1.885242e+09  3.206960e+10
# 2891  0.6543  2.076373e+09  3.019395e+10
# 2892  0.6654  1.938959e+09  3.072284e+10
#
# [2893 rows x 10 columns]

# %% [markdown]
# ##Filtrando dados de 2013

# %%
df['Date'] = pd.to_datetime(df['Date'])

df_2013 = df[df['Date'].dt.year == 2013]

print(df_2013)
# Out:
#      serial_number Name Symbol                Date    High     Low    Open  \
# 0                1  XRP    XRP 2013-08-05 23:59:59  0.0060  0.0056  0.0059
# 1                2  XRP    XRP 2013-08-06 23:59:59  0.0057  0.0046  0.0056
# 2                3  XRP    XRP 2013-08-07 23:59:59  0.0047  0.0043  0.0047
# 3                4  XRP    XRP 2013-08-08 23:59:59  0.0044  0.0042  0.0044
# 4                5  XRP    XRP 2013-08-09 23:59:59  0.0044  0.0043  0.0043
# ..             ...  ...    ...                 ...     ...     ...     ...
# 144            145  XRP    XRP 2013-12-27 23:59:59  0.0271  0.0235  0.0244
# 145            146  XRP    XRP 2013-12-28 23:59:59  0.0281  0.0266  0.0276
# 146            147  XRP    XRP 2013-12-29 23:59:59  0.0275  0.0266  0.0273
# 147            148  XRP    XRP 2013-12-30 23:59:59  0.0278  0.0270  0.0271
# 148            149  XRP    XRP 2013-12-31 23:59:59  0.0277  0.0270  0.0277
#
#       Close       Volume     Marketcap
# 0    0.0056       0.0000  4.387916e+07
# 1    0.0047       0.0000  3.659101e+07
# 2    0.0044       0.0000  3.453412e+07
# 3    0.0043       0.0000  3.325863e+07
# 4    0.0043       0.0000  3.354750e+07
# ..      ...          ...           ...
# 144  0.0271  148422.0000  2.116741e+08
# 145  0.0273  143404.0000  2.134534e+08
# 146  0.0272   56771.6016  2.127842e+08
# 147  0.0275   72634.3984  2.146808e+08
# 148  0.0273   63620.6016  2.136637e+08
#
# [149 rows x 10 columns]

# %% [markdown]
# ##Filtrando dados de 2020 para frente
# Esse é o que vamos usar para trabalhar

# %%
start_date = pd.to_datetime('2020-01-01')

df_from_2020 = df[df['Date'] >= start_date]

print(df_from_2020)

from google.colab import files

filtered_file_path = '/content/'
df_from_2020.to_csv("XRP_limpo.csv", index=False)
# Out:
#       serial_number Name Symbol                Date    High     Low    Open  \
# 2340           2341  XRP    XRP 2020-01-01 23:59:59  0.1944  0.1921  0.1929
# 2341           2342  XRP    XRP 2020-01-02 23:59:59  0.1929  0.1869  0.1927
# 2342           2343  XRP    XRP 2020-01-03 23:59:59  0.1941  0.1858  0.1879
# 2343           2344  XRP    XRP 2020-01-04 23:59:59  0.1947  0.1918  0.1935
# 2344           2345  XRP    XRP 2020-01-05 23:59:59  0.1992  0.1939  0.1944
# ...             ...  ...    ...                 ...     ...     ...     ...
# 2888           2889  XRP    XRP 2021-07-02 23:59:59  0.6673  0.6347  0.6599
# 2889           2890  XRP    XRP 2021-07-03 23:59:59  0.6837  0.6447  0.6556
# 2890           2891  XRP    XRP 2021-07-04 23:59:59  0.7078  0.6658  0.6732
# 2891           2892  XRP    XRP 2021-07-05 23:59:59  0.6957  0.6485  0.6957
# 2892           2893  XRP    XRP 2021-07-06 23:59:59  0.6799  0.6527  0.6531
#
#        Close        Volume     Marketcap
# 2340  0.1927  1.041134e+09  8.349802e+09
# 2341  0.1880  1.085351e+09  8.149376e+09
# 2342  0.1935  1.270017e+09  8.386800e+09
# 2343  0.1944  9.993316e+08  8.422952e+09
# 2344  0.1955  1.168068e+09  8.474172e+09
# ...      ...           ...           ...
# 2888  0.6568  2.061607e+09  3.030759e+10
# 2889  0.6729  1.872820e+09  3.105172e+10
# 2890  0.6949  1.885242e+09  3.206960e+10
# 2891  0.6543  2.076373e+09  3.019395e+10
# 2892  0.6654  1.938959e+09  3.072284e+10
#
# [553 rows x 10 columns]

# %% [markdown]
# ##O que foi feito
# Perguntas para verificar se a planilha está realmente limpa e útil:
#
#     Esses dados fazem sentido?
#         Sim, estou removendo todos os dados que não serão úteis, seja por serem duplicados, nulos ou não totalmente preenchidos. Essa planilha será comparada com eventos filtrados por ano e comparada com outras moedas referentes ao mesmo período.
#
#     Os dados seguem o padrão certo?
#         Sim, os dados foram convertidos, corrigidos e arredondados.
#
#     Prova alguma teoria, suspeita ou traz algum insight?
#         Sim, com esses dados posso analisar a relação entre as moedas e o mundo real.
#
#     Você consegue identificar tendências ou padrões com esses dados?
#         Sim, consigo observar médias, padrões e usar gráficos para extrair informações sobre como a moeda reagiu e como outras moedas reagiram. Posso comparar acontecimentos e observar seu impacto na moeda, além de calcular médias anuais.
#
#     Se não está conseguindo identificar tendências, seria por causa de algum problema na planilha?
#         Não se aplica.
