# %% [markdown]
# #Limpando os dados da moeda EOS

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Juevan/Projeto_Grupo_M3_CNSEG/main/dados/coin_EOS.csv')
df.head(10)
# Out:
#    SNo Name Symbol                 Date     High       Low      Open    Close  \
# 0    1  EOS    EOS  2017-07-02 23:59:59  2.87751  0.822648  0.996521  2.71005
# 1    2  EOS    EOS  2017-07-03 23:59:59  5.39597  2.632310  2.717390  4.08664
# 2    3  EOS    EOS  2017-07-04 23:59:59  4.19124  2.933450  4.098010  3.37200
# 3    4  EOS    EOS  2017-07-05 23:59:59  3.52350  2.730130  3.356000  3.00323
# 4    5  EOS    EOS  2017-07-06 23:59:59  3.86747  3.007830  3.014260  3.36133
# 5    6  EOS    EOS  2017-07-07 23:59:59  3.35117  2.713240  3.351170  2.80111
# 6    7  EOS    EOS  2017-07-08 23:59:59  2.89696  2.085130  2.824680  2.58690
# 7    8  EOS    EOS  2017-07-09 23:59:59  2.69045  2.193780  2.600430  2.29223
# 8    9  EOS    EOS  2017-07-10 23:59:59  2.38841  1.722730  2.253080  1.83264
# 9   10  EOS    EOS  2017-07-11 23:59:59  1.82325  1.419030  1.785430  1.65582
#
#         Volume     Marketcap
# 0  320452000.0  0.000000e+00
# 1  414950016.0  6.549307e+08
# 2  218559008.0  5.501552e+08
# 3  124339000.0  5.006264e+08
# 4  177463008.0  5.683615e+08
# 5   96596496.0  4.811395e+08
# 6  151162000.0  4.893975e+08
# 7   87525104.0  4.726832e+08
# 8   79608800.0  3.819511e+08
# 9  111023000.0  3.484488e+08

# %%
df = df.rename(columns={'SNo': 'serial_number'})
df.head()
# Out:
#    serial_number Name Symbol                 Date     High       Low  \
# 0              1  EOS    EOS  2017-07-02 23:59:59  2.87751  0.822648
# 1              2  EOS    EOS  2017-07-03 23:59:59  5.39597  2.632310
# 2              3  EOS    EOS  2017-07-04 23:59:59  4.19124  2.933450
# 3              4  EOS    EOS  2017-07-05 23:59:59  3.52350  2.730130
# 4              5  EOS    EOS  2017-07-06 23:59:59  3.86747  3.007830
#
#        Open    Close       Volume     Marketcap
# 0  0.996521  2.71005  320452000.0  0.000000e+00
# 1  2.717390  4.08664  414950016.0  6.549307e+08
# 2  4.098010  3.37200  218559008.0  5.501552e+08
# 3  3.356000  3.00323  124339000.0  5.006264e+08
# 4  3.014260  3.36133  177463008.0  5.683615e+08

# %%
df.isnull().any()
df
# Out:
#       serial_number Name Symbol                 Date      High       Low  \
# 0                 1  EOS    EOS  2017-07-02 23:59:59  2.877510  0.822648
# 1                 2  EOS    EOS  2017-07-03 23:59:59  5.395970  2.632310
# 2                 3  EOS    EOS  2017-07-04 23:59:59  4.191240  2.933450
# 3                 4  EOS    EOS  2017-07-05 23:59:59  3.523500  2.730130
# 4                 5  EOS    EOS  2017-07-06 23:59:59  3.867470  3.007830
# ...             ...  ...    ...                  ...       ...       ...
# 1461           1462  EOS    EOS  2021-07-02 23:59:59  4.000508  3.751986
# 1462           1463  EOS    EOS  2021-07-03 23:59:59  4.060837  3.859586
# 1463           1464  EOS    EOS  2021-07-04 23:59:59  4.181861  3.952532
# 1464           1465  EOS    EOS  2021-07-05 23:59:59  4.061888  3.773130
# 1465           1466  EOS    EOS  2021-07-06 23:59:59  4.004299  3.797596
#
#           Open     Close        Volume     Marketcap
# 0     0.996521  2.710050  3.204520e+08  0.000000e+00
# 1     2.717390  4.086640  4.149500e+08  6.549307e+08
# 2     4.098010  3.372000  2.185590e+08  5.501552e+08
# 3     3.356000  3.003230  1.243390e+08  5.006264e+08
# 4     3.014260  3.361330  1.774630e+08  5.683615e+08
# ...        ...       ...           ...           ...
# 1461  3.930561  3.934325  1.014258e+09  3.756672e+09
# 1462  3.926595  4.046421  7.302703e+08  3.863820e+09
# 1463  4.048645  4.059930  8.086025e+08  3.876834e+09
# 1464  4.061888  3.819266  8.004033e+08  3.647131e+09
# 1465  3.814236  3.882325  6.967875e+08  3.707457e+09
#
# [1466 rows x 10 columns]

# %% [markdown]
# ###Localizar e filtrar duplicatas específicas

# %%
df.duplicated
df_filtered.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# 1465    False
# Length: 1466, dtype: bool

# %% [markdown]
# #Localizando Duplicatas

# %%
df[df['Date'].duplicated() == 1]
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# #Excluindo as Duplicatas

# %%
df_sem_duplicatas = df.drop_duplicates()
df_sem_duplicatas
# Out:
#       serial_number Name Symbol                 Date      High       Low  \
# 0                 1  EOS    EOS  2017-07-02 23:59:59  2.877510  0.822648
# 1                 2  EOS    EOS  2017-07-03 23:59:59  5.395970  2.632310
# 2                 3  EOS    EOS  2017-07-04 23:59:59  4.191240  2.933450
# 3                 4  EOS    EOS  2017-07-05 23:59:59  3.523500  2.730130
# 4                 5  EOS    EOS  2017-07-06 23:59:59  3.867470  3.007830
# ...             ...  ...    ...                  ...       ...       ...
# 1461           1462  EOS    EOS  2021-07-02 23:59:59  4.000508  3.751986
# 1462           1463  EOS    EOS  2021-07-03 23:59:59  4.060837  3.859586
# 1463           1464  EOS    EOS  2021-07-04 23:59:59  4.181861  3.952532
# 1464           1465  EOS    EOS  2021-07-05 23:59:59  4.061888  3.773130
# 1465           1466  EOS    EOS  2021-07-06 23:59:59  4.004299  3.797596
#
#           Open     Close        Volume     Marketcap
# 0     0.996521  2.710050  3.204520e+08  0.000000e+00
# 1     2.717390  4.086640  4.149500e+08  6.549307e+08
# 2     4.098010  3.372000  2.185590e+08  5.501552e+08
# 3     3.356000  3.003230  1.243390e+08  5.006264e+08
# 4     3.014260  3.361330  1.774630e+08  5.683615e+08
# ...        ...       ...           ...           ...
# 1461  3.930561  3.934325  1.014258e+09  3.756672e+09
# 1462  3.926595  4.046421  7.302703e+08  3.863820e+09
# 1463  4.048645  4.059930  8.086025e+08  3.876834e+09
# 1464  4.061888  3.819266  8.004033e+08  3.647131e+09
# 1465  3.814236  3.882325  6.967875e+08  3.707457e+09
#
# [1466 rows x 10 columns]

# %% [markdown]
# ##Organizando os valores para o google sheets conseguir interpretar

# %% [markdown]
# ##Arredondando valores, ajeitando o sinal de float, convertendo tipos

# %%
df['High'] = df['High'].astype(str)
df['Low'] = df['Low'].astype(str)
df['Open'] = df['Open'].astype(str)
df['Close'] = df['Close'].astype(str)
df['Volume'] = df['Volume'].astype(str)


df['High'].str.replace(';', '')
df['Low'].str.replace(',', '.')
df['Open'].str.replace(',', '.')
df['Close'].str.replace(',', '.')
df['Volume'].str.replace(',', '.')

df['High'] = df['High'].astype(float).round(4)
df['Low'] = df['Low'].astype(float).round(4)
df['Open'] = df['Open'].astype(float).round(4)
df['Close'] = df['Close'].astype(float).round(4)
df['Volume'] = df['Volume'].astype(float).round(4)

df
# Out:
#       serial_number Name Symbol                 Date    High     Low    Open  \
# 0                 1  EOS    EOS  2017-07-02 23:59:59  2.8775  0.8226  0.9965
# 1                 2  EOS    EOS  2017-07-03 23:59:59  5.3960  2.6323  2.7174
# 2                 3  EOS    EOS  2017-07-04 23:59:59  4.1912  2.9334  4.0980
# 3                 4  EOS    EOS  2017-07-05 23:59:59  3.5235  2.7301  3.3560
# 4                 5  EOS    EOS  2017-07-06 23:59:59  3.8675  3.0078  3.0143
# ...             ...  ...    ...                  ...     ...     ...     ...
# 1461           1462  EOS    EOS  2021-07-02 23:59:59  4.0005  3.7520  3.9306
# 1462           1463  EOS    EOS  2021-07-03 23:59:59  4.0608  3.8596  3.9266
# 1463           1464  EOS    EOS  2021-07-04 23:59:59  4.1819  3.9525  4.0486
# 1464           1465  EOS    EOS  2021-07-05 23:59:59  4.0619  3.7731  4.0619
# 1465           1466  EOS    EOS  2021-07-06 23:59:59  4.0043  3.7976  3.8142
#
#        Close        Volume     Marketcap
# 0     2.7101  3.204520e+08  0.000000e+00
# 1     4.0866  4.149500e+08  6.549307e+08
# 2     3.3720  2.185590e+08  5.501552e+08
# 3     3.0032  1.243390e+08  5.006264e+08
# 4     3.3613  1.774630e+08  5.683615e+08
# ...      ...           ...           ...
# 1461  3.9343  1.014258e+09  3.756672e+09
# 1462  4.0464  7.302703e+08  3.863820e+09
# 1463  4.0599  8.086025e+08  3.876834e+09
# 1464  3.8193  8.004033e+08  3.647131e+09
# 1465  3.8823  6.967875e+08  3.707457e+09
#
# [1466 rows x 10 columns]

# %% [markdown]
# ##Tirar campos nulos

# %%
null_rows = df[df.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ####Não tem dados nulos

# %% [markdown]
# ###Tirando todos os registros vazios no intervalo de dados

# %%
df.dropna()
df
# Out:
#       serial_number Name Symbol                 Date    High     Low    Open  \
# 0                 1  EOS    EOS  2017-07-02 23:59:59  2.8775  0.8226  0.9965
# 1                 2  EOS    EOS  2017-07-03 23:59:59  5.3960  2.6323  2.7174
# 2                 3  EOS    EOS  2017-07-04 23:59:59  4.1912  2.9334  4.0980
# 3                 4  EOS    EOS  2017-07-05 23:59:59  3.5235  2.7301  3.3560
# 4                 5  EOS    EOS  2017-07-06 23:59:59  3.8675  3.0078  3.0143
# ...             ...  ...    ...                  ...     ...     ...     ...
# 1461           1462  EOS    EOS  2021-07-02 23:59:59  4.0005  3.7520  3.9306
# 1462           1463  EOS    EOS  2021-07-03 23:59:59  4.0608  3.8596  3.9266
# 1463           1464  EOS    EOS  2021-07-04 23:59:59  4.1819  3.9525  4.0486
# 1464           1465  EOS    EOS  2021-07-05 23:59:59  4.0619  3.7731  4.0619
# 1465           1466  EOS    EOS  2021-07-06 23:59:59  4.0043  3.7976  3.8142
#
#        Close        Volume     Marketcap
# 0     2.7101  3.204520e+08  0.000000e+00
# 1     4.0866  4.149500e+08  6.549307e+08
# 2     3.3720  2.185590e+08  5.501552e+08
# 3     3.0032  1.243390e+08  5.006264e+08
# 4     3.3613  1.774630e+08  5.683615e+08
# ...      ...           ...           ...
# 1461  3.9343  1.014258e+09  3.756672e+09
# 1462  4.0464  7.302703e+08  3.863820e+09
# 1463  4.0599  8.086025e+08  3.876834e+09
# 1464  3.8193  8.004033e+08  3.647131e+09
# 1465  3.8823  6.967875e+08  3.707457e+09
#
# [1466 rows x 10 columns]

# %% [markdown]
# ##Filtrando dados de 2013

# %%
df['Date'] = pd.to_datetime(df['Date'])

df_2013 = df[df['Date'].dt.year == 2013]

print(df_2013)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ##Filtrando dados de 2020 para frente
# Esse é o que vamos usar para trabalhar

# %%
start_date = pd.to_datetime('2020-01-01')

df_from_2020 = df[df['Date'] >= start_date]

print(df_from_2020)

from google.colab import files

filtered_file_path = '/content/'
df_from_2020.to_csv("EOS_limpo.csv", index=False)
# Out:
#       serial_number Name Symbol                Date    High     Low    Open  \
# 913             914  EOS    EOS 2020-01-01 23:59:59  2.6314  2.5730  2.5799
# 914             915  EOS    EOS 2020-01-02 23:59:59  2.6078  2.4482  2.5978
# 915             916  EOS    EOS 2020-01-03 23:59:59  2.6588  2.4477  2.4690
# 916             917  EOS    EOS 2020-01-04 23:59:59  2.6727  2.6226  2.6372
# 917             918  EOS    EOS 2020-01-05 23:59:59  2.7828  2.6660  2.6664
# ...             ...  ...    ...                 ...     ...     ...     ...
# 1461           1462  EOS    EOS 2021-07-02 23:59:59  4.0005  3.7520  3.9306
# 1462           1463  EOS    EOS 2021-07-03 23:59:59  4.0608  3.8596  3.9266
# 1463           1464  EOS    EOS 2021-07-04 23:59:59  4.1819  3.9525  4.0486
# 1464           1465  EOS    EOS 2021-07-05 23:59:59  4.0619  3.7731  4.0619
# 1465           1466  EOS    EOS 2021-07-06 23:59:59  4.0043  3.7976  3.8142
#
#        Close        Volume     Marketcap
# 913   2.5972  1.430407e+09  2.459275e+09
# 914   2.4624  1.572602e+09  2.331925e+09
# 915   2.6377  2.170633e+09  2.498295e+09
# 916   2.6678  1.568801e+09  2.527254e+09
# 917   2.7016  1.993837e+09  2.559644e+09
# ...      ...           ...           ...
# 1461  3.9343  1.014258e+09  3.756672e+09
# 1462  4.0464  7.302703e+08  3.863820e+09
# 1463  4.0599  8.086025e+08  3.876834e+09
# 1464  3.8193  8.004033e+08  3.647131e+09
# 1465  3.8823  6.967875e+08  3.707457e+09
#
# [553 rows x 10 columns]

# %% [markdown]
# ##O que foi feito
# Perguntas para verificar se a planilha está realmente limpa e útil:
#
#     Esses dados fazem sentido?
#         Sim, estou removendo todos os dados que não serão úteis, seja por serem duplicados, nulos ou não totalmente preenchidos. Essa planilha será comparada com eventos filtrados por ano e comparada com outras moedas referentes ao mesmo período.
#
#     Os dados seguem o padrão certo?
#         Sim, os dados foram convertidos, corrigidos e arredondados.
#
#     Prova alguma teoria, suspeita ou traz algum insight?
#         Sim, com esses dados posso analisar a relação entre as moedas e o mundo real.
#
#     Você consegue identificar tendências ou padrões com esses dados?
#         Sim, consigo observar médias, padrões e usar gráficos para extrair informações sobre como a moeda reagiu e como outras moedas reagiram. Posso comparar acontecimentos e observar seu impacto na moeda, além de calcular médias anuais.
#
#     Se não está conseguindo identificar tendências, seria por causa de algum problema na planilha?
#         Não se aplica.
