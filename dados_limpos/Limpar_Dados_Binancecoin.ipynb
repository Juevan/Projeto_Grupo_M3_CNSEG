# %% [markdown]
# #Limpando os dados da moeda Binancecoin

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Juevan/Projeto_Grupo_M3_CNSEG/main/dados/coin_BinanceCoin.csv')
df.head(10)
# Out:
#    SNo          Name Symbol                 Date      High       Low  \
# 0    1  Binance Coin    BNB  2017-07-26 23:59:59  0.109013  0.099266
# 1    2  Binance Coin    BNB  2017-07-27 23:59:59  0.108479  0.100888
# 2    3  Binance Coin    BNB  2017-07-28 23:59:59  0.109019  0.101473
# 3    4  Binance Coin    BNB  2017-07-29 23:59:59  0.111264  0.101108
# 4    5  Binance Coin    BNB  2017-07-30 23:59:59  0.108138  0.103162
# 5    6  Binance Coin    BNB  2017-07-31 23:59:59  0.108349  0.101600
# 6    7  Binance Coin    BNB  2017-08-01 23:59:59  0.106266  0.096109
# 7    8  Binance Coin    BNB  2017-08-02 23:59:59  0.101211  0.097361
# 8    9  Binance Coin    BNB  2017-08-03 23:59:59  0.106978  0.099120
# 9   10  Binance Coin    BNB  2017-08-04 23:59:59  0.107756  0.102699
#
#        Open     Close    Volume   Marketcap
# 0  0.105893  0.105138  200395.0  10513800.0
# 1  0.105108  0.107737  344499.0  10773700.0
# 2  0.107632  0.104067  342568.0  10406700.0
# 3  0.104782  0.107811  340218.0  10781100.0
# 4  0.107935  0.106414  224261.0  10641400.0
# 5  0.106828  0.104250  240309.0  10425000.0
# 6  0.104595  0.099867  300413.0   9986680.0
# 7  0.099721  0.100452  256793.0  10045200.0
# 8  0.100328  0.106642  293008.0  10664200.0
# 9  0.106685  0.107494  287621.0  10749400.0

# %%
df = df.rename(columns={'SNo': 'serial_number'})
df.head()
# Out:
#    serial_number          Name Symbol                 Date      High  \
# 0              1  Binance Coin    BNB  2017-07-26 23:59:59  0.109013
# 1              2  Binance Coin    BNB  2017-07-27 23:59:59  0.108479
# 2              3  Binance Coin    BNB  2017-07-28 23:59:59  0.109019
# 3              4  Binance Coin    BNB  2017-07-29 23:59:59  0.111264
# 4              5  Binance Coin    BNB  2017-07-30 23:59:59  0.108138
#
#         Low      Open     Close    Volume   Marketcap
# 0  0.099266  0.105893  0.105138  200395.0  10513800.0
# 1  0.100888  0.105108  0.107737  344499.0  10773700.0
# 2  0.101473  0.107632  0.104067  342568.0  10406700.0
# 3  0.101108  0.104782  0.107811  340218.0  10781100.0
# 4  0.103162  0.107935  0.106414  224261.0  10641400.0

# %%
df.isnull().any()
df
# Out:
#       serial_number          Name Symbol                 Date        High  \
# 0                 1  Binance Coin    BNB  2017-07-26 23:59:59    0.109013
# 1                 2  Binance Coin    BNB  2017-07-27 23:59:59    0.108479
# 2                 3  Binance Coin    BNB  2017-07-28 23:59:59    0.109019
# 3                 4  Binance Coin    BNB  2017-07-29 23:59:59    0.111264
# 4                 5  Binance Coin    BNB  2017-07-30 23:59:59    0.108138
# ...             ...           ...    ...                  ...         ...
# 1437           1438  Binance Coin    BNB  2021-07-02 23:59:59  290.621683
# 1438           1439  Binance Coin    BNB  2021-07-03 23:59:59  302.605867
# 1439           1440  Binance Coin    BNB  2021-07-04 23:59:59  314.713019
# 1440           1441  Binance Coin    BNB  2021-07-05 23:59:59  307.684855
# 1441           1442  Binance Coin    BNB  2021-07-06 23:59:59  321.520965
#
#              Low        Open       Close        Volume     Marketcap
# 0       0.099266    0.105893    0.105138  2.003950e+05  1.051380e+07
# 1       0.100888    0.105108    0.107737  3.444990e+05  1.077370e+07
# 2       0.101473    0.107632    0.104067  3.425680e+05  1.040670e+07
# 3       0.101108    0.104782    0.107811  3.402180e+05  1.078110e+07
# 4       0.103162    0.107935    0.106414  2.242610e+05  1.064140e+07
# ...          ...         ...         ...           ...           ...
# 1437  277.350302  287.754456  287.423094  1.133633e+09  4.410016e+10
# 1438  283.434010  287.215592  298.237117  1.113777e+09  4.575938e+10
# 1439  292.787370  298.113557  307.732096  1.387396e+09  4.721623e+10
# 1440  293.523465  307.684855  302.377980  1.504870e+09  4.639473e+10
# 1441  302.195584  302.195584  320.934802  2.203265e+09  4.924196e+10
#
# [1442 rows x 10 columns]

# %%
df['Date'].unique()
df
# Out:
#       serial_number          Name Symbol                 Date        High  \
# 0                 1  Binance Coin    BNB  2017-07-26 23:59:59    0.109013
# 1                 2  Binance Coin    BNB  2017-07-27 23:59:59    0.108479
# 2                 3  Binance Coin    BNB  2017-07-28 23:59:59    0.109019
# 3                 4  Binance Coin    BNB  2017-07-29 23:59:59    0.111264
# 4                 5  Binance Coin    BNB  2017-07-30 23:59:59    0.108138
# ...             ...           ...    ...                  ...         ...
# 1437           1438  Binance Coin    BNB  2021-07-02 23:59:59  290.621683
# 1438           1439  Binance Coin    BNB  2021-07-03 23:59:59  302.605867
# 1439           1440  Binance Coin    BNB  2021-07-04 23:59:59  314.713019
# 1440           1441  Binance Coin    BNB  2021-07-05 23:59:59  307.684855
# 1441           1442  Binance Coin    BNB  2021-07-06 23:59:59  321.520965
#
#              Low        Open       Close        Volume     Marketcap
# 0       0.099266    0.105893    0.105138  2.003950e+05  1.051380e+07
# 1       0.100888    0.105108    0.107737  3.444990e+05  1.077370e+07
# 2       0.101473    0.107632    0.104067  3.425680e+05  1.040670e+07
# 3       0.101108    0.104782    0.107811  3.402180e+05  1.078110e+07
# 4       0.103162    0.107935    0.106414  2.242610e+05  1.064140e+07
# ...          ...         ...         ...           ...           ...
# 1437  277.350302  287.754456  287.423094  1.133633e+09  4.410016e+10
# 1438  283.434010  287.215592  298.237117  1.113777e+09  4.575938e+10
# 1439  292.787370  298.113557  307.732096  1.387396e+09  4.721623e+10
# 1440  293.523465  307.684855  302.377980  1.504870e+09  4.639473e+10
# 1441  302.195584  302.195584  320.934802  2.203265e+09  4.924196e+10
#
# [1442 rows x 10 columns]

# %%
df_filtered = df[df['Date'].isna() == False]
df_filtered
# Out:
#       serial_number          Name Symbol                 Date        High  \
# 0                 1  Binance Coin    BNB  2017-07-26 23:59:59    0.109013
# 1                 2  Binance Coin    BNB  2017-07-27 23:59:59    0.108479
# 2                 3  Binance Coin    BNB  2017-07-28 23:59:59    0.109019
# 3                 4  Binance Coin    BNB  2017-07-29 23:59:59    0.111264
# 4                 5  Binance Coin    BNB  2017-07-30 23:59:59    0.108138
# ...             ...           ...    ...                  ...         ...
# 1437           1438  Binance Coin    BNB  2021-07-02 23:59:59  290.621683
# 1438           1439  Binance Coin    BNB  2021-07-03 23:59:59  302.605867
# 1439           1440  Binance Coin    BNB  2021-07-04 23:59:59  314.713019
# 1440           1441  Binance Coin    BNB  2021-07-05 23:59:59  307.684855
# 1441           1442  Binance Coin    BNB  2021-07-06 23:59:59  321.520965
#
#              Low        Open       Close        Volume     Marketcap
# 0       0.099266    0.105893    0.105138  2.003950e+05  1.051380e+07
# 1       0.100888    0.105108    0.107737  3.444990e+05  1.077370e+07
# 2       0.101473    0.107632    0.104067  3.425680e+05  1.040670e+07
# 3       0.101108    0.104782    0.107811  3.402180e+05  1.078110e+07
# 4       0.103162    0.107935    0.106414  2.242610e+05  1.064140e+07
# ...          ...         ...         ...           ...           ...
# 1437  277.350302  287.754456  287.423094  1.133633e+09  4.410016e+10
# 1438  283.434010  287.215592  298.237117  1.113777e+09  4.575938e+10
# 1439  292.787370  298.113557  307.732096  1.387396e+09  4.721623e+10
# 1440  293.523465  307.684855  302.377980  1.504870e+09  4.639473e+10
# 1441  302.195584  302.195584  320.934802  2.203265e+09  4.924196e+10
#
# [1442 rows x 10 columns]

# %% [markdown]
# ###Localizar e filtrar duplicatas específicas

# %%
df.duplicated
df_filtered.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1437    False
# 1438    False
# 1439    False
# 1440    False
# 1441    False
# Length: 1442, dtype: bool

# %% [markdown]
# #Localizando Duplicatas

# %%
df[df['Date'].duplicated() == 1]
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# #Excluindo as Duplicatas

# %%
df_sem_duplicatas = df.drop_duplicates()
df_sem_duplicatas
# Out:
#       serial_number          Name Symbol                 Date        High  \
# 0                 1  Binance Coin    BNB  2017-07-26 23:59:59    0.109013
# 1                 2  Binance Coin    BNB  2017-07-27 23:59:59    0.108479
# 2                 3  Binance Coin    BNB  2017-07-28 23:59:59    0.109019
# 3                 4  Binance Coin    BNB  2017-07-29 23:59:59    0.111264
# 4                 5  Binance Coin    BNB  2017-07-30 23:59:59    0.108138
# ...             ...           ...    ...                  ...         ...
# 1437           1438  Binance Coin    BNB  2021-07-02 23:59:59  290.621683
# 1438           1439  Binance Coin    BNB  2021-07-03 23:59:59  302.605867
# 1439           1440  Binance Coin    BNB  2021-07-04 23:59:59  314.713019
# 1440           1441  Binance Coin    BNB  2021-07-05 23:59:59  307.684855
# 1441           1442  Binance Coin    BNB  2021-07-06 23:59:59  321.520965
#
#              Low        Open       Close        Volume     Marketcap
# 0       0.099266    0.105893    0.105138  2.003950e+05  1.051380e+07
# 1       0.100888    0.105108    0.107737  3.444990e+05  1.077370e+07
# 2       0.101473    0.107632    0.104067  3.425680e+05  1.040670e+07
# 3       0.101108    0.104782    0.107811  3.402180e+05  1.078110e+07
# 4       0.103162    0.107935    0.106414  2.242610e+05  1.064140e+07
# ...          ...         ...         ...           ...           ...
# 1437  277.350302  287.754456  287.423094  1.133633e+09  4.410016e+10
# 1438  283.434010  287.215592  298.237117  1.113777e+09  4.575938e+10
# 1439  292.787370  298.113557  307.732096  1.387396e+09  4.721623e+10
# 1440  293.523465  307.684855  302.377980  1.504870e+09  4.639473e+10
# 1441  302.195584  302.195584  320.934802  2.203265e+09  4.924196e+10
#
# [1442 rows x 10 columns]

# %% [markdown]
# ##Organizando os valores para o google sheets conseguir interpretar

# %% [markdown]
# ##Arredondando valores, ajeitando o sinal de float, convertendo tipos

# %%
df['High'] = df['High'].astype(str)
df['Low'] = df['Low'].astype(str)
df['Open'] = df['Open'].astype(str)
df['Close'] = df['Close'].astype(str)
df['Volume'] = df['Volume'].astype(str)


df['High'].str.replace(';', '')
df['Low'].str.replace(',', '.')
df['Open'].str.replace(',', '.')
df['Close'].str.replace(',', '.')
df['Volume'].str.replace(',', '.')

df['High'] = df['High'].astype(float).round(4)
df['Low'] = df['Low'].astype(float).round(4)
df['Open'] = df['Open'].astype(float).round(4)
df['Close'] = df['Close'].astype(float).round(4)
df['Volume'] = df['Volume'].astype(float).round(4)

df
# Out:
#       serial_number          Name Symbol                 Date      High  \
# 0                 1  Binance Coin    BNB  2017-07-26 23:59:59    0.1090
# 1                 2  Binance Coin    BNB  2017-07-27 23:59:59    0.1085
# 2                 3  Binance Coin    BNB  2017-07-28 23:59:59    0.1090
# 3                 4  Binance Coin    BNB  2017-07-29 23:59:59    0.1113
# 4                 5  Binance Coin    BNB  2017-07-30 23:59:59    0.1081
# ...             ...           ...    ...                  ...       ...
# 1437           1438  Binance Coin    BNB  2021-07-02 23:59:59  290.6217
# 1438           1439  Binance Coin    BNB  2021-07-03 23:59:59  302.6059
# 1439           1440  Binance Coin    BNB  2021-07-04 23:59:59  314.7130
# 1440           1441  Binance Coin    BNB  2021-07-05 23:59:59  307.6849
# 1441           1442  Binance Coin    BNB  2021-07-06 23:59:59  321.5210
#
#            Low      Open     Close        Volume     Marketcap
# 0       0.0993    0.1059    0.1051  2.003950e+05  1.051380e+07
# 1       0.1009    0.1051    0.1077  3.444990e+05  1.077370e+07
# 2       0.1015    0.1076    0.1041  3.425680e+05  1.040670e+07
# 3       0.1011    0.1048    0.1078  3.402180e+05  1.078110e+07
# 4       0.1032    0.1079    0.1064  2.242610e+05  1.064140e+07
# ...        ...       ...       ...           ...           ...
# 1437  277.3503  287.7545  287.4231  1.133633e+09  4.410016e+10
# 1438  283.4340  287.2156  298.2371  1.113777e+09  4.575938e+10
# 1439  292.7874  298.1136  307.7321  1.387396e+09  4.721623e+10
# 1440  293.5235  307.6849  302.3780  1.504870e+09  4.639473e+10
# 1441  302.1956  302.1956  320.9348  2.203265e+09  4.924196e+10
#
# [1442 rows x 10 columns]

# %% [markdown]
# ##Tirar campos nulos

# %%
null_rows = df[df.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ####Não tem dados nulos

# %% [markdown]
# ###Tirando todos os registros vazios no intervalo de dados

# %%
df.dropna()
df
# Out:
#       serial_number          Name Symbol                 Date      High  \
# 0                 1  Binance Coin    BNB  2017-07-26 23:59:59    0.1090
# 1                 2  Binance Coin    BNB  2017-07-27 23:59:59    0.1085
# 2                 3  Binance Coin    BNB  2017-07-28 23:59:59    0.1090
# 3                 4  Binance Coin    BNB  2017-07-29 23:59:59    0.1113
# 4                 5  Binance Coin    BNB  2017-07-30 23:59:59    0.1081
# ...             ...           ...    ...                  ...       ...
# 1437           1438  Binance Coin    BNB  2021-07-02 23:59:59  290.6217
# 1438           1439  Binance Coin    BNB  2021-07-03 23:59:59  302.6059
# 1439           1440  Binance Coin    BNB  2021-07-04 23:59:59  314.7130
# 1440           1441  Binance Coin    BNB  2021-07-05 23:59:59  307.6849
# 1441           1442  Binance Coin    BNB  2021-07-06 23:59:59  321.5210
#
#            Low      Open     Close        Volume     Marketcap
# 0       0.0993    0.1059    0.1051  2.003950e+05  1.051380e+07
# 1       0.1009    0.1051    0.1077  3.444990e+05  1.077370e+07
# 2       0.1015    0.1076    0.1041  3.425680e+05  1.040670e+07
# 3       0.1011    0.1048    0.1078  3.402180e+05  1.078110e+07
# 4       0.1032    0.1079    0.1064  2.242610e+05  1.064140e+07
# ...        ...       ...       ...           ...           ...
# 1437  277.3503  287.7545  287.4231  1.133633e+09  4.410016e+10
# 1438  283.4340  287.2156  298.2371  1.113777e+09  4.575938e+10
# 1439  292.7874  298.1136  307.7321  1.387396e+09  4.721623e+10
# 1440  293.5235  307.6849  302.3780  1.504870e+09  4.639473e+10
# 1441  302.1956  302.1956  320.9348  2.203265e+09  4.924196e+10
#
# [1442 rows x 10 columns]

# %% [markdown]
# ##Filtrando dados de 2013

# %%
df['Date'] = pd.to_datetime(df['Date'])

df_2013 = df[df['Date'].dt.year == 2013]

print(df_2013)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ##Filtrando dados de 2020 para frente
# Esse é o que vamos usar para trabalhar

# %%
start_date = pd.to_datetime('2020-01-01')

df_from_2020 = df[df['Date'] >= start_date]

print(df_from_2020)

from google.colab import files

filtered_file_path = '/content/'
df_from_2020.to_csv("binancecoin_limpo.csv", index=False)
# Out:
#       serial_number          Name Symbol                Date      High  \
# 889             890  Binance Coin    BNB 2020-01-01 23:59:59   13.8739
# 890             891  Binance Coin    BNB 2020-01-02 23:59:59   13.7155
# 891             892  Binance Coin    BNB 2020-01-03 23:59:59   13.7637
# 892             893  Binance Coin    BNB 2020-01-04 23:59:59   13.9219
# 893             894  Binance Coin    BNB 2020-01-05 23:59:59   14.4108
# ...             ...           ...    ...                 ...       ...
# 1437           1438  Binance Coin    BNB 2021-07-02 23:59:59  290.6217
# 1438           1439  Binance Coin    BNB 2021-07-03 23:59:59  302.6059
# 1439           1440  Binance Coin    BNB 2021-07-04 23:59:59  314.7130
# 1440           1441  Binance Coin    BNB 2021-07-05 23:59:59  307.6849
# 1441           1442  Binance Coin    BNB 2021-07-06 23:59:59  321.5210
#
#            Low      Open     Close        Volume     Marketcap
# 889    13.6549   13.7310   13.6891  1.729807e+08  2.129155e+09
# 890    12.9900   13.6981   13.0270  1.563764e+08  2.026178e+09
# 891    13.0126   13.0353   13.6605  1.736839e+08  2.124702e+09
# 892    13.5600   13.6674   13.8915  1.822304e+08  2.160640e+09
# 893    13.8865   13.8883   14.1110  2.025527e+08  2.194781e+09
# ...        ...       ...       ...           ...           ...
# 1437  277.3503  287.7545  287.4231  1.133633e+09  4.410016e+10
# 1438  283.4340  287.2156  298.2371  1.113777e+09  4.575938e+10
# 1439  292.7874  298.1136  307.7321  1.387396e+09  4.721623e+10
# 1440  293.5235  307.6849  302.3780  1.504870e+09  4.639473e+10
# 1441  302.1956  302.1956  320.9348  2.203265e+09  4.924196e+10
#
# [553 rows x 10 columns]

# %% [markdown]
# ##O que foi feito
# Perguntas para verificar se a planilha está realmente limpa e útil:
#
#     Esses dados fazem sentido?
#         Sim, estou removendo todos os dados que não serão úteis, seja por serem duplicados, nulos ou não totalmente preenchidos. Essa planilha será comparada com eventos filtrados por ano e comparada com outras moedas referentes ao mesmo período.
#
#     Os dados seguem o padrão certo?
#         Sim, os dados foram convertidos, corrigidos e arredondados.
#
#     Prova alguma teoria, suspeita ou traz algum insight?
#         Sim, com esses dados posso analisar a relação entre as moedas e o mundo real.
#
#     Você consegue identificar tendências ou padrões com esses dados?
#         Sim, consigo observar médias, padrões e usar gráficos para extrair informações sobre como a moeda reagiu e como outras moedas reagiram. Posso comparar acontecimentos e observar seu impacto na moeda, além de calcular médias anuais.
#
#     Se não está conseguindo identificar tendências, seria por causa de algum problema na planilha?
#         Não se aplica.
