# %% [markdown]
# #Limpando os dados da moeda Cosmos

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Juevan/Projeto_Grupo_M3_CNSEG/main/dados/coin_Cosmos.csv')
df.head(10)
# Out:
#    SNo    Name Symbol                 Date      High       Low      Open  \
# 0    1  Cosmos   ATOM  2019-03-15 23:59:59  7.715249  6.432468  6.633174
# 1    2  Cosmos   ATOM  2019-03-16 23:59:59  8.305615  6.694531  7.507990
# 2    3  Cosmos   ATOM  2019-03-17 23:59:59  7.357443  4.727895  7.357443
# 3    4  Cosmos   ATOM  2019-03-18 23:59:59  5.229982  4.828242  4.828242
# 4    5  Cosmos   ATOM  2019-03-19 23:59:59  5.206172  4.794501  5.099978
# 5    6  Cosmos   ATOM  2019-03-20 23:59:59  4.835415  3.871130  4.817675
# 6    7  Cosmos   ATOM  2019-03-21 23:59:59  4.421520  3.585871  4.421520
# 7    8  Cosmos   ATOM  2019-03-22 23:59:59  3.633278  3.285579  3.631108
# 8    9  Cosmos   ATOM  2019-03-23 23:59:59  3.533852  3.337097  3.506196
# 9   10  Cosmos   ATOM  2019-03-24 23:59:59  3.881491  3.428650  3.445452
#
#       Close        Volume  Marketcap
# 0  7.504351  6.057301e+06        0.0
# 1  7.383882  3.477393e+06        0.0
# 2  4.776164  2.653565e+06        0.0
# 3  5.110341  2.567201e+06        0.0
# 4  4.821883  3.891084e+06        0.0
# 5  4.381395  3.934421e+06        0.0
# 6  3.632948  3.901346e+06        0.0
# 7  3.498546  4.680808e+06        0.0
# 8  3.445516  4.409797e+06        0.0
# 9  3.765243  3.928803e+06        0.0

# %%
df = df.rename(columns={'SNo': 'serial_number'})
df.head()
# Out:
#    serial_number    Name Symbol                 Date      High       Low  \
# 0              1  Cosmos   ATOM  2019-03-15 23:59:59  7.715249  6.432468
# 1              2  Cosmos   ATOM  2019-03-16 23:59:59  8.305615  6.694531
# 2              3  Cosmos   ATOM  2019-03-17 23:59:59  7.357443  4.727895
# 3              4  Cosmos   ATOM  2019-03-18 23:59:59  5.229982  4.828242
# 4              5  Cosmos   ATOM  2019-03-19 23:59:59  5.206172  4.794501
#
#        Open     Close        Volume  Marketcap
# 0  6.633174  7.504351  6.057301e+06        0.0
# 1  7.507990  7.383882  3.477393e+06        0.0
# 2  7.357443  4.776164  2.653565e+06        0.0
# 3  4.828242  5.110341  2.567201e+06        0.0
# 4  5.099978  4.821883  3.891084e+06        0.0

# %%
df.isnull().any()
df
# Out:
#      serial_number    Name Symbol                 Date       High        Low  \
# 0                1  Cosmos   ATOM  2019-03-15 23:59:59   7.715249   6.432468
# 1                2  Cosmos   ATOM  2019-03-16 23:59:59   8.305615   6.694531
# 2                3  Cosmos   ATOM  2019-03-17 23:59:59   7.357443   4.727895
# 3                4  Cosmos   ATOM  2019-03-18 23:59:59   5.229982   4.828242
# 4                5  Cosmos   ATOM  2019-03-19 23:59:59   5.206172   4.794501
# ..             ...     ...    ...                  ...        ...        ...
# 840            841  Cosmos   ATOM  2021-07-02 23:59:59  11.764925  10.543935
# 841            842  Cosmos   ATOM  2021-07-03 23:59:59  12.198276  11.540298
# 842            843  Cosmos   ATOM  2021-07-04 23:59:59  12.433965  11.520693
# 843            844  Cosmos   ATOM  2021-07-05 23:59:59  13.968271  11.955753
# 844            845  Cosmos   ATOM  2021-07-06 23:59:59  14.020420  12.823983
#
#           Open      Close        Volume     Marketcap
# 0     6.633174   7.504351  6.057301e+06  0.000000e+00
# 1     7.507990   7.383882  3.477393e+06  0.000000e+00
# 2     7.357443   4.776164  2.653565e+06  0.000000e+00
# 3     4.828242   5.110341  2.567201e+06  0.000000e+00
# 4     5.099978   4.821883  3.891084e+06  0.000000e+00
# ..         ...        ...           ...           ...
# 840  11.048080  11.764925  1.891418e+08  2.559039e+09
# 841  11.791034  11.817927  1.551317e+08  2.571184e+09
# 842  11.799601  12.263548  1.449177e+08  2.668775e+09
# 843  12.320437  13.548475  4.489358e+08  2.949102e+09
# 844  13.558099  13.159371  2.537822e+08  2.865093e+09
#
# [845 rows x 10 columns]

# %%
df['Date'].unique()
df
# Out:
#      serial_number    Name Symbol                 Date       High        Low  \
# 0                1  Cosmos   ATOM  2019-03-15 23:59:59   7.715249   6.432468
# 1                2  Cosmos   ATOM  2019-03-16 23:59:59   8.305615   6.694531
# 2                3  Cosmos   ATOM  2019-03-17 23:59:59   7.357443   4.727895
# 3                4  Cosmos   ATOM  2019-03-18 23:59:59   5.229982   4.828242
# 4                5  Cosmos   ATOM  2019-03-19 23:59:59   5.206172   4.794501
# ..             ...     ...    ...                  ...        ...        ...
# 840            841  Cosmos   ATOM  2021-07-02 23:59:59  11.764925  10.543935
# 841            842  Cosmos   ATOM  2021-07-03 23:59:59  12.198276  11.540298
# 842            843  Cosmos   ATOM  2021-07-04 23:59:59  12.433965  11.520693
# 843            844  Cosmos   ATOM  2021-07-05 23:59:59  13.968271  11.955753
# 844            845  Cosmos   ATOM  2021-07-06 23:59:59  14.020420  12.823983
#
#           Open      Close        Volume     Marketcap
# 0     6.633174   7.504351  6.057301e+06  0.000000e+00
# 1     7.507990   7.383882  3.477393e+06  0.000000e+00
# 2     7.357443   4.776164  2.653565e+06  0.000000e+00
# 3     4.828242   5.110341  2.567201e+06  0.000000e+00
# 4     5.099978   4.821883  3.891084e+06  0.000000e+00
# ..         ...        ...           ...           ...
# 840  11.048080  11.764925  1.891418e+08  2.559039e+09
# 841  11.791034  11.817927  1.551317e+08  2.571184e+09
# 842  11.799601  12.263548  1.449177e+08  2.668775e+09
# 843  12.320437  13.548475  4.489358e+08  2.949102e+09
# 844  13.558099  13.159371  2.537822e+08  2.865093e+09
#
# [845 rows x 10 columns]

# %%
df_filtered = df[df['Date'].isna() == False]
df_filtered
# Out:
#      serial_number    Name Symbol                 Date       High        Low  \
# 0                1  Cosmos   ATOM  2019-03-15 23:59:59   7.715249   6.432468
# 1                2  Cosmos   ATOM  2019-03-16 23:59:59   8.305615   6.694531
# 2                3  Cosmos   ATOM  2019-03-17 23:59:59   7.357443   4.727895
# 3                4  Cosmos   ATOM  2019-03-18 23:59:59   5.229982   4.828242
# 4                5  Cosmos   ATOM  2019-03-19 23:59:59   5.206172   4.794501
# ..             ...     ...    ...                  ...        ...        ...
# 840            841  Cosmos   ATOM  2021-07-02 23:59:59  11.764925  10.543935
# 841            842  Cosmos   ATOM  2021-07-03 23:59:59  12.198276  11.540298
# 842            843  Cosmos   ATOM  2021-07-04 23:59:59  12.433965  11.520693
# 843            844  Cosmos   ATOM  2021-07-05 23:59:59  13.968271  11.955753
# 844            845  Cosmos   ATOM  2021-07-06 23:59:59  14.020420  12.823983
#
#           Open      Close        Volume     Marketcap
# 0     6.633174   7.504351  6.057301e+06  0.000000e+00
# 1     7.507990   7.383882  3.477393e+06  0.000000e+00
# 2     7.357443   4.776164  2.653565e+06  0.000000e+00
# 3     4.828242   5.110341  2.567201e+06  0.000000e+00
# 4     5.099978   4.821883  3.891084e+06  0.000000e+00
# ..         ...        ...           ...           ...
# 840  11.048080  11.764925  1.891418e+08  2.559039e+09
# 841  11.791034  11.817927  1.551317e+08  2.571184e+09
# 842  11.799601  12.263548  1.449177e+08  2.668775e+09
# 843  12.320437  13.548475  4.489358e+08  2.949102e+09
# 844  13.558099  13.159371  2.537822e+08  2.865093e+09
#
# [845 rows x 10 columns]

# %% [markdown]
# ###Localizar e filtrar duplicatas específicas

# %%
df.duplicated
df_filtered.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 840    False
# 841    False
# 842    False
# 843    False
# 844    False
# Length: 845, dtype: bool

# %% [markdown]
# #Localizando Duplicatas

# %%
df[df['Date'].duplicated() == 1]
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# #Excluindo as Duplicatas

# %%
df_sem_duplicatas = df.drop_duplicates()
df_sem_duplicatas
# Out:
#      serial_number    Name Symbol                 Date       High        Low  \
# 0                1  Cosmos   ATOM  2019-03-15 23:59:59   7.715249   6.432468
# 1                2  Cosmos   ATOM  2019-03-16 23:59:59   8.305615   6.694531
# 2                3  Cosmos   ATOM  2019-03-17 23:59:59   7.357443   4.727895
# 3                4  Cosmos   ATOM  2019-03-18 23:59:59   5.229982   4.828242
# 4                5  Cosmos   ATOM  2019-03-19 23:59:59   5.206172   4.794501
# ..             ...     ...    ...                  ...        ...        ...
# 840            841  Cosmos   ATOM  2021-07-02 23:59:59  11.764925  10.543935
# 841            842  Cosmos   ATOM  2021-07-03 23:59:59  12.198276  11.540298
# 842            843  Cosmos   ATOM  2021-07-04 23:59:59  12.433965  11.520693
# 843            844  Cosmos   ATOM  2021-07-05 23:59:59  13.968271  11.955753
# 844            845  Cosmos   ATOM  2021-07-06 23:59:59  14.020420  12.823983
#
#           Open      Close        Volume     Marketcap
# 0     6.633174   7.504351  6.057301e+06  0.000000e+00
# 1     7.507990   7.383882  3.477393e+06  0.000000e+00
# 2     7.357443   4.776164  2.653565e+06  0.000000e+00
# 3     4.828242   5.110341  2.567201e+06  0.000000e+00
# 4     5.099978   4.821883  3.891084e+06  0.000000e+00
# ..         ...        ...           ...           ...
# 840  11.048080  11.764925  1.891418e+08  2.559039e+09
# 841  11.791034  11.817927  1.551317e+08  2.571184e+09
# 842  11.799601  12.263548  1.449177e+08  2.668775e+09
# 843  12.320437  13.548475  4.489358e+08  2.949102e+09
# 844  13.558099  13.159371  2.537822e+08  2.865093e+09
#
# [845 rows x 10 columns]

# %% [markdown]
# ##Organizando os valores para o google sheets conseguir interpretar

# %% [markdown]
# ##Arredondando valores, ajeitando o sinal de float, convertendo tipos

# %%
df['High'] = df['High'].astype(str)
df['Low'] = df['Low'].astype(str)
df['Open'] = df['Open'].astype(str)
df['Close'] = df['Close'].astype(str)
df['Volume'] = df['Volume'].astype(str)


df['High'].str.replace(';', '')
df['Low'].str.replace(',', '.')
df['Open'].str.replace(',', '.')
df['Close'].str.replace(',', '.')
df['Volume'].str.replace(',', '.')

df['High'] = df['High'].astype(float).round(4)
df['Low'] = df['Low'].astype(float).round(4)
df['Open'] = df['Open'].astype(float).round(4)
df['Close'] = df['Close'].astype(float).round(4)
df['Volume'] = df['Volume'].astype(float).round(4)

df
# Out:
#      serial_number    Name Symbol                 Date     High      Low  \
# 0                1  Cosmos   ATOM  2019-03-15 23:59:59   7.7152   6.4325
# 1                2  Cosmos   ATOM  2019-03-16 23:59:59   8.3056   6.6945
# 2                3  Cosmos   ATOM  2019-03-17 23:59:59   7.3574   4.7279
# 3                4  Cosmos   ATOM  2019-03-18 23:59:59   5.2300   4.8282
# 4                5  Cosmos   ATOM  2019-03-19 23:59:59   5.2062   4.7945
# ..             ...     ...    ...                  ...      ...      ...
# 840            841  Cosmos   ATOM  2021-07-02 23:59:59  11.7649  10.5439
# 841            842  Cosmos   ATOM  2021-07-03 23:59:59  12.1983  11.5403
# 842            843  Cosmos   ATOM  2021-07-04 23:59:59  12.4340  11.5207
# 843            844  Cosmos   ATOM  2021-07-05 23:59:59  13.9683  11.9558
# 844            845  Cosmos   ATOM  2021-07-06 23:59:59  14.0204  12.8240
#
#         Open    Close        Volume     Marketcap
# 0     6.6332   7.5044  6.057301e+06  0.000000e+00
# 1     7.5080   7.3839  3.477393e+06  0.000000e+00
# 2     7.3574   4.7762  2.653565e+06  0.000000e+00
# 3     4.8282   5.1103  2.567201e+06  0.000000e+00
# 4     5.1000   4.8219  3.891084e+06  0.000000e+00
# ..       ...      ...           ...           ...
# 840  11.0481  11.7649  1.891418e+08  2.559039e+09
# 841  11.7910  11.8179  1.551317e+08  2.571184e+09
# 842  11.7996  12.2635  1.449177e+08  2.668775e+09
# 843  12.3204  13.5485  4.489358e+08  2.949102e+09
# 844  13.5581  13.1594  2.537822e+08  2.865093e+09
#
# [845 rows x 10 columns]

# %% [markdown]
# ##Tirar campos nulos

# %%
null_rows = df[df.isnull().any(axis=1)]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ####Não tem dados nulos

# %% [markdown]
# ###Tirando todos os registros vazios no intervalo de dados

# %%
df.dropna()
df
# Out:
#      serial_number    Name Symbol                 Date     High      Low  \
# 0                1  Cosmos   ATOM  2019-03-15 23:59:59   7.7152   6.4325
# 1                2  Cosmos   ATOM  2019-03-16 23:59:59   8.3056   6.6945
# 2                3  Cosmos   ATOM  2019-03-17 23:59:59   7.3574   4.7279
# 3                4  Cosmos   ATOM  2019-03-18 23:59:59   5.2300   4.8282
# 4                5  Cosmos   ATOM  2019-03-19 23:59:59   5.2062   4.7945
# ..             ...     ...    ...                  ...      ...      ...
# 840            841  Cosmos   ATOM  2021-07-02 23:59:59  11.7649  10.5439
# 841            842  Cosmos   ATOM  2021-07-03 23:59:59  12.1983  11.5403
# 842            843  Cosmos   ATOM  2021-07-04 23:59:59  12.4340  11.5207
# 843            844  Cosmos   ATOM  2021-07-05 23:59:59  13.9683  11.9558
# 844            845  Cosmos   ATOM  2021-07-06 23:59:59  14.0204  12.8240
#
#         Open    Close        Volume     Marketcap
# 0     6.6332   7.5044  6.057301e+06  0.000000e+00
# 1     7.5080   7.3839  3.477393e+06  0.000000e+00
# 2     7.3574   4.7762  2.653565e+06  0.000000e+00
# 3     4.8282   5.1103  2.567201e+06  0.000000e+00
# 4     5.1000   4.8219  3.891084e+06  0.000000e+00
# ..       ...      ...           ...           ...
# 840  11.0481  11.7649  1.891418e+08  2.559039e+09
# 841  11.7910  11.8179  1.551317e+08  2.571184e+09
# 842  11.7996  12.2635  1.449177e+08  2.668775e+09
# 843  12.3204  13.5485  4.489358e+08  2.949102e+09
# 844  13.5581  13.1594  2.537822e+08  2.865093e+09
#
# [845 rows x 10 columns]

# %% [markdown]
# ##Filtrando dados de 2013

# %%
df['Date'] = pd.to_datetime(df['Date'])

df_2013 = df[df['Date'].dt.year == 2013]

print(df_2013)
# Out:
# Empty DataFrame
# Columns: [serial_number, Name, Symbol, Date, High, Low, Open, Close, Volume, Marketcap]
# Index: []

# %% [markdown]
# ##Filtrando dados de 2020 para frente
# Esse é o que vamos usar para trabalhar

# %%
start_date = pd.to_datetime('2020-01-01')

df_from_2020 = df[df['Date'] >= start_date]

print(df_from_2020)

from google.colab import files

filtered_file_path = '/content/'
df_from_2020.to_csv("cosmos_limpo.csv", index=False)
# Out:
#      serial_number    Name Symbol                Date     High      Low  \
# 292            293  Cosmos   ATOM 2020-01-01 23:59:59   4.4676   4.2044
# 293            294  Cosmos   ATOM 2020-01-02 23:59:59   4.3813   4.0777
# 294            295  Cosmos   ATOM 2020-01-03 23:59:59   4.3566   4.0155
# 295            296  Cosmos   ATOM 2020-01-04 23:59:59   4.3856   4.2336
# 296            297  Cosmos   ATOM 2020-01-05 23:59:59   4.3951   4.2158
# ..             ...     ...    ...                 ...      ...      ...
# 840            841  Cosmos   ATOM 2021-07-02 23:59:59  11.7649  10.5439
# 841            842  Cosmos   ATOM 2021-07-03 23:59:59  12.1983  11.5403
# 842            843  Cosmos   ATOM 2021-07-04 23:59:59  12.4340  11.5207
# 843            844  Cosmos   ATOM 2021-07-05 23:59:59  13.9683  11.9558
# 844            845  Cosmos   ATOM 2021-07-06 23:59:59  14.0204  12.8240
#
#         Open    Close        Volume     Marketcap
# 292   4.2167   4.3802  1.079945e+08  8.352455e+08
# 293   4.3791   4.0918  1.113253e+08  7.802621e+08
# 294   4.1059   4.2479  1.386177e+08  8.100249e+08
# 295   4.2457   4.2864  9.071830e+07  8.173585e+08
# 296   4.2842   4.2319  1.153998e+08  8.069701e+08
# ..       ...      ...           ...           ...
# 840  11.0481  11.7649  1.891418e+08  2.559039e+09
# 841  11.7910  11.8179  1.551317e+08  2.571184e+09
# 842  11.7996  12.2635  1.449177e+08  2.668775e+09
# 843  12.3204  13.5485  4.489358e+08  2.949102e+09
# 844  13.5581  13.1594  2.537822e+08  2.865093e+09
#
# [553 rows x 10 columns]

# %% [markdown]
# ##O que foi feito
# Perguntas para verificar se a planilha está realmente limpa e útil:
#
#     Esses dados fazem sentido?
#         Sim, estou removendo todos os dados que não serão úteis, seja por serem duplicados, nulos ou não totalmente preenchidos. Essa planilha será comparada com eventos filtrados por ano e comparada com outras moedas referentes ao mesmo período.
#
#     Os dados seguem o padrão certo?
#         Sim, os dados foram convertidos, corrigidos e arredondados.
#
#     Prova alguma teoria, suspeita ou traz algum insight?
#         Sim, com esses dados posso analisar a relação entre as moedas e o mundo real.
#
#     Você consegue identificar tendências ou padrões com esses dados?
#         Sim, consigo observar médias, padrões e usar gráficos para extrair informações sobre como a moeda reagiu e como outras moedas reagiram. Posso comparar acontecimentos e observar seu impacto na moeda, além de calcular médias anuais.
#
#     Se não está conseguindo identificar tendências, seria por causa de algum problema na planilha?
#         Não se aplica.
